# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.ensemble import RandomForestRegressor
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score


# input file path
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario8_individual_model_approach"

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(workdir + "//200914_MC9K_%s.npz" % dname)
    ss0 = np.load(workdir + '//200914_MC9K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]

    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    rf = RandomForestRegressor(random_state = 84)
    # Train the model on training data
    rf.fit(train_X, train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)


    predicted_classes = rf.predict(test_X)
    predicted_value = predicted_classes
        
    
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//scenario8_individual_approach//Table//RF"
    c.to_csv(workdir + '//200915_scenario8_RF_%s_pred_and_val_result.csv' % dname, index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//scenario8_individual_model_approach"
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//scenario8_individual_approach//Figure"    

plt.savefig(workdir +'//200915_scenario8_RF_plot.png', dpi=400)
# Out:
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 10:04:01.471767
# EndTime : 2020-09-18 10:13:28.153853
# AEW541’s final rmse value is = 0.749675
# AEW541 R-squared value is = 0.091745
# Nilotinib_//n
# train_X shape: (326, 18988)
# 326 train samples
# 81 test samples
# StartTime : 2020-09-18 10:13:28.442053
# EndTime : 2020-09-18 10:21:36.360961
# Nilotinib’s final rmse value is = 1.005240
# Nilotinib R-squared value is = 0.053239
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 10:21:36.638221
# EndTime : 2020-09-18 10:25:32.397808
# 17-AAG’s final rmse value is = 1.028852
# 17-AAG R-squared value is = 0.185279
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 10:25:32.671048
# EndTime : 2020-09-18 10:31:44.821764
# PHA-665752’s final rmse value is = 0.206438
# PHA-665752 R-squared value is = -1.142846
# Lapatinib_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 10:31:45.121959
# EndTime : 2020-09-18 10:40:44.931060
# Lapatinib’s final rmse value is = 0.554244
# Lapatinib R-squared value is = -0.111036
# Nutlin-3_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 10:40:45.212278
# EndTime : 2020-09-18 10:44:48.659154
# Nutlin-3’s final rmse value is = 0.349622
# Nutlin-3 R-squared value is = -15.675499
# AZD0530_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 10:44:48.940429
# EndTime : 2020-09-18 10:53:33.230628
# AZD0530’s final rmse value is = 0.938675
# AZD0530 R-squared value is = 0.057605
# PF2341066_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 10:53:33.641518
# EndTime : 2020-09-18 11:03:00.599266
# PF2341066’s final rmse value is = 0.797784
# PF2341066 R-squared value is = 0.073253
# L-685458_//n
# train_X shape: (383, 18988)
# 383 train samples
# 95 test samples
# StartTime : 2020-09-18 11:03:00.927458
# EndTime : 2020-09-18 11:10:58.241789
# L-685458’s final rmse value is = 0.638878
# L-685458 R-squared value is = 0.111932
# ZD-6474_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-18 11:10:58.532385
# EndTime : 2020-09-18 11:18:31.945511
# ZD-6474’s final rmse value is = 0.655578
# ZD-6474 R-squared value is = -0.015622
# Panobinostat_//n
# train_X shape: (390, 18988)
# 390 train samples
# 97 test samples
# StartTime : 2020-09-18 11:18:32.271639
# EndTime : 2020-09-18 11:22:39.256822
# Panobinostat’s final rmse value is = 0.729667
# Panobinostat R-squared value is = 0.383346
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 11:22:39.580956
# EndTime : 2020-09-18 11:32:56.243195
# Sorafenib’s final rmse value is = 0.525295
# Sorafenib R-squared value is = 0.184542
# Irinotecan_//n
# train_X shape: (245, 18988)
# 245 train samples
# 61 test samples
# StartTime : 2020-09-18 11:32:56.437278
# EndTime : 2020-09-18 11:35:03.891808
# Irinotecan’s final rmse value is = 1.075735
# Irinotecan R-squared value is = 0.336975
# Topotecan_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 11:35:04.187020
# EndTime : 2020-09-18 11:38:52.589805
# Topotecan’s final rmse value is = 1.179149
# Topotecan R-squared value is = 0.369341
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 11:38:52.898233
# EndTime : 2020-09-18 11:44:26.005954
# LBW242’s final rmse value is = 0.434366
# LBW242 R-squared value is = -0.798772
# PD-0325901_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 11:44:26.307532
# EndTime : 2020-09-18 11:50:51.779311
# PD-0325901’s final rmse value is = 1.828890
# PD-0325901 R-squared value is = 0.338771
# PD-0332991_//n
# train_X shape: (337, 18988)
# 337 train samples
# 84 test samples
# StartTime : 2020-09-18 11:50:52.052088
# EndTime : 2020-09-18 11:56:33.894579
# PD-0332991’s final rmse value is = 0.581512
# PD-0332991 R-squared value is = 0.190803
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 11:56:34.186822
# EndTime : 2020-09-18 12:02:52.808432
# Paclitaxel’s final rmse value is = 1.966438
# Paclitaxel R-squared value is = 0.113419
# PLX4720_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-18 12:02:53.157892
# EndTime : 2020-09-18 12:08:52.786565
# PLX4720’s final rmse value is = 0.782863
# PLX4720 R-squared value is = 0.235262
# RAF265_//n
# train_X shape: (358, 18988)
# 358 train samples
# 89 test samples
# StartTime : 2020-09-18 12:08:53.052334
# EndTime : 2020-09-18 12:13:05.881663
# RAF265’s final rmse value is = 1.079934
# RAF265 R-squared value is = 0.093260
# TAE684_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 12:13:06.228737
# EndTime : 2020-09-18 12:18:20.258259
# TAE684’s final rmse value is = 1.238720
# TAE684 R-squared value is = 0.085121
# TKI258_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 12:18:20.560475
# EndTime : 2020-09-18 12:25:30.404599
# TKI258’s final rmse value is = 0.614063
# TKI258 R-squared value is = 0.222973
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 12:25:30.703902
# EndTime : 2020-09-18 12:33:23.421500
# Erlotinib’s final rmse value is = 0.727574
# Erlotinib R-squared value is = 0.049464
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 12:33:23.709729
# EndTime : 2020-09-18 12:39:39.587028
# AZD6244’s final rmse value is = 1.159408
# AZD6244 R-squared value is = 0.186009

# %%
num
# Out:
# 25

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE    R2value
# 0         AEW541  0.749675   0.091745
# 1      Nilotinib  1.005240   0.053239
# 2         17-AAG  1.028852   0.185279
# 3     PHA-665752  0.206438  -1.142846
# 4      Lapatinib  0.554244  -0.111036
# 5       Nutlin-3  0.349622 -15.675499
# 6        AZD0530  0.938675   0.057605
# 7      PF2341066  0.797784   0.073253
# 8       L-685458  0.638878   0.111932
# 9        ZD-6474  0.655578  -0.015622
# 10  Panobinostat  0.729667   0.383346
# 11     Sorafenib  0.525295   0.184542
# 12    Irinotecan  1.075735   0.336975
# 13     Topotecan  1.179149   0.369341
# 14        LBW242  0.434366  -0.798772
# 15    PD-0325901  1.828890   0.338771
# 16    PD-0332991  0.581512   0.190803
# 17    Paclitaxel  1.966438   0.113419
# 18       PLX4720  0.782863   0.235262
# 19        RAF265  1.079934   0.093260
# 20        TAE684  1.238720   0.085121
# 21        TKI258  0.614063   0.222973
# 22     Erlotinib  0.727574   0.049464
# 23       AZD6244  1.159408   0.186009

# %%
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario8_individual_approach" 
result.to_csv(workdir +'//200915_scenario8_RF_24drugs_metrics.csv', index=False)
