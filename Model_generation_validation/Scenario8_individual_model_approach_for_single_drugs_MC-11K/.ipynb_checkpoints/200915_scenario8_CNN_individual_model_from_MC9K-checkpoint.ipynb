# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import random
from pandas import DataFrame
from datetime import datetime
import keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten, Reshape, Activation
from keras.layers import Conv1D, MaxPooling1D ,AveragePooling1D
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras import backend as K
# from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
#from tensorflow.keras.optimizers import Adam
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# input file path
workdir = "E://Ronny_TF//200914_reupload//Dataset//Scenario8_individual_model_approach"
# Out:
# Using TensorFlow backend.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8322878813747914654
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8267812044
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14633437643887258416
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
# hyperparameters of CNN
num_classes = 1
learning_rate = 0.0002
training_epochs = 40
batch_size = 50
# img_rows, img_cols = 154, 154

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(workdir + "//200914_MC9K_%s.npz" % dname)
    ss0 = np.load(workdir + '//200914_MC9K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]
    
    # data reshape for CNN
    train_X = train_X.reshape(train_X.shape[0], train_X.shape[1],1)
    test_X = test_X.reshape(test_X.shape[0], test_X.shape[1],1)
    
    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model architecture
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    # In[10]:
    with K.tf.device('/GPU:0'):
        inputs = Input(shape=(train_X.shape[1],1),name='inputs')

        conv_cell_line_1 = Conv1D(filters=50, kernel_size=700, strides=5, activation='tanh')(inputs)
        maxpool_cell_line_1 = MaxPooling1D(pool_size=5)(conv_cell_line_1)
        conv_cell_line_2 = Conv1D(filters=30, kernel_size=5, strides=2, activation='relu')(maxpool_cell_line_1)
        maxpool_cell_line_2 = MaxPooling1D(pool_size=10)(conv_cell_line_2)
        flatten_cell_line = Flatten()(maxpool_cell_line_2)
        dense_cell_line = Dense(100, activation='relu')(flatten_cell_line)
        dropout_cell_line = Dropout(0.1)(dense_cell_line)

        dense_1 = Dense(300, activation='tanh')(dropout_cell_line)
        dropout_1 = Dropout(0.1)(dense_1)
        reshape_1 = Reshape((300, 1))(dropout_1)
        conv_1 = Conv1D(filters=30, kernel_size=150, strides=1, activation='relu')(reshape_1)
        maxpool_1 = MaxPooling1D(pool_size=2)(conv_1)
        conv_2 = Conv1D(filters=10, kernel_size=5, strides=1, activation='relu')(maxpool_1)
        maxpool_2 = MaxPooling1D(pool_size=3)(conv_2)
        conv_3 = Conv1D(filters=5, kernel_size=5, strides=1, activation='relu')(maxpool_2)
        maxpool_3 = MaxPooling1D(pool_size=3)(conv_3)
        dropout_2 = Dropout(0.1)(maxpool_3)
        flatten = Flatten()(dropout_2)
        dropout_3 = Dropout(0.2)(flatten)

        predictions = Dense(1, activation='linear')(dropout_3)



        model = Model(inputs=inputs, outputs=predictions, name='Test_v2_DNN20190327')
        model.compile(loss=keras.losses.mean_squared_error,
                      optimizer=keras.optimizers.Adam(learning_rate),
                      metrics=['mse','mae'])
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    with K.tf.device('/GPU:0'):
        model_train = model.fit(train_X, train_y, batch_size=batch_size,epochs=training_epochs,verbose=1,
                            validation_data=(test_X, test_y))

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = model.predict(test_X)
    predicted_value = predicted_classes
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "E://Ronny_TF//200914_reupload//Result//scenario8_individual_approach//Table//CNN"
    c.to_csv(workdir + '//200915_scenario8_CNN_%s_pred_and_val_result.csv' % dname, index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "E://Ronny_TF//200914_reupload//Dataset//scenario8_individual_model_approach"
workdir = "E://Ronny_TF//200914_reupload//Result//scenario8_individual_approach//Figure"

plt.savefig(workdir +'//200915_scenario8_CNN_plot.png', dpi=400)
# Out:
# AEW541_//n
# WARNING: Logging before flag parsing goes to stderr.
# W0917 12:30:26.358005 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:514: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0917 12:30:26.359926 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:71: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0917 12:30:26.360903 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:4076: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0917 12:30:26.375542 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:3900: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0917 12:30:26.406801 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:130: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0917 12:30:26.412632 10280 deprecation.py:506] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:3363: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0917 12:30:26.525873 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# train_X shape: (392, 18988, 1)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-17 12:30:26.358005
# StartTime : 2020-09-17 12:30:26.539509
# W0917 12:30:26.804982 10280 deprecation_wrapper.py:119] From c:\users\a\anaconda3\envs\tf_gpu_3.6\lib\site-packages\keras\backend\tensorflow_backend.py:983: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 392 samples, validate on 98 samples
# Epoch 1/40
# 392/392 [==============================] - 2s 5ms/step - loss: 1.8599 - mean_squared_error: 1.8599 - mean_absolute_error: 1.2429 - val_loss: 0.6572 - val_mean_squared_error: 0.6572 - val_mean_absolute_error: 0.7002
# Epoch 2/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.9627 - mean_squared_error: 0.9627 - mean_absolute_error: 0.7447 - val_loss: 0.8930 - val_mean_squared_error: 0.8930 - val_mean_absolute_error: 0.5549
# Epoch 3/40
# 392/392 [==============================] - 0s 434us/step - loss: 0.8945 - mean_squared_error: 0.8945 - mean_absolute_error: 0.6775 - val_loss: 0.6334 - val_mean_squared_error: 0.6334 - val_mean_absolute_error: 0.5766
# Epoch 4/40
# 392/392 [==============================] - 0s 422us/step - loss: 0.8938 - mean_squared_error: 0.8938 - mean_absolute_error: 0.7507 - val_loss: 0.6118 - val_mean_squared_error: 0.6118 - val_mean_absolute_error: 0.6275
# Epoch 5/40
# 392/392 [==============================] - 0s 424us/step - loss: 0.8200 - mean_squared_error: 0.8200 - mean_absolute_error: 0.7020 - val_loss: 0.6328 - val_mean_squared_error: 0.6328 - val_mean_absolute_error: 0.5758
# Epoch 6/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.9020 - mean_squared_error: 0.9020 - mean_absolute_error: 0.6934 - val_loss: 0.6145 - val_mean_squared_error: 0.6145 - val_mean_absolute_error: 0.5899
# Epoch 7/40
# 392/392 [==============================] - 0s 461us/step - loss: 0.8295 - mean_squared_error: 0.8295 - mean_absolute_error: 0.6974 - val_loss: 0.6058 - val_mean_squared_error: 0.6058 - val_mean_absolute_error: 0.6043
# Epoch 8/40
# 392/392 [==============================] - 0s 458us/step - loss: 0.8358 - mean_squared_error: 0.8358 - mean_absolute_error: 0.7056 - val_loss: 0.6108 - val_mean_squared_error: 0.6108 - val_mean_absolute_error: 0.5851
# Epoch 9/40
# 392/392 [==============================] - 0s 436us/step - loss: 0.8346 - mean_squared_error: 0.8346 - mean_absolute_error: 0.7231 - val_loss: 0.5954 - val_mean_squared_error: 0.5954 - val_mean_absolute_error: 0.6104
# Epoch 10/40
# 392/392 [==============================] - 0s 454us/step - loss: 0.8147 - mean_squared_error: 0.8147 - mean_absolute_error: 0.6679 - val_loss: 0.6088 - val_mean_squared_error: 0.6088 - val_mean_absolute_error: 0.5758
# Epoch 11/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.7651 - mean_squared_error: 0.7651 - mean_absolute_error: 0.6636 - val_loss: 0.5868 - val_mean_squared_error: 0.5868 - val_mean_absolute_error: 0.6005
# Epoch 12/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.7227 - mean_squared_error: 0.7227 - mean_absolute_error: 0.6401 - val_loss: 0.5871 - val_mean_squared_error: 0.5871 - val_mean_absolute_error: 0.5878
# Epoch 13/40
# 392/392 [==============================] - 0s 441us/step - loss: 0.7799 - mean_squared_error: 0.7799 - mean_absolute_error: 0.6741 - val_loss: 0.5837 - val_mean_squared_error: 0.5837 - val_mean_absolute_error: 0.5809
# Epoch 14/40
# 392/392 [==============================] - 0s 458us/step - loss: 0.7252 - mean_squared_error: 0.7252 - mean_absolute_error: 0.6475 - val_loss: 0.5819 - val_mean_squared_error: 0.5819 - val_mean_absolute_error: 0.5771
# Epoch 15/40
# 392/392 [==============================] - 0s 436us/step - loss: 0.6834 - mean_squared_error: 0.6834 - mean_absolute_error: 0.6173 - val_loss: 0.5684 - val_mean_squared_error: 0.5684 - val_mean_absolute_error: 0.5898
# Epoch 16/40
# 392/392 [==============================] - 0s 443us/step - loss: 0.6986 - mean_squared_error: 0.6986 - mean_absolute_error: 0.6341 - val_loss: 0.5575 - val_mean_squared_error: 0.5575 - val_mean_absolute_error: 0.6016
# Epoch 17/40
# 392/392 [==============================] - 0s 438us/step - loss: 0.6814 - mean_squared_error: 0.6814 - mean_absolute_error: 0.6287 - val_loss: 0.5514 - val_mean_squared_error: 0.5514 - val_mean_absolute_error: 0.5934
# Epoch 18/40
# 392/392 [==============================] - 0s 439us/step - loss: 0.6710 - mean_squared_error: 0.6710 - mean_absolute_error: 0.6208 - val_loss: 0.5461 - val_mean_squared_error: 0.5461 - val_mean_absolute_error: 0.6018
# Epoch 19/40
# 392/392 [==============================] - 0s 438us/step - loss: 0.6463 - mean_squared_error: 0.6463 - mean_absolute_error: 0.6303 - val_loss: 0.7060 - val_mean_squared_error: 0.7060 - val_mean_absolute_error: 0.5384
# Epoch 20/40
# 392/392 [==============================] - 0s 430us/step - loss: 0.6642 - mean_squared_error: 0.6642 - mean_absolute_error: 0.6301 - val_loss: 0.5494 - val_mean_squared_error: 0.5494 - val_mean_absolute_error: 0.6187
# Epoch 21/40
# 392/392 [==============================] - 0s 430us/step - loss: 0.5790 - mean_squared_error: 0.5790 - mean_absolute_error: 0.5891 - val_loss: 0.5484 - val_mean_squared_error: 0.5484 - val_mean_absolute_error: 0.5490
# Epoch 22/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.5426 - mean_squared_error: 0.5426 - mean_absolute_error: 0.5646 - val_loss: 0.5518 - val_mean_squared_error: 0.5518 - val_mean_absolute_error: 0.5418
# Epoch 23/40
# 392/392 [==============================] - 0s 416us/step - loss: 0.5339 - mean_squared_error: 0.5339 - mean_absolute_error: 0.5571 - val_loss: 0.5439 - val_mean_squared_error: 0.5439 - val_mean_absolute_error: 0.6016
# Epoch 24/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.5080 - mean_squared_error: 0.5080 - mean_absolute_error: 0.5643 - val_loss: 0.5893 - val_mean_squared_error: 0.5893 - val_mean_absolute_error: 0.5299
# Epoch 25/40
# 392/392 [==============================] - 0s 421us/step - loss: 0.4779 - mean_squared_error: 0.4779 - mean_absolute_error: 0.5388 - val_loss: 0.5834 - val_mean_squared_error: 0.5834 - val_mean_absolute_error: 0.5228
# Epoch 26/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.4675 - mean_squared_error: 0.4675 - mean_absolute_error: 0.5277 - val_loss: 0.6420 - val_mean_squared_error: 0.6420 - val_mean_absolute_error: 0.5270
# Epoch 27/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.4116 - mean_squared_error: 0.4116 - mean_absolute_error: 0.4890 - val_loss: 0.5382 - val_mean_squared_error: 0.5382 - val_mean_absolute_error: 0.5418
# Epoch 28/40
# 392/392 [==============================] - 0s 420us/step - loss: 0.4192 - mean_squared_error: 0.4192 - mean_absolute_error: 0.4978 - val_loss: 0.5360 - val_mean_squared_error: 0.5360 - val_mean_absolute_error: 0.5614
# Epoch 29/40
# 392/392 [==============================] - 0s 424us/step - loss: 0.3438 - mean_squared_error: 0.3438 - mean_absolute_error: 0.4583 - val_loss: 0.5275 - val_mean_squared_error: 0.5275 - val_mean_absolute_error: 0.5562
# Epoch 30/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.3428 - mean_squared_error: 0.3428 - mean_absolute_error: 0.4508 - val_loss: 0.5420 - val_mean_squared_error: 0.5420 - val_mean_absolute_error: 0.5605
# Epoch 31/40
# 392/392 [==============================] - 0s 425us/step - loss: 0.3323 - mean_squared_error: 0.3323 - mean_absolute_error: 0.4622 - val_loss: 0.5410 - val_mean_squared_error: 0.5410 - val_mean_absolute_error: 0.5896
# Epoch 32/40
# 392/392 [==============================] - 0s 436us/step - loss: 0.2989 - mean_squared_error: 0.2989 - mean_absolute_error: 0.4239 - val_loss: 0.5306 - val_mean_squared_error: 0.5306 - val_mean_absolute_error: 0.5579
# Epoch 33/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.3542 - mean_squared_error: 0.3542 - mean_absolute_error: 0.4704 - val_loss: 0.5421 - val_mean_squared_error: 0.5421 - val_mean_absolute_error: 0.5363
# Epoch 34/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.3072 - mean_squared_error: 0.3072 - mean_absolute_error: 0.4296 - val_loss: 0.5530 - val_mean_squared_error: 0.5530 - val_mean_absolute_error: 0.5362
# Epoch 35/40
# 392/392 [==============================] - 0s 447us/step - loss: 0.2492 - mean_squared_error: 0.2492 - mean_absolute_error: 0.3802 - val_loss: 0.5718 - val_mean_squared_error: 0.5718 - val_mean_absolute_error: 0.5392
# Epoch 36/40
# 392/392 [==============================] - 0s 418us/step - loss: 0.2559 - mean_squared_error: 0.2559 - mean_absolute_error: 0.3938 - val_loss: 0.5543 - val_mean_squared_error: 0.5543 - val_mean_absolute_error: 0.5278
# Epoch 37/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.2382 - mean_squared_error: 0.2382 - mean_absolute_error: 0.3823 - val_loss: 0.5885 - val_mean_squared_error: 0.5885 - val_mean_absolute_error: 0.5426
# Epoch 38/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.2107 - mean_squared_error: 0.2107 - mean_absolute_error: 0.3500 - val_loss: 0.5750 - val_mean_squared_error: 0.5750 - val_mean_absolute_error: 0.5730
# Epoch 39/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.2280 - mean_squared_error: 0.2280 - mean_absolute_error: 0.3703 - val_loss: 0.5711 - val_mean_squared_error: 0.5711 - val_mean_absolute_error: 0.5309
# Epoch 40/40
# 392/392 [==============================] - 0s 422us/step - loss: 0.2187 - mean_squared_error: 0.2187 - mean_absolute_error: 0.3576 - val_loss: 0.6106 - val_mean_squared_error: 0.6106 - val_mean_absolute_error: 0.5148
# EndTime : 2020-09-17 12:30:35.826806
# AEW541’s final rmse value is = 0.781426
# AEW541 R-squared value is = 0.013181
# Nilotinib_//n
# train_X shape: (326, 18988, 1)
# 326 train samples
# 81 test samples
# StartTime : 2020-09-17 12:30:36.160598
# StartTime : 2020-09-17 12:30:36.374342
# Train on 326 samples, validate on 81 samples
# Epoch 1/40
# 326/326 [==============================] - 1s 3ms/step - loss: 3.7185 - mean_squared_error: 3.7185 - mean_absolute_error: 1.8673 - val_loss: 2.5098 - val_mean_squared_error: 2.5098 - val_mean_absolute_error: 1.4772
# Epoch 2/40
# 326/326 [==============================] - 0s 455us/step - loss: 2.1613 - mean_squared_error: 2.1613 - mean_absolute_error: 1.3314 - val_loss: 1.1738 - val_mean_squared_error: 1.1738 - val_mean_absolute_error: 0.7201
# Epoch 3/40
# 326/326 [==============================] - 0s 443us/step - loss: 1.1607 - mean_squared_error: 1.1607 - mean_absolute_error: 0.7385 - val_loss: 1.2248 - val_mean_squared_error: 1.2248 - val_mean_absolute_error: 0.4048
# Epoch 4/40
# 326/326 [==============================] - 0s 434us/step - loss: 1.3213 - mean_squared_error: 1.3213 - mean_absolute_error: 0.5992 - val_loss: 1.3713 - val_mean_squared_error: 1.3713 - val_mean_absolute_error: 0.5561
# Epoch 5/40
# 326/326 [==============================] - 0s 431us/step - loss: 1.1937 - mean_squared_error: 1.1937 - mean_absolute_error: 0.5870 - val_loss: 1.1050 - val_mean_squared_error: 1.1050 - val_mean_absolute_error: 0.3670
# Epoch 6/40
# 326/326 [==============================] - 0s 433us/step - loss: 1.1163 - mean_squared_error: 1.1163 - mean_absolute_error: 0.6138 - val_loss: 1.0635 - val_mean_squared_error: 1.0635 - val_mean_absolute_error: 0.4797
# Epoch 7/40
# 326/326 [==============================] - 0s 425us/step - loss: 1.1344 - mean_squared_error: 1.1344 - mean_absolute_error: 0.6251 - val_loss: 1.0713 - val_mean_squared_error: 1.0713 - val_mean_absolute_error: 0.4195
# Epoch 8/40
# 326/326 [==============================] - 0s 428us/step - loss: 1.0958 - mean_squared_error: 1.0958 - mean_absolute_error: 0.5740 - val_loss: 1.0997 - val_mean_squared_error: 1.0997 - val_mean_absolute_error: 0.3696
# Epoch 9/40
# 326/326 [==============================] - 0s 432us/step - loss: 1.0795 - mean_squared_error: 1.0795 - mean_absolute_error: 0.5729 - val_loss: 1.1065 - val_mean_squared_error: 1.1065 - val_mean_absolute_error: 0.3597
# Epoch 10/40
# 326/326 [==============================] - 0s 435us/step - loss: 1.1708 - mean_squared_error: 1.1708 - mean_absolute_error: 0.5911 - val_loss: 1.0680 - val_mean_squared_error: 1.0680 - val_mean_absolute_error: 0.4064
# Epoch 11/40
# 326/326 [==============================] - 0s 480us/step - loss: 1.0693 - mean_squared_error: 1.0693 - mean_absolute_error: 0.5700 - val_loss: 1.0606 - val_mean_squared_error: 1.0606 - val_mean_absolute_error: 0.4128
# Epoch 12/40
# 326/326 [==============================] - 0s 432us/step - loss: 1.0754 - mean_squared_error: 1.0754 - mean_absolute_error: 0.6145 - val_loss: 1.0609 - val_mean_squared_error: 1.0609 - val_mean_absolute_error: 0.3955
# Epoch 13/40
# 326/326 [==============================] - 0s 431us/step - loss: 1.1051 - mean_squared_error: 1.1051 - mean_absolute_error: 0.6184 - val_loss: 1.0420 - val_mean_squared_error: 1.0420 - val_mean_absolute_error: 0.4283
# Epoch 14/40
# 326/326 [==============================] - 0s 432us/step - loss: 1.0686 - mean_squared_error: 1.0686 - mean_absolute_error: 0.5935 - val_loss: 1.0370 - val_mean_squared_error: 1.0370 - val_mean_absolute_error: 0.4126
# Epoch 15/40
# 326/326 [==============================] - 0s 440us/step - loss: 1.0280 - mean_squared_error: 1.0280 - mean_absolute_error: 0.5834 - val_loss: 1.0463 - val_mean_squared_error: 1.0463 - val_mean_absolute_error: 0.3727
# Epoch 16/40
# 326/326 [==============================] - 0s 419us/step - loss: 1.0542 - mean_squared_error: 1.0542 - mean_absolute_error: 0.5899 - val_loss: 1.0206 - val_mean_squared_error: 1.0206 - val_mean_absolute_error: 0.4165
# Epoch 17/40
# 326/326 [==============================] - 0s 419us/step - loss: 1.0183 - mean_squared_error: 1.0183 - mean_absolute_error: 0.6098 - val_loss: 1.0199 - val_mean_squared_error: 1.0199 - val_mean_absolute_error: 0.4007
# Epoch 18/40
# 326/326 [==============================] - 0s 435us/step - loss: 0.9479 - mean_squared_error: 0.9479 - mean_absolute_error: 0.5557 - val_loss: 1.0346 - val_mean_squared_error: 1.0346 - val_mean_absolute_error: 0.3666
# Epoch 19/40
# 326/326 [==============================] - 0s 431us/step - loss: 0.9343 - mean_squared_error: 0.9343 - mean_absolute_error: 0.5621 - val_loss: 1.0050 - val_mean_squared_error: 1.0050 - val_mean_absolute_error: 0.4647
# Epoch 20/40
# 326/326 [==============================] - 0s 431us/step - loss: 0.9581 - mean_squared_error: 0.9581 - mean_absolute_error: 0.6098 - val_loss: 1.0327 - val_mean_squared_error: 1.0327 - val_mean_absolute_error: 0.3936
# Epoch 21/40
# 326/326 [==============================] - 0s 428us/step - loss: 0.9136 - mean_squared_error: 0.9136 - mean_absolute_error: 0.5361 - val_loss: 0.9897 - val_mean_squared_error: 0.9897 - val_mean_absolute_error: 0.4057
# Epoch 22/40
# 326/326 [==============================] - 0s 431us/step - loss: 0.9235 - mean_squared_error: 0.9235 - mean_absolute_error: 0.6260 - val_loss: 0.9930 - val_mean_squared_error: 0.9930 - val_mean_absolute_error: 0.3970
# Epoch 23/40
# 326/326 [==============================] - 0s 428us/step - loss: 0.8203 - mean_squared_error: 0.8203 - mean_absolute_error: 0.5265 - val_loss: 1.0589 - val_mean_squared_error: 1.0589 - val_mean_absolute_error: 0.3979
# Epoch 24/40
# 326/326 [==============================] - 0s 425us/step - loss: 0.8624 - mean_squared_error: 0.8624 - mean_absolute_error: 0.5432 - val_loss: 0.9598 - val_mean_squared_error: 0.9598 - val_mean_absolute_error: 0.4820
# Epoch 25/40
# 326/326 [==============================] - 0s 428us/step - loss: 0.8512 - mean_squared_error: 0.8512 - mean_absolute_error: 0.5711 - val_loss: 0.9901 - val_mean_squared_error: 0.9901 - val_mean_absolute_error: 0.3673
# Epoch 26/40
# 326/326 [==============================] - 0s 434us/step - loss: 0.7877 - mean_squared_error: 0.7877 - mean_absolute_error: 0.5358 - val_loss: 0.9648 - val_mean_squared_error: 0.9648 - val_mean_absolute_error: 0.4043
# Epoch 27/40
# 326/326 [==============================] - 0s 425us/step - loss: 0.7381 - mean_squared_error: 0.7381 - mean_absolute_error: 0.5292 - val_loss: 0.9513 - val_mean_squared_error: 0.9513 - val_mean_absolute_error: 0.3849
# Epoch 28/40
# 326/326 [==============================] - 0s 443us/step - loss: 0.7434 - mean_squared_error: 0.7434 - mean_absolute_error: 0.5503 - val_loss: 0.9163 - val_mean_squared_error: 0.9163 - val_mean_absolute_error: 0.4033
# Epoch 29/40
# 326/326 [==============================] - 0s 425us/step - loss: 0.6599 - mean_squared_error: 0.6599 - mean_absolute_error: 0.5101 - val_loss: 0.9523 - val_mean_squared_error: 0.9523 - val_mean_absolute_error: 0.3955
# Epoch 30/40
# 326/326 [==============================] - 0s 437us/step - loss: 0.6064 - mean_squared_error: 0.6064 - mean_absolute_error: 0.4927 - val_loss: 0.8971 - val_mean_squared_error: 0.8971 - val_mean_absolute_error: 0.4081
# Epoch 31/40
# 326/326 [==============================] - 0s 433us/step - loss: 0.6199 - mean_squared_error: 0.6199 - mean_absolute_error: 0.5110 - val_loss: 0.9611 - val_mean_squared_error: 0.9611 - val_mean_absolute_error: 0.3824
# Epoch 32/40
# 326/326 [==============================] - 0s 424us/step - loss: 0.5792 - mean_squared_error: 0.5792 - mean_absolute_error: 0.4925 - val_loss: 0.8928 - val_mean_squared_error: 0.8928 - val_mean_absolute_error: 0.3871
# Epoch 33/40
# 326/326 [==============================] - 0s 427us/step - loss: 0.5471 - mean_squared_error: 0.5471 - mean_absolute_error: 0.4802 - val_loss: 0.8891 - val_mean_squared_error: 0.8891 - val_mean_absolute_error: 0.4495
# Epoch 34/40
# 326/326 [==============================] - 0s 427us/step - loss: 0.4800 - mean_squared_error: 0.4800 - mean_absolute_error: 0.4431 - val_loss: 0.8814 - val_mean_squared_error: 0.8814 - val_mean_absolute_error: 0.3796
# Epoch 35/40
# 326/326 [==============================] - 0s 431us/step - loss: 0.4916 - mean_squared_error: 0.4916 - mean_absolute_error: 0.4517 - val_loss: 0.8911 - val_mean_squared_error: 0.8911 - val_mean_absolute_error: 0.3619
# Epoch 36/40
# 326/326 [==============================] - 0s 426us/step - loss: 0.4414 - mean_squared_error: 0.4414 - mean_absolute_error: 0.4305 - val_loss: 0.8866 - val_mean_squared_error: 0.8866 - val_mean_absolute_error: 0.3832
# Epoch 37/40
# 326/326 [==============================] - 0s 425us/step - loss: 0.3753 - mean_squared_error: 0.3753 - mean_absolute_error: 0.4039 - val_loss: 0.8590 - val_mean_squared_error: 0.8590 - val_mean_absolute_error: 0.4557
# Epoch 38/40
# 326/326 [==============================] - 0s 428us/step - loss: 0.4023 - mean_squared_error: 0.4023 - mean_absolute_error: 0.4391 - val_loss: 0.8679 - val_mean_squared_error: 0.8679 - val_mean_absolute_error: 0.3710
# Epoch 39/40
# 326/326 [==============================] - 0s 432us/step - loss: 0.3598 - mean_squared_error: 0.3598 - mean_absolute_error: 0.4034 - val_loss: 0.9148 - val_mean_squared_error: 0.9148 - val_mean_absolute_error: 0.3853
# Epoch 40/40
# 326/326 [==============================] - 0s 434us/step - loss: 0.3862 - mean_squared_error: 0.3862 - mean_absolute_error: 0.4225 - val_loss: 0.8502 - val_mean_squared_error: 0.8502 - val_mean_absolute_error: 0.3744
# EndTime : 2020-09-17 12:30:43.227669
# Nilotinib’s final rmse value is = 0.922080
# Nilotinib R-squared value is = 0.203403
# 17-AAG_//n
# train_X shape: (392, 18988, 1)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-17 12:30:43.606546
# StartTime : 2020-09-17 12:30:43.838835
# Train on 392 samples, validate on 98 samples
# Epoch 1/40
# 392/392 [==============================] - 1s 2ms/step - loss: 3.7571 - mean_squared_error: 3.7571 - mean_absolute_error: 1.6307 - val_loss: 2.0593 - val_mean_squared_error: 2.0593 - val_mean_absolute_error: 1.1811
# Epoch 2/40
# 392/392 [==============================] - 0s 480us/step - loss: 2.7097 - mean_squared_error: 2.7097 - mean_absolute_error: 1.3203 - val_loss: 1.2853 - val_mean_squared_error: 1.2853 - val_mean_absolute_error: 0.8865
# Epoch 3/40
# 392/392 [==============================] - 0s 451us/step - loss: 2.7072 - mean_squared_error: 2.7072 - mean_absolute_error: 1.2674 - val_loss: 1.2927 - val_mean_squared_error: 1.2927 - val_mean_absolute_error: 0.8863
# Epoch 4/40
# 392/392 [==============================] - 0s 433us/step - loss: 2.5095 - mean_squared_error: 2.5095 - mean_absolute_error: 1.2266 - val_loss: 1.4111 - val_mean_squared_error: 1.4111 - val_mean_absolute_error: 0.9151
# Epoch 5/40
# 392/392 [==============================] - 0s 421us/step - loss: 2.6714 - mean_squared_error: 2.6714 - mean_absolute_error: 1.2948 - val_loss: 1.4519 - val_mean_squared_error: 1.4519 - val_mean_absolute_error: 0.9320
# Epoch 6/40
# 392/392 [==============================] - 0s 423us/step - loss: 2.6379 - mean_squared_error: 2.6379 - mean_absolute_error: 1.2652 - val_loss: 1.3535 - val_mean_squared_error: 1.3535 - val_mean_absolute_error: 0.8975
# Epoch 7/40
# 392/392 [==============================] - 0s 419us/step - loss: 2.6143 - mean_squared_error: 2.6143 - mean_absolute_error: 1.2761 - val_loss: 1.3786 - val_mean_squared_error: 1.3786 - val_mean_absolute_error: 0.9050
# Epoch 8/40
# 392/392 [==============================] - 0s 426us/step - loss: 2.5563 - mean_squared_error: 2.5563 - mean_absolute_error: 1.2485 - val_loss: 1.3879 - val_mean_squared_error: 1.3879 - val_mean_absolute_error: 0.9100
# Epoch 9/40
# 392/392 [==============================] - 0s 423us/step - loss: 2.4799 - mean_squared_error: 2.4799 - mean_absolute_error: 1.2317 - val_loss: 1.3544 - val_mean_squared_error: 1.3544 - val_mean_absolute_error: 0.8987
# Epoch 10/40
# 392/392 [==============================] - 0s 421us/step - loss: 2.4922 - mean_squared_error: 2.4922 - mean_absolute_error: 1.2576 - val_loss: 1.3545 - val_mean_squared_error: 1.3545 - val_mean_absolute_error: 0.9033
# Epoch 11/40
# 392/392 [==============================] - 0s 436us/step - loss: 2.5005 - mean_squared_error: 2.5005 - mean_absolute_error: 1.2475 - val_loss: 1.2971 - val_mean_squared_error: 1.2971 - val_mean_absolute_error: 0.8869
# Epoch 12/40
# 392/392 [==============================] - 0s 423us/step - loss: 2.4503 - mean_squared_error: 2.4503 - mean_absolute_error: 1.2140 - val_loss: 1.3891 - val_mean_squared_error: 1.3891 - val_mean_absolute_error: 0.9254
# Epoch 13/40
# 392/392 [==============================] - 0s 424us/step - loss: 2.4206 - mean_squared_error: 2.4206 - mean_absolute_error: 1.2273 - val_loss: 1.2063 - val_mean_squared_error: 1.2063 - val_mean_absolute_error: 0.8629
# Epoch 14/40
# 392/392 [==============================] - 0s 423us/step - loss: 2.3223 - mean_squared_error: 2.3223 - mean_absolute_error: 1.1721 - val_loss: 1.3550 - val_mean_squared_error: 1.3550 - val_mean_absolute_error: 0.9200
# Epoch 15/40
# 392/392 [==============================] - 0s 421us/step - loss: 2.1462 - mean_squared_error: 2.1462 - mean_absolute_error: 1.1403 - val_loss: 1.2177 - val_mean_squared_error: 1.2177 - val_mean_absolute_error: 0.8734
# Epoch 16/40
# 392/392 [==============================] - 0s 420us/step - loss: 2.2239 - mean_squared_error: 2.2239 - mean_absolute_error: 1.1410 - val_loss: 1.2060 - val_mean_squared_error: 1.2060 - val_mean_absolute_error: 0.8696
# Epoch 17/40
# 392/392 [==============================] - 0s 423us/step - loss: 1.9078 - mean_squared_error: 1.9078 - mean_absolute_error: 1.0649 - val_loss: 1.3958 - val_mean_squared_error: 1.3958 - val_mean_absolute_error: 0.9441
# Epoch 18/40
# 392/392 [==============================] - 0s 429us/step - loss: 1.7775 - mean_squared_error: 1.7775 - mean_absolute_error: 1.0199 - val_loss: 1.3966 - val_mean_squared_error: 1.3966 - val_mean_absolute_error: 0.9487
# Epoch 19/40
# 392/392 [==============================] - 0s 419us/step - loss: 1.7320 - mean_squared_error: 1.7320 - mean_absolute_error: 1.0140 - val_loss: 1.2192 - val_mean_squared_error: 1.2192 - val_mean_absolute_error: 0.8836
# Epoch 20/40
# 392/392 [==============================] - 0s 421us/step - loss: 1.6637 - mean_squared_error: 1.6637 - mean_absolute_error: 1.0002 - val_loss: 1.3927 - val_mean_squared_error: 1.3927 - val_mean_absolute_error: 0.9487
# Epoch 21/40
# 392/392 [==============================] - 0s 418us/step - loss: 1.5087 - mean_squared_error: 1.5087 - mean_absolute_error: 0.9572 - val_loss: 1.1726 - val_mean_squared_error: 1.1726 - val_mean_absolute_error: 0.8554
# Epoch 22/40
# 392/392 [==============================] - 0s 426us/step - loss: 1.4622 - mean_squared_error: 1.4622 - mean_absolute_error: 0.9332 - val_loss: 1.0770 - val_mean_squared_error: 1.0770 - val_mean_absolute_error: 0.8178
# Epoch 23/40
# 392/392 [==============================] - 0s 423us/step - loss: 1.1259 - mean_squared_error: 1.1259 - mean_absolute_error: 0.8112 - val_loss: 1.4042 - val_mean_squared_error: 1.4042 - val_mean_absolute_error: 0.9447
# Epoch 24/40
# 392/392 [==============================] - 0s 421us/step - loss: 1.0974 - mean_squared_error: 1.0974 - mean_absolute_error: 0.7834 - val_loss: 1.5323 - val_mean_squared_error: 1.5323 - val_mean_absolute_error: 0.9934
# Epoch 25/40
# 392/392 [==============================] - 0s 441us/step - loss: 1.0988 - mean_squared_error: 1.0988 - mean_absolute_error: 0.8217 - val_loss: 1.3217 - val_mean_squared_error: 1.3217 - val_mean_absolute_error: 0.9035
# Epoch 26/40
# 392/392 [==============================] - 0s 426us/step - loss: 1.0244 - mean_squared_error: 1.0244 - mean_absolute_error: 0.7664 - val_loss: 1.2468 - val_mean_squared_error: 1.2468 - val_mean_absolute_error: 0.8852
# Epoch 27/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.8818 - mean_squared_error: 0.8818 - mean_absolute_error: 0.6963 - val_loss: 1.1095 - val_mean_squared_error: 1.1095 - val_mean_absolute_error: 0.8369
# Epoch 28/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.7721 - mean_squared_error: 0.7721 - mean_absolute_error: 0.6695 - val_loss: 1.1028 - val_mean_squared_error: 1.1028 - val_mean_absolute_error: 0.8401
# Epoch 29/40
# 392/392 [==============================] - 0s 429us/step - loss: 0.8439 - mean_squared_error: 0.8439 - mean_absolute_error: 0.6734 - val_loss: 1.1979 - val_mean_squared_error: 1.1979 - val_mean_absolute_error: 0.8744
# Epoch 30/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.7601 - mean_squared_error: 0.7601 - mean_absolute_error: 0.6366 - val_loss: 1.0815 - val_mean_squared_error: 1.0815 - val_mean_absolute_error: 0.8266
# Epoch 31/40
# 392/392 [==============================] - 0s 446us/step - loss: 0.7212 - mean_squared_error: 0.7212 - mean_absolute_error: 0.6142 - val_loss: 1.1471 - val_mean_squared_error: 1.1471 - val_mean_absolute_error: 0.8530
# Epoch 32/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.7218 - mean_squared_error: 0.7218 - mean_absolute_error: 0.6371 - val_loss: 1.1550 - val_mean_squared_error: 1.1550 - val_mean_absolute_error: 0.8611
# Epoch 33/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.6655 - mean_squared_error: 0.6655 - mean_absolute_error: 0.6162 - val_loss: 1.1669 - val_mean_squared_error: 1.1669 - val_mean_absolute_error: 0.8675
# Epoch 34/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.6658 - mean_squared_error: 0.6658 - mean_absolute_error: 0.6091 - val_loss: 1.1741 - val_mean_squared_error: 1.1741 - val_mean_absolute_error: 0.8678
# Epoch 35/40
# 392/392 [==============================] - 0s 422us/step - loss: 0.5975 - mean_squared_error: 0.5975 - mean_absolute_error: 0.5646 - val_loss: 1.0621 - val_mean_squared_error: 1.0621 - val_mean_absolute_error: 0.8267
# Epoch 36/40
# 392/392 [==============================] - 0s 438us/step - loss: 0.5414 - mean_squared_error: 0.5414 - mean_absolute_error: 0.5449 - val_loss: 1.1077 - val_mean_squared_error: 1.1077 - val_mean_absolute_error: 0.8459
# Epoch 37/40
# 392/392 [==============================] - 0s 421us/step - loss: 0.6050 - mean_squared_error: 0.6050 - mean_absolute_error: 0.5724 - val_loss: 1.2064 - val_mean_squared_error: 1.2064 - val_mean_absolute_error: 0.8874
# Epoch 38/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.5976 - mean_squared_error: 0.5976 - mean_absolute_error: 0.5893 - val_loss: 1.1349 - val_mean_squared_error: 1.1349 - val_mean_absolute_error: 0.8427
# Epoch 39/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.5364 - mean_squared_error: 0.5364 - mean_absolute_error: 0.5613 - val_loss: 1.3094 - val_mean_squared_error: 1.3094 - val_mean_absolute_error: 0.9282
# Epoch 40/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.5784 - mean_squared_error: 0.5784 - mean_absolute_error: 0.5899 - val_loss: 1.1654 - val_mean_squared_error: 1.1654 - val_mean_absolute_error: 0.8620
# EndTime : 2020-09-17 12:30:51.880611
# 17-AAG’s final rmse value is = 1.079519
# 17-AAG R-squared value is = 0.103060
# PHA-665752_//n
# train_X shape: (392, 18988, 1)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-17 12:30:52.292483
# StartTime : 2020-09-17 12:30:52.459351
# Train on 392 samples, validate on 98 samples
# Epoch 1/40
# 392/392 [==============================] - 1s 2ms/step - loss: 3.5012 - mean_squared_error: 3.5012 - mean_absolute_error: 1.8412 - val_loss: 2.3198 - val_mean_squared_error: 2.3198 - val_mean_absolute_error: 1.5167
# Epoch 2/40
# 392/392 [==============================] - 0s 431us/step - loss: 1.9207 - mean_squared_error: 1.9207 - mean_absolute_error: 1.3138 - val_loss: 0.4170 - val_mean_squared_error: 0.4170 - val_mean_absolute_error: 0.6390
# Epoch 3/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.7408 - mean_squared_error: 0.7408 - mean_absolute_error: 0.6644 - val_loss: 0.0997 - val_mean_squared_error: 0.0997 - val_mean_absolute_error: 0.2842
# Epoch 4/40
# 392/392 [==============================] - 0s 422us/step - loss: 0.7332 - mean_squared_error: 0.7332 - mean_absolute_error: 0.5879 - val_loss: 0.0848 - val_mean_squared_error: 0.0848 - val_mean_absolute_error: 0.2553
# Epoch 5/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.6286 - mean_squared_error: 0.6286 - mean_absolute_error: 0.5483 - val_loss: 0.0489 - val_mean_squared_error: 0.0489 - val_mean_absolute_error: 0.2079
# Epoch 6/40
# 392/392 [==============================] - 0s 425us/step - loss: 0.6332 - mean_squared_error: 0.6332 - mean_absolute_error: 0.5372 - val_loss: 0.0247 - val_mean_squared_error: 0.0247 - val_mean_absolute_error: 0.1168
# Epoch 7/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.4724 - mean_squared_error: 0.4724 - mean_absolute_error: 0.4754 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - val_mean_absolute_error: 0.0479
# Epoch 8/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.5146 - mean_squared_error: 0.5146 - mean_absolute_error: 0.4640 - val_loss: 0.0290 - val_mean_squared_error: 0.0290 - val_mean_absolute_error: 0.1408
# Epoch 9/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.5104 - mean_squared_error: 0.5104 - mean_absolute_error: 0.4811 - val_loss: 0.0294 - val_mean_squared_error: 0.0294 - val_mean_absolute_error: 0.1422
# Epoch 10/40
# 392/392 [==============================] - 0s 429us/step - loss: 0.4299 - mean_squared_error: 0.4299 - mean_absolute_error: 0.4271 - val_loss: 0.0405 - val_mean_squared_error: 0.0405 - val_mean_absolute_error: 0.1838
# Epoch 11/40
# 392/392 [==============================] - 0s 446us/step - loss: 0.4771 - mean_squared_error: 0.4771 - mean_absolute_error: 0.4441 - val_loss: 0.0306 - val_mean_squared_error: 0.0306 - val_mean_absolute_error: 0.1474
# Epoch 12/40
# 392/392 [==============================] - 0s 421us/step - loss: 0.4398 - mean_squared_error: 0.4398 - mean_absolute_error: 0.4093 - val_loss: 0.0281 - val_mean_squared_error: 0.0281 - val_mean_absolute_error: 0.1364
# Epoch 13/40
# 392/392 [==============================] - 0s 429us/step - loss: 0.4636 - mean_squared_error: 0.4636 - mean_absolute_error: 0.4223 - val_loss: 0.0436 - val_mean_squared_error: 0.0436 - val_mean_absolute_error: 0.1935
# Epoch 14/40
# 392/392 [==============================] - 0s 419us/step - loss: 0.4270 - mean_squared_error: 0.4270 - mean_absolute_error: 0.4201 - val_loss: 0.0246 - val_mean_squared_error: 0.0246 - val_mean_absolute_error: 0.1174
# Epoch 15/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.4372 - mean_squared_error: 0.4372 - mean_absolute_error: 0.4148 - val_loss: 0.0420 - val_mean_squared_error: 0.0420 - val_mean_absolute_error: 0.1886
# Epoch 16/40
# 392/392 [==============================] - 0s 425us/step - loss: 0.4095 - mean_squared_error: 0.4095 - mean_absolute_error: 0.4002 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0932
# Epoch 17/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.4736 - mean_squared_error: 0.4736 - mean_absolute_error: 0.4052 - val_loss: 0.0378 - val_mean_squared_error: 0.0378 - val_mean_absolute_error: 0.1754
# Epoch 18/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.4382 - mean_squared_error: 0.4382 - mean_absolute_error: 0.4154 - val_loss: 0.0500 - val_mean_squared_error: 0.0500 - val_mean_absolute_error: 0.2113
# Epoch 19/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.4260 - mean_squared_error: 0.4260 - mean_absolute_error: 0.3930 - val_loss: 0.0353 - val_mean_squared_error: 0.0353 - val_mean_absolute_error: 0.1663
# Epoch 20/40
# 392/392 [==============================] - 0s 441us/step - loss: 0.4330 - mean_squared_error: 0.4330 - mean_absolute_error: 0.3937 - val_loss: 0.0491 - val_mean_squared_error: 0.0491 - val_mean_absolute_error: 0.2094
# Epoch 21/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.4135 - mean_squared_error: 0.4135 - mean_absolute_error: 0.3906 - val_loss: 0.0485 - val_mean_squared_error: 0.0485 - val_mean_absolute_error: 0.2080
# Epoch 22/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.4495 - mean_squared_error: 0.4495 - mean_absolute_error: 0.4109 - val_loss: 0.0423 - val_mean_squared_error: 0.0423 - val_mean_absolute_error: 0.1905
# Epoch 23/40
# 392/392 [==============================] - 0s 433us/step - loss: 0.3704 - mean_squared_error: 0.3704 - mean_absolute_error: 0.3634 - val_loss: 0.0442 - val_mean_squared_error: 0.0442 - val_mean_absolute_error: 0.1964
# Epoch 24/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.3909 - mean_squared_error: 0.3909 - mean_absolute_error: 0.3971 - val_loss: 0.0537 - val_mean_squared_error: 0.0537 - val_mean_absolute_error: 0.2220
# Epoch 25/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.4183 - mean_squared_error: 0.4183 - mean_absolute_error: 0.3789 - val_loss: 0.0507 - val_mean_squared_error: 0.0507 - val_mean_absolute_error: 0.2145
# Epoch 26/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.3827 - mean_squared_error: 0.3827 - mean_absolute_error: 0.3704 - val_loss: 0.0316 - val_mean_squared_error: 0.0316 - val_mean_absolute_error: 0.1545
# Epoch 27/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.3914 - mean_squared_error: 0.3914 - mean_absolute_error: 0.3790 - val_loss: 0.0375 - val_mean_squared_error: 0.0375 - val_mean_absolute_error: 0.1753
# Epoch 28/40
# 392/392 [==============================] - 0s 426us/step - loss: 0.3896 - mean_squared_error: 0.3896 - mean_absolute_error: 0.3986 - val_loss: 0.0258 - val_mean_squared_error: 0.0258 - val_mean_absolute_error: 0.1281
# Epoch 29/40
# 392/392 [==============================] - 0s 429us/step - loss: 0.4029 - mean_squared_error: 0.4029 - mean_absolute_error: 0.3756 - val_loss: 0.0303 - val_mean_squared_error: 0.0303 - val_mean_absolute_error: 0.1489
# Epoch 30/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.4043 - mean_squared_error: 0.4043 - mean_absolute_error: 0.4181 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - val_mean_absolute_error: 0.1403
# Epoch 31/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.4171 - mean_squared_error: 0.4171 - mean_absolute_error: 0.3809 - val_loss: 0.0365 - val_mean_squared_error: 0.0365 - val_mean_absolute_error: 0.1715
# Epoch 32/40
# 392/392 [==============================] - 0s 456us/step - loss: 0.3813 - mean_squared_error: 0.3813 - mean_absolute_error: 0.3829 - val_loss: 0.0461 - val_mean_squared_error: 0.0461 - val_mean_absolute_error: 0.2011
# Epoch 33/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.3771 - mean_squared_error: 0.3771 - mean_absolute_error: 0.3623 - val_loss: 0.0367 - val_mean_squared_error: 0.0367 - val_mean_absolute_error: 0.1681
# Epoch 34/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.3303 - mean_squared_error: 0.3303 - mean_absolute_error: 0.3425 - val_loss: 0.0387 - val_mean_squared_error: 0.0387 - val_mean_absolute_error: 0.1681
# Epoch 35/40
# 392/392 [==============================] - 0s 427us/step - loss: 0.3234 - mean_squared_error: 0.3234 - mean_absolute_error: 0.3464 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - val_mean_absolute_error: 0.1109
# Epoch 36/40
# 392/392 [==============================] - 0s 423us/step - loss: 0.3501 - mean_squared_error: 0.3501 - mean_absolute_error: 0.3542 - val_loss: 0.0291 - val_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.1267
# Epoch 37/40
# 392/392 [==============================] - 0s 431us/step - loss: 0.3689 - mean_squared_error: 0.3689 - mean_absolute_error: 0.3674 - val_loss: 0.0768 - val_mean_squared_error: 0.0768 - val_mean_absolute_error: 0.2574
# Epoch 38/40
# 392/392 [==============================] - 0s 418us/step - loss: 0.3610 - mean_squared_error: 0.3610 - mean_absolute_error: 0.3813 - val_loss: 0.0260 - val_mean_squared_error: 0.0260 - val_mean_absolute_error: 0.1086
# Epoch 39/40
# 392/392 [==============================] - 0s 424us/step - loss: 0.3426 - mean_squared_error: 0.3426 - mean_absolute_error: 0.3775 - val_loss: 0.0496 - val_mean_squared_error: 0.0496 - val_mean_absolute_error: 0.1911
# Epoch 40/40
# 392/392 [==============================] - 0s 428us/step - loss: 0.3407 - mean_squared_error: 0.3407 - mean_absolute_error: 0.3657 - val_loss: 0.0715 - val_mean_squared_error: 0.0715 - val_mean_absolute_error: 0.2334
# EndTime : 2020-09-17 12:31:00.544437
# PHA-665752’s final rmse value is = 0.267395
# PHA-665752 R-squared value is = -2.595168
# Lapatinib_//n
# train_X shape: (393, 18988, 1)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-17 12:31:01.009989
# StartTime : 2020-09-17 12:31:01.186671
# Train on 393 samples, validate on 98 samples
# Epoch 1/40
# 393/393 [==============================] - 1s 3ms/step - loss: 3.5354 - mean_squared_error: 3.5354 - mean_absolute_error: 1.8192 - val_loss: 2.8917 - val_mean_squared_error: 2.8917 - val_mean_absolute_error: 1.6463
# Epoch 2/40
# 393/393 [==============================] - 0s 450us/step - loss: 2.5240 - mean_squared_error: 2.5240 - mean_absolute_error: 1.5231 - val_loss: 1.2693 - val_mean_squared_error: 1.2693 - val_mean_absolute_error: 1.0961
# Epoch 3/40
# 393/393 [==============================] - 0s 447us/step - loss: 1.3471 - mean_squared_error: 1.3471 - mean_absolute_error: 1.0216 - val_loss: 0.3315 - val_mean_squared_error: 0.3315 - val_mean_absolute_error: 0.4940
# Epoch 4/40
# 393/393 [==============================] - 0s 418us/step - loss: 0.9451 - mean_squared_error: 0.9451 - mean_absolute_error: 0.6861 - val_loss: 0.3170 - val_mean_squared_error: 0.3170 - val_mean_absolute_error: 0.2163
# Epoch 5/40
# 393/393 [==============================] - 0s 420us/step - loss: 1.1151 - mean_squared_error: 1.1151 - mean_absolute_error: 0.7191 - val_loss: 0.2753 - val_mean_squared_error: 0.2753 - val_mean_absolute_error: 0.3415
# Epoch 6/40
# 393/393 [==============================] - 0s 425us/step - loss: 0.9216 - mean_squared_error: 0.9216 - mean_absolute_error: 0.6852 - val_loss: 0.3346 - val_mean_squared_error: 0.3346 - val_mean_absolute_error: 0.4997
# Epoch 7/40
# 393/393 [==============================] - 0s 415us/step - loss: 0.9050 - mean_squared_error: 0.9050 - mean_absolute_error: 0.7047 - val_loss: 0.2948 - val_mean_squared_error: 0.2948 - val_mean_absolute_error: 0.4262
# Epoch 8/40
# 393/393 [==============================] - 0s 427us/step - loss: 0.8450 - mean_squared_error: 0.8450 - mean_absolute_error: 0.6637 - val_loss: 0.2756 - val_mean_squared_error: 0.2756 - val_mean_absolute_error: 0.3095
# Epoch 9/40
# 393/393 [==============================] - 0s 422us/step - loss: 0.9615 - mean_squared_error: 0.9615 - mean_absolute_error: 0.6597 - val_loss: 0.2794 - val_mean_squared_error: 0.2794 - val_mean_absolute_error: 0.3792
# Epoch 10/40
# 393/393 [==============================] - 0s 420us/step - loss: 0.9130 - mean_squared_error: 0.9130 - mean_absolute_error: 0.6865 - val_loss: 0.3056 - val_mean_squared_error: 0.3056 - val_mean_absolute_error: 0.4531
# Epoch 11/40
# 393/393 [==============================] - 0s 422us/step - loss: 0.8438 - mean_squared_error: 0.8438 - mean_absolute_error: 0.6767 - val_loss: 0.2796 - val_mean_squared_error: 0.2796 - val_mean_absolute_error: 0.3882
# Epoch 12/40
# 393/393 [==============================] - 0s 425us/step - loss: 0.8274 - mean_squared_error: 0.8274 - mean_absolute_error: 0.6346 - val_loss: 0.2718 - val_mean_squared_error: 0.2718 - val_mean_absolute_error: 0.3051
# Epoch 13/40
# 393/393 [==============================] - 0s 417us/step - loss: 0.8924 - mean_squared_error: 0.8924 - mean_absolute_error: 0.6534 - val_loss: 0.3123 - val_mean_squared_error: 0.3123 - val_mean_absolute_error: 0.4685
# Epoch 14/40
# 393/393 [==============================] - 0s 425us/step - loss: 0.8225 - mean_squared_error: 0.8225 - mean_absolute_error: 0.6604 - val_loss: 0.2720 - val_mean_squared_error: 0.2720 - val_mean_absolute_error: 0.3657
# Epoch 15/40
# 393/393 [==============================] - 0s 425us/step - loss: 0.7692 - mean_squared_error: 0.7692 - mean_absolute_error: 0.6006 - val_loss: 0.2678 - val_mean_squared_error: 0.2678 - val_mean_absolute_error: 0.3196
# Epoch 16/40
# 393/393 [==============================] - 0s 420us/step - loss: 0.8336 - mean_squared_error: 0.8336 - mean_absolute_error: 0.6292 - val_loss: 0.3087 - val_mean_squared_error: 0.3087 - val_mean_absolute_error: 0.4635
# Epoch 17/40
# 393/393 [==============================] - 0s 429us/step - loss: 0.7831 - mean_squared_error: 0.7831 - mean_absolute_error: 0.6388 - val_loss: 0.2720 - val_mean_squared_error: 0.2720 - val_mean_absolute_error: 0.3762
# Epoch 18/40
# 393/393 [==============================] - 0s 430us/step - loss: 0.8567 - mean_squared_error: 0.8567 - mean_absolute_error: 0.6519 - val_loss: 0.2767 - val_mean_squared_error: 0.2767 - val_mean_absolute_error: 0.3906
# Epoch 19/40
# 393/393 [==============================] - 0s 420us/step - loss: 0.7710 - mean_squared_error: 0.7710 - mean_absolute_error: 0.6123 - val_loss: 0.2918 - val_mean_squared_error: 0.2918 - val_mean_absolute_error: 0.4202
# Epoch 20/40
# 393/393 [==============================] - 0s 430us/step - loss: 0.7198 - mean_squared_error: 0.7198 - mean_absolute_error: 0.6080 - val_loss: 0.2762 - val_mean_squared_error: 0.2762 - val_mean_absolute_error: 0.3572
# Epoch 21/40
# 393/393 [==============================] - 0s 435us/step - loss: 0.7067 - mean_squared_error: 0.7067 - mean_absolute_error: 0.5884 - val_loss: 0.2949 - val_mean_squared_error: 0.2949 - val_mean_absolute_error: 0.3824
# Epoch 22/40
# 393/393 [==============================] - 0s 447us/step - loss: 0.7497 - mean_squared_error: 0.7497 - mean_absolute_error: 0.6171 - val_loss: 0.2922 - val_mean_squared_error: 0.2922 - val_mean_absolute_error: 0.3428
# Epoch 23/40
# 393/393 [==============================] - 0s 422us/step - loss: 0.6597 - mean_squared_error: 0.6597 - mean_absolute_error: 0.6026 - val_loss: 0.3043 - val_mean_squared_error: 0.3043 - val_mean_absolute_error: 0.3441
# Epoch 24/40
# 393/393 [==============================] - 0s 427us/step - loss: 0.6822 - mean_squared_error: 0.6822 - mean_absolute_error: 0.5933 - val_loss: 0.3997 - val_mean_squared_error: 0.3997 - val_mean_absolute_error: 0.4713
# Epoch 25/40
# 393/393 [==============================] - 0s 422us/step - loss: 0.6721 - mean_squared_error: 0.6721 - mean_absolute_error: 0.5991 - val_loss: 0.3036 - val_mean_squared_error: 0.3036 - val_mean_absolute_error: 0.3335
# Epoch 26/40
# 393/393 [==============================] - 0s 427us/step - loss: 0.6313 - mean_squared_error: 0.6313 - mean_absolute_error: 0.6012 - val_loss: 0.3161 - val_mean_squared_error: 0.3161 - val_mean_absolute_error: 0.3763
# Epoch 27/40
# 393/393 [==============================] - 0s 420us/step - loss: 0.6235 - mean_squared_error: 0.6235 - mean_absolute_error: 0.5900 - val_loss: 0.3041 - val_mean_squared_error: 0.3041 - val_mean_absolute_error: 0.3535
# Epoch 28/40
# 393/393 [==============================] - 0s 425us/step - loss: 0.5843 - mean_squared_error: 0.5843 - mean_absolute_error: 0.5845 - val_loss: 0.3093 - val_mean_squared_error: 0.3093 - val_mean_absolute_error: 0.3332
# Epoch 29/40
# 393/393 [==============================] - 0s 432us/step - loss: 0.5541 - mean_squared_error: 0.5541 - mean_absolute_error: 0.5444 - val_loss: 0.2991 - val_mean_squared_error: 0.2991 - val_mean_absolute_error: 0.3404
# Epoch 30/40
# 393/393 [==============================] - 0s 427us/step - loss: 0.5510 - mean_squared_error: 0.5510 - mean_absolute_error: 0.5584 - val_loss: 0.3526 - val_mean_squared_error: 0.3526 - val_mean_absolute_error: 0.4119
# Epoch 31/40
# 393/393 [==============================] - 0s 425us/step - loss: 0.4245 - mean_squared_error: 0.4245 - mean_absolute_error: 0.4846 - val_loss: 0.2910 - val_mean_squared_error: 0.2910 - val_mean_absolute_error: 0.3407
# Epoch 32/40
# 393/393 [==============================] - 0s 436us/step - loss: 0.4665 - mean_squared_error: 0.4665 - mean_absolute_error: 0.5240 - val_loss: 0.3094 - val_mean_squared_error: 0.3094 - val_mean_absolute_error: 0.3411
# Epoch 33/40
# 393/393 [==============================] - 0s 430us/step - loss: 0.4310 - mean_squared_error: 0.4310 - mean_absolute_error: 0.5005 - val_loss: 0.2879 - val_mean_squared_error: 0.2879 - val_mean_absolute_error: 0.3430
# Epoch 34/40
# 393/393 [==============================] - 0s 422us/step - loss: 0.3905 - mean_squared_error: 0.3905 - mean_absolute_error: 0.4831 - val_loss: 0.2948 - val_mean_squared_error: 0.2948 - val_mean_absolute_error: 0.3438
# ...
# Epoch 13/40
# 392/392 [==============================] - 0s 455us/step - loss: 0.6539 - mean_squared_error: 0.6539 - mean_absolute_error: 0.5352 - val_loss: 0.5468 - val_mean_squared_error: 0.5468 - val_mean_absolute_error: 0.4683
# Epoch 14/40
# 392/392 [==============================] - 0s 469us/step - loss: 0.5976 - mean_squared_error: 0.5976 - mean_absolute_error: 0.5377 - val_loss: 0.5414 - val_mean_squared_error: 0.5414 - val_mean_absolute_error: 0.4587
# Epoch 15/40
# 392/392 [==============================] - 0s 457us/step - loss: 0.6075 - mean_squared_error: 0.6075 - mean_absolute_error: 0.5355 - val_loss: 0.5353 - val_mean_squared_error: 0.5353 - val_mean_absolute_error: 0.4255
# Epoch 16/40
# 392/392 [==============================] - 0s 454us/step - loss: 0.6043 - mean_squared_error: 0.6043 - mean_absolute_error: 0.5106 - val_loss: 0.5324 - val_mean_squared_error: 0.5324 - val_mean_absolute_error: 0.4559
# Epoch 17/40
# 392/392 [==============================] - 0s 452us/step - loss: 0.6464 - mean_squared_error: 0.6464 - mean_absolute_error: 0.5492 - val_loss: 0.5269 - val_mean_squared_error: 0.5269 - val_mean_absolute_error: 0.4574
# Epoch 18/40
# 392/392 [==============================] - 0s 448us/step - loss: 0.6379 - mean_squared_error: 0.6379 - mean_absolute_error: 0.5491 - val_loss: 0.5193 - val_mean_squared_error: 0.5193 - val_mean_absolute_error: 0.4165
# Epoch 19/40
# 392/392 [==============================] - 0s 446us/step - loss: 0.5275 - mean_squared_error: 0.5275 - mean_absolute_error: 0.4922 - val_loss: 0.5134 - val_mean_squared_error: 0.5134 - val_mean_absolute_error: 0.4310
# Epoch 20/40
# 392/392 [==============================] - 0s 456us/step - loss: 0.5925 - mean_squared_error: 0.5925 - mean_absolute_error: 0.5432 - val_loss: 0.5058 - val_mean_squared_error: 0.5058 - val_mean_absolute_error: 0.4177
# Epoch 21/40
# 392/392 [==============================] - 0s 471us/step - loss: 0.6439 - mean_squared_error: 0.6439 - mean_absolute_error: 0.5291 - val_loss: 0.4997 - val_mean_squared_error: 0.4997 - val_mean_absolute_error: 0.3998
# Epoch 22/40
# 392/392 [==============================] - 0s 453us/step - loss: 0.5806 - mean_squared_error: 0.5806 - mean_absolute_error: 0.5479 - val_loss: 0.5008 - val_mean_squared_error: 0.5008 - val_mean_absolute_error: 0.4632
# Epoch 23/40
# 392/392 [==============================] - 0s 461us/step - loss: 0.5964 - mean_squared_error: 0.5964 - mean_absolute_error: 0.5375 - val_loss: 0.4908 - val_mean_squared_error: 0.4908 - val_mean_absolute_error: 0.3676
# Epoch 24/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.5564 - mean_squared_error: 0.5564 - mean_absolute_error: 0.5223 - val_loss: 0.4797 - val_mean_squared_error: 0.4797 - val_mean_absolute_error: 0.4113
# Epoch 25/40
# 392/392 [==============================] - 0s 466us/step - loss: 0.5681 - mean_squared_error: 0.5681 - mean_absolute_error: 0.5469 - val_loss: 0.4753 - val_mean_squared_error: 0.4753 - val_mean_absolute_error: 0.3674
# Epoch 26/40
# 392/392 [==============================] - 0s 461us/step - loss: 0.5299 - mean_squared_error: 0.5299 - mean_absolute_error: 0.5287 - val_loss: 0.4747 - val_mean_squared_error: 0.4747 - val_mean_absolute_error: 0.3648
# Epoch 27/40
# 392/392 [==============================] - 0s 444us/step - loss: 0.5178 - mean_squared_error: 0.5178 - mean_absolute_error: 0.5012 - val_loss: 0.4833 - val_mean_squared_error: 0.4833 - val_mean_absolute_error: 0.4556
# Epoch 28/40
# 392/392 [==============================] - 0s 449us/step - loss: 0.5377 - mean_squared_error: 0.5377 - mean_absolute_error: 0.5455 - val_loss: 0.4987 - val_mean_squared_error: 0.4987 - val_mean_absolute_error: 0.3364
# Epoch 29/40
# 392/392 [==============================] - 0s 458us/step - loss: 0.5305 - mean_squared_error: 0.5305 - mean_absolute_error: 0.5231 - val_loss: 0.4875 - val_mean_squared_error: 0.4875 - val_mean_absolute_error: 0.4831
# Epoch 30/40
# 392/392 [==============================] - 0s 446us/step - loss: 0.5128 - mean_squared_error: 0.5128 - mean_absolute_error: 0.5204 - val_loss: 0.4848 - val_mean_squared_error: 0.4848 - val_mean_absolute_error: 0.3409
# Epoch 31/40
# 392/392 [==============================] - 0s 446us/step - loss: 0.4910 - mean_squared_error: 0.4910 - mean_absolute_error: 0.5181 - val_loss: 0.4678 - val_mean_squared_error: 0.4678 - val_mean_absolute_error: 0.3864
# Epoch 32/40
# 392/392 [==============================] - 0s 458us/step - loss: 0.4601 - mean_squared_error: 0.4601 - mean_absolute_error: 0.4859 - val_loss: 0.5523 - val_mean_squared_error: 0.5523 - val_mean_absolute_error: 0.5647
# Epoch 33/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.4558 - mean_squared_error: 0.4558 - mean_absolute_error: 0.5167 - val_loss: 0.5070 - val_mean_squared_error: 0.5070 - val_mean_absolute_error: 0.3538
# Epoch 34/40
# 392/392 [==============================] - 0s 453us/step - loss: 0.3844 - mean_squared_error: 0.3844 - mean_absolute_error: 0.4568 - val_loss: 0.4763 - val_mean_squared_error: 0.4763 - val_mean_absolute_error: 0.4297
# Epoch 35/40
# 392/392 [==============================] - 0s 458us/step - loss: 0.4322 - mean_squared_error: 0.4322 - mean_absolute_error: 0.4818 - val_loss: 0.4749 - val_mean_squared_error: 0.4749 - val_mean_absolute_error: 0.4092
# Epoch 36/40
# 392/392 [==============================] - 0s 448us/step - loss: 0.3851 - mean_squared_error: 0.3851 - mean_absolute_error: 0.4601 - val_loss: 0.4741 - val_mean_squared_error: 0.4741 - val_mean_absolute_error: 0.3989
# Epoch 37/40
# 392/392 [==============================] - 0s 453us/step - loss: 0.3774 - mean_squared_error: 0.3774 - mean_absolute_error: 0.4669 - val_loss: 0.4964 - val_mean_squared_error: 0.4964 - val_mean_absolute_error: 0.3609
# Epoch 38/40
# 392/392 [==============================] - 0s 452us/step - loss: 0.3630 - mean_squared_error: 0.3630 - mean_absolute_error: 0.4534 - val_loss: 0.4933 - val_mean_squared_error: 0.4933 - val_mean_absolute_error: 0.3509
# Epoch 39/40
# 392/392 [==============================] - 0s 448us/step - loss: 0.3278 - mean_squared_error: 0.3278 - mean_absolute_error: 0.4310 - val_loss: 0.4775 - val_mean_squared_error: 0.4775 - val_mean_absolute_error: 0.3885
# Epoch 40/40
# 392/392 [==============================] - 0s 455us/step - loss: 0.3497 - mean_squared_error: 0.3497 - mean_absolute_error: 0.4488 - val_loss: 0.4957 - val_mean_squared_error: 0.4957 - val_mean_absolute_error: 0.3631
# EndTime : 2020-09-17 12:34:10.163662
# Erlotinib’s final rmse value is = 0.704041
# Erlotinib R-squared value is = 0.109959
# AZD6244_//n
# train_X shape: (392, 18988, 1)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-17 12:34:11.291921
# StartTime : 2020-09-17 12:34:11.452930
# Train on 392 samples, validate on 98 samples
# Epoch 1/40
# 392/392 [==============================] - 3s 7ms/step - loss: 3.9653 - mean_squared_error: 3.9653 - mean_absolute_error: 1.8983 - val_loss: 3.2224 - val_mean_squared_error: 3.2224 - val_mean_absolute_error: 1.6831
# Epoch 2/40
# 392/392 [==============================] - 0s 500us/step - loss: 3.4428 - mean_squared_error: 3.4428 - mean_absolute_error: 1.7472 - val_loss: 2.3369 - val_mean_squared_error: 2.3369 - val_mean_absolute_error: 1.4042
# Epoch 3/40
# 392/392 [==============================] - 0s 468us/step - loss: 2.7200 - mean_squared_error: 2.7200 - mean_absolute_error: 1.4848 - val_loss: 1.7384 - val_mean_squared_error: 1.7384 - val_mean_absolute_error: 1.1015
# Epoch 4/40
# 392/392 [==============================] - 0s 451us/step - loss: 2.6023 - mean_squared_error: 2.6023 - mean_absolute_error: 1.2822 - val_loss: 1.6432 - val_mean_squared_error: 1.6432 - val_mean_absolute_error: 0.9302
# Epoch 5/40
# 392/392 [==============================] - 0s 449us/step - loss: 2.5792 - mean_squared_error: 2.5792 - mean_absolute_error: 1.1839 - val_loss: 1.6446 - val_mean_squared_error: 1.6446 - val_mean_absolute_error: 0.9074
# Epoch 6/40
# 392/392 [==============================] - 0s 446us/step - loss: 2.5617 - mean_squared_error: 2.5617 - mean_absolute_error: 1.2114 - val_loss: 1.6479 - val_mean_squared_error: 1.6479 - val_mean_absolute_error: 0.9846
# Epoch 7/40
# 392/392 [==============================] - 0s 445us/step - loss: 2.3931 - mean_squared_error: 2.3931 - mean_absolute_error: 1.2201 - val_loss: 1.6390 - val_mean_squared_error: 1.6390 - val_mean_absolute_error: 0.9639
# Epoch 8/40
# 392/392 [==============================] - 0s 447us/step - loss: 2.3944 - mean_squared_error: 2.3944 - mean_absolute_error: 1.1725 - val_loss: 1.6318 - val_mean_squared_error: 1.6318 - val_mean_absolute_error: 0.9396
# Epoch 9/40
# 392/392 [==============================] - 0s 447us/step - loss: 2.4561 - mean_squared_error: 2.4561 - mean_absolute_error: 1.2066 - val_loss: 1.6307 - val_mean_squared_error: 1.6307 - val_mean_absolute_error: 0.9730
# Epoch 10/40
# 392/392 [==============================] - 0s 447us/step - loss: 2.3963 - mean_squared_error: 2.3963 - mean_absolute_error: 1.1990 - val_loss: 1.6105 - val_mean_squared_error: 1.6105 - val_mean_absolute_error: 0.9592
# Epoch 11/40
# 392/392 [==============================] - 0s 448us/step - loss: 2.4135 - mean_squared_error: 2.4135 - mean_absolute_error: 1.2450 - val_loss: 1.6286 - val_mean_squared_error: 1.6286 - val_mean_absolute_error: 1.0327
# Epoch 12/40
# 392/392 [==============================] - 0s 456us/step - loss: 2.2629 - mean_squared_error: 2.2629 - mean_absolute_error: 1.1750 - val_loss: 1.5473 - val_mean_squared_error: 1.5473 - val_mean_absolute_error: 0.8730
# Epoch 13/40
# 392/392 [==============================] - 0s 479us/step - loss: 2.3473 - mean_squared_error: 2.3473 - mean_absolute_error: 1.1478 - val_loss: 1.5369 - val_mean_squared_error: 1.5369 - val_mean_absolute_error: 0.9986
# Epoch 14/40
# 392/392 [==============================] - 0s 451us/step - loss: 2.1139 - mean_squared_error: 2.1139 - mean_absolute_error: 1.1254 - val_loss: 1.4356 - val_mean_squared_error: 1.4356 - val_mean_absolute_error: 0.9229
# Epoch 15/40
# 392/392 [==============================] - 0s 468us/step - loss: 2.0746 - mean_squared_error: 2.0746 - mean_absolute_error: 1.1046 - val_loss: 1.4301 - val_mean_squared_error: 1.4301 - val_mean_absolute_error: 0.9740
# Epoch 16/40
# 392/392 [==============================] - 0s 451us/step - loss: 1.8102 - mean_squared_error: 1.8102 - mean_absolute_error: 1.0264 - val_loss: 1.2825 - val_mean_squared_error: 1.2825 - val_mean_absolute_error: 0.7388
# Epoch 17/40
# 392/392 [==============================] - 0s 448us/step - loss: 1.7300 - mean_squared_error: 1.7300 - mean_absolute_error: 0.9787 - val_loss: 1.2674 - val_mean_squared_error: 1.2674 - val_mean_absolute_error: 0.8413
# Epoch 18/40
# 392/392 [==============================] - 0s 455us/step - loss: 1.6286 - mean_squared_error: 1.6286 - mean_absolute_error: 0.9026 - val_loss: 1.4106 - val_mean_squared_error: 1.4106 - val_mean_absolute_error: 0.9567
# Epoch 19/40
# 392/392 [==============================] - 0s 456us/step - loss: 1.4761 - mean_squared_error: 1.4761 - mean_absolute_error: 0.8780 - val_loss: 1.1976 - val_mean_squared_error: 1.1976 - val_mean_absolute_error: 0.6626
# Epoch 20/40
# 392/392 [==============================] - 0s 448us/step - loss: 1.3279 - mean_squared_error: 1.3279 - mean_absolute_error: 0.8427 - val_loss: 1.3379 - val_mean_squared_error: 1.3379 - val_mean_absolute_error: 0.8771
# Epoch 21/40
# 392/392 [==============================] - 0s 445us/step - loss: 1.2428 - mean_squared_error: 1.2428 - mean_absolute_error: 0.8339 - val_loss: 1.2980 - val_mean_squared_error: 1.2980 - val_mean_absolute_error: 0.7365
# Epoch 22/40
# 392/392 [==============================] - 0s 449us/step - loss: 1.0720 - mean_squared_error: 1.0720 - mean_absolute_error: 0.7614 - val_loss: 1.2645 - val_mean_squared_error: 1.2645 - val_mean_absolute_error: 0.6420
# Epoch 23/40
# 392/392 [==============================] - 0s 444us/step - loss: 0.9518 - mean_squared_error: 0.9518 - mean_absolute_error: 0.7198 - val_loss: 1.3243 - val_mean_squared_error: 1.3243 - val_mean_absolute_error: 0.6061
# Epoch 24/40
# 392/392 [==============================] - 0s 443us/step - loss: 0.8999 - mean_squared_error: 0.8999 - mean_absolute_error: 0.7071 - val_loss: 1.3612 - val_mean_squared_error: 1.3612 - val_mean_absolute_error: 0.6118
# Epoch 25/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.7881 - mean_squared_error: 0.7881 - mean_absolute_error: 0.6428 - val_loss: 1.3456 - val_mean_squared_error: 1.3456 - val_mean_absolute_error: 0.5871
# Epoch 26/40
# 392/392 [==============================] - 0s 461us/step - loss: 0.8019 - mean_squared_error: 0.8019 - mean_absolute_error: 0.6774 - val_loss: 1.5080 - val_mean_squared_error: 1.5080 - val_mean_absolute_error: 0.6365
# Epoch 27/40
# 392/392 [==============================] - 0s 443us/step - loss: 0.7537 - mean_squared_error: 0.7537 - mean_absolute_error: 0.6528 - val_loss: 1.3374 - val_mean_squared_error: 1.3374 - val_mean_absolute_error: 0.5823
# Epoch 28/40
# 392/392 [==============================] - 0s 449us/step - loss: 0.6010 - mean_squared_error: 0.6010 - mean_absolute_error: 0.5777 - val_loss: 1.3839 - val_mean_squared_error: 1.3839 - val_mean_absolute_error: 0.6368
# Epoch 29/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.5004 - mean_squared_error: 0.5004 - mean_absolute_error: 0.5318 - val_loss: 1.4654 - val_mean_squared_error: 1.4654 - val_mean_absolute_error: 0.6713
# Epoch 30/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.4566 - mean_squared_error: 0.4566 - mean_absolute_error: 0.5022 - val_loss: 1.3651 - val_mean_squared_error: 1.3651 - val_mean_absolute_error: 0.6739
# Epoch 31/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.4413 - mean_squared_error: 0.4413 - mean_absolute_error: 0.5087 - val_loss: 1.3841 - val_mean_squared_error: 1.3841 - val_mean_absolute_error: 0.6278
# Epoch 32/40
# 392/392 [==============================] - 0s 453us/step - loss: 0.4080 - mean_squared_error: 0.4080 - mean_absolute_error: 0.4885 - val_loss: 1.4123 - val_mean_squared_error: 1.4123 - val_mean_absolute_error: 0.6847
# Epoch 33/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.3486 - mean_squared_error: 0.3486 - mean_absolute_error: 0.4526 - val_loss: 1.5164 - val_mean_squared_error: 1.5164 - val_mean_absolute_error: 0.7418
# Epoch 34/40
# 392/392 [==============================] - 0s 454us/step - loss: 0.4652 - mean_squared_error: 0.4652 - mean_absolute_error: 0.5105 - val_loss: 1.4553 - val_mean_squared_error: 1.4553 - val_mean_absolute_error: 0.7054
# Epoch 35/40
# 392/392 [==============================] - 0s 457us/step - loss: 0.4410 - mean_squared_error: 0.4410 - mean_absolute_error: 0.5114 - val_loss: 1.6387 - val_mean_squared_error: 1.6387 - val_mean_absolute_error: 0.7872
# Epoch 36/40
# 392/392 [==============================] - 0s 449us/step - loss: 0.3744 - mean_squared_error: 0.3744 - mean_absolute_error: 0.4747 - val_loss: 1.3939 - val_mean_squared_error: 1.3939 - val_mean_absolute_error: 0.6402
# Epoch 37/40
# 392/392 [==============================] - 0s 451us/step - loss: 0.4054 - mean_squared_error: 0.4054 - mean_absolute_error: 0.4913 - val_loss: 1.3623 - val_mean_squared_error: 1.3623 - val_mean_absolute_error: 0.6344
# Epoch 38/40
# 392/392 [==============================] - 0s 441us/step - loss: 0.3992 - mean_squared_error: 0.3992 - mean_absolute_error: 0.4781 - val_loss: 1.5309 - val_mean_squared_error: 1.5309 - val_mean_absolute_error: 0.6939
# Epoch 39/40
# 392/392 [==============================] - 0s 446us/step - loss: 0.3526 - mean_squared_error: 0.3526 - mean_absolute_error: 0.4578 - val_loss: 1.4641 - val_mean_squared_error: 1.4641 - val_mean_absolute_error: 0.6619
# Epoch 40/40
# 392/392 [==============================] - 0s 438us/step - loss: 0.3807 - mean_squared_error: 0.3807 - mean_absolute_error: 0.4682 - val_loss: 1.4631 - val_mean_squared_error: 1.4631 - val_mean_absolute_error: 0.6700
# EndTime : 2020-09-17 12:34:21.764867
# AZD6244’s final rmse value is = 1.209575
# AZD6244 R-squared value is = 0.114043

# %%
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         AEW541  0.781426  0.013181
# 1      Nilotinib  0.922080  0.203403
# 2         17-AAG  1.079519  0.103060
# 3     PHA-665752  0.267395 -2.595168
# 4      Lapatinib  0.503474  0.083189
# 5       Nutlin-3  0.149605 -2.053318
# 6        AZD0530  0.879391  0.172883
# 7      PF2341066  0.773394  0.129052
# 8       L-685458  0.674815  0.009213
# 9        ZD-6474  0.744313 -0.309168
# 10  Panobinostat  0.706458  0.421950
# 11     Sorafenib  0.576132  0.019071
# 12    Irinotecan  1.085136  0.325336
# 13     Topotecan  1.208131  0.337959
# 14        LBW242  0.361326 -0.244694
# 15    PD-0325901  1.924270  0.268004
# 16    PD-0332991  0.601765  0.133458
# 17    Paclitaxel  2.032373  0.052967
# 18       PLX4720  0.739385  0.317845
# 19        RAF265  1.068388  0.112544
# 20        TAE684  1.201706  0.138979
# 21        TKI258  0.615749  0.218700
# 22     Erlotinib  0.704041  0.109959
# 23       AZD6244  1.209575  0.114043

# %%
workdir = "E://Ronny_TF//200914_reupload//Result//Scenario8_individual_approach"
result.to_csv(workdir +'//200915_scenario8_CNN_24drugs_metrics.csv', index=False)
