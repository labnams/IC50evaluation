# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import random
from pandas import DataFrame
from datetime import datetime
import keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten, Reshape, Activation
from keras.layers import Conv1D, MaxPooling1D ,AveragePooling1D
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras import backend as K
# from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
#from tensorflow.keras.optimizers import Adam
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario8_MC-9K_single_drug_model_approach

workdir = "path"
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())


# 출처: https://3months.tistory.com/206 [Deep Play]
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17503963642618052028
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 18038862643
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15352722826526874468
# physical_device_desc: "device: 0, name: TITAN RTX, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
file_list = os.listdir(workdir)

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[-1].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list[0:12])
# Out:
# 12

# %%
# In[21]:

num_classes = 1
learning_rate = 0.0002
training_epochs = 40
batch_size = 50
# img_rows, img_cols = 154, 154

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list[0:12])):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//190509_ccle_mut_ic50_aron_%s.npz" % dname) # input file
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.reshape(train_X.shape[0], train_X.shape[1],1)
    test_X = test_X.reshape(test_X.shape[0], test_X.shape[1],1)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-lasso-and-lasso-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    # In[10]:
    with K.tf.device('/GPU:0'):
        inputs = Input(shape=(train_X.shape[1],1),name='inputs')

        x = Conv1D(16, kernel_size=3, strides=2, padding="same")(inputs)
        x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
    #     y = x
        x = Activation('tanh')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)


        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)


        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)


        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=2, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
    #     x = BatchNormalization()(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)


        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=2, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
    #     x = BatchNormalization()(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)


        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

    #     x = AveragePooling1D(pool_size=8)(x)
        x = Flatten()(x)
        x = Dense(units=2048, name='dense1'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout1') (x)
        x = Activation('relu')(x)

    #    x = Reshape((300,1))(x)

    #    x = Conv1D(30, kernel_size=150, strides=1, activation = 'relu')(x)
    #    x = MaxPooling1D(pool_size=2)(x)
    #    x = BatchNormalization()(x)

        x = Dense(units=1024, name='dense5'  ) (x)
        x = BatchNormalization()(x)
        y = x
        x = Dropout(0.1, name='dropout5') (x)
        x = Activation('relu')(x)

        x = Dense(units=512, name='dense6'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout6') (x)
        x = Activation('relu')(x)

        x = Dense(units=1024, name='dense7'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout7') (x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Dense(units=512, name='dense8'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout8') (x)
        x = Activation('relu')(x)

        x = Dense(units=256, name='dense9'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout9') (x)
        x = Activation('relu')(x)

        x = Dense(units=128, name='dense10'  ) (x)
        x = BatchNormalization()(x)
        y = x
        x = Dropout(0.1, name='dropout10') (x)
        x = Activation('relu')(x)


        predictions = Dense(1, activation='linear', name='predictions', kernel_initializer='he_normal')(x)
    #     predictions = Dense(1, activation='linear', name='predictions')(x)



        model = Model(inputs=inputs, outputs=predictions, name='Test_v2_DNN20190327')
        model.compile(loss=keras.losses.mean_squared_error,
                      optimizer=keras.optimizers.Adam(learning_rate),
                      metrics=['mse','mae'])
        EndTime8 = datetime.now()
        print("EndTime :", EndTime8)
    
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    with K.tf.device('/GPU:0'):
        model_train = model.fit(train_X, train_y, batch_size=batch_size,epochs=training_epochs,verbose=1,
                            validation_data=(test_X, test_y))

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = model.predict(test_X)
    predicted_value = predicted_classes
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Result//EC-11K_individual_drugs//191212//ResNet//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='blue')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)

    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.7
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    # status initialize

    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = '0' 

    # out of memory
    import tensorflow as tf
    with tf.Graph().as_default():
      gpu_options = tf.GPUOptions(allow_growth=True)

    workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//MC-9K//Dataset//mut"
workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Result//MC-9K_individual//ResNet"

plt.savefig(workdir +'//191210_MC9K_one_drug_one_model_12drugs_ResNet.png', dpi=400)
workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//MC-9K//Dataset//mut"
# Out:
# 17-AAG_//n
# train_X shape: (301, 21213, 1)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-13 01:29:27.700902
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ronnytf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ronnytf\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# EndTime : 2019-12-13 01:29:30.593902
# StartTime : 2019-12-13 01:29:30.593902
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ronnytf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 301 samples, validate on 76 samples
# Epoch 1/40
# 301/301 [==============================] - 10s 33ms/step - loss: 4.0211 - mean_squared_error: 4.0211 - mean_absolute_error: 1.6654 - val_loss: 10.7460 - val_mean_squared_error: 10.7460 - val_mean_absolute_error: 2.5396
# Epoch 2/40
# 301/301 [==============================] - 1s 2ms/step - loss: 2.5658 - mean_squared_error: 2.5658 - mean_absolute_error: 1.2988 - val_loss: 3.2138 - val_mean_squared_error: 3.2138 - val_mean_absolute_error: 1.4593
# Epoch 3/40
# 301/301 [==============================] - 1s 2ms/step - loss: 2.0574 - mean_squared_error: 2.0574 - mean_absolute_error: 1.1726 - val_loss: 4.5759 - val_mean_squared_error: 4.5759 - val_mean_absolute_error: 1.7429
# Epoch 4/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.6755 - mean_squared_error: 1.6755 - mean_absolute_error: 1.0380 - val_loss: 4.4300 - val_mean_squared_error: 4.4300 - val_mean_absolute_error: 1.7312
# Epoch 5/40
# 301/301 [==============================] - 1s 2ms/step - loss: 1.3121 - mean_squared_error: 1.3121 - mean_absolute_error: 0.8943 - val_loss: 3.9969 - val_mean_squared_error: 3.9969 - val_mean_absolute_error: 1.6101
# Epoch 6/40
# 301/301 [==============================] - 1s 2ms/step - loss: 1.1165 - mean_squared_error: 1.1165 - mean_absolute_error: 0.8366 - val_loss: 4.2879 - val_mean_squared_error: 4.2879 - val_mean_absolute_error: 1.6288
# Epoch 7/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.9441 - mean_squared_error: 0.9441 - mean_absolute_error: 0.7170 - val_loss: 3.4767 - val_mean_squared_error: 3.4767 - val_mean_absolute_error: 1.4447
# Epoch 8/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.8479 - mean_squared_error: 0.8479 - mean_absolute_error: 0.7329 - val_loss: 2.9848 - val_mean_squared_error: 2.9848 - val_mean_absolute_error: 1.3303
# Epoch 9/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.8831 - mean_squared_error: 0.8831 - mean_absolute_error: 0.7167 - val_loss: 2.8709 - val_mean_squared_error: 2.8709 - val_mean_absolute_error: 1.3196
# Epoch 10/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.7811 - mean_squared_error: 0.7811 - mean_absolute_error: 0.6836 - val_loss: 3.3699 - val_mean_squared_error: 3.3699 - val_mean_absolute_error: 1.4306
# Epoch 11/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.7549 - mean_squared_error: 0.7549 - mean_absolute_error: 0.6622 - val_loss: 3.3729 - val_mean_squared_error: 3.3729 - val_mean_absolute_error: 1.4196
# Epoch 12/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.7336 - mean_squared_error: 0.7336 - mean_absolute_error: 0.6481 - val_loss: 3.1846 - val_mean_squared_error: 3.1846 - val_mean_absolute_error: 1.3615
# Epoch 13/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5794 - mean_squared_error: 0.5794 - mean_absolute_error: 0.6030 - val_loss: 3.1454 - val_mean_squared_error: 3.1454 - val_mean_absolute_error: 1.3837
# Epoch 14/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6099 - mean_squared_error: 0.6099 - mean_absolute_error: 0.5834 - val_loss: 3.3762 - val_mean_squared_error: 3.3762 - val_mean_absolute_error: 1.4282
# Epoch 15/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5947 - mean_squared_error: 0.5947 - mean_absolute_error: 0.5702 - val_loss: 3.8758 - val_mean_squared_error: 3.8758 - val_mean_absolute_error: 1.5402
# Epoch 16/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5257 - mean_squared_error: 0.5257 - mean_absolute_error: 0.5519 - val_loss: 4.2438 - val_mean_squared_error: 4.2438 - val_mean_absolute_error: 1.6052
# Epoch 17/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5681 - mean_squared_error: 0.5681 - mean_absolute_error: 0.5947 - val_loss: 3.4345 - val_mean_squared_error: 3.4345 - val_mean_absolute_error: 1.4617
# Epoch 18/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5778 - mean_squared_error: 0.5778 - mean_absolute_error: 0.5962 - val_loss: 2.9827 - val_mean_squared_error: 2.9827 - val_mean_absolute_error: 1.3602
# Epoch 19/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4920 - mean_squared_error: 0.4920 - mean_absolute_error: 0.5588 - val_loss: 2.9155 - val_mean_squared_error: 2.9155 - val_mean_absolute_error: 1.3460
# Epoch 20/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5236 - mean_squared_error: 0.5236 - mean_absolute_error: 0.5433 - val_loss: 2.7609 - val_mean_squared_error: 2.7609 - val_mean_absolute_error: 1.3030
# Epoch 21/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6257 - mean_squared_error: 0.6257 - mean_absolute_error: 0.5997 - val_loss: 2.8121 - val_mean_squared_error: 2.8121 - val_mean_absolute_error: 1.3069
# Epoch 22/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4668 - mean_squared_error: 0.4668 - mean_absolute_error: 0.5563 - val_loss: 3.1155 - val_mean_squared_error: 3.1155 - val_mean_absolute_error: 1.3642
# Epoch 23/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4608 - mean_squared_error: 0.4608 - mean_absolute_error: 0.5010 - val_loss: 3.0639 - val_mean_squared_error: 3.0639 - val_mean_absolute_error: 1.3574
# Epoch 24/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4807 - mean_squared_error: 0.4807 - mean_absolute_error: 0.5340 - val_loss: 2.7279 - val_mean_squared_error: 2.7279 - val_mean_absolute_error: 1.2827
# Epoch 25/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4068 - mean_squared_error: 0.4068 - mean_absolute_error: 0.4913 - val_loss: 2.5989 - val_mean_squared_error: 2.5989 - val_mean_absolute_error: 1.2456
# Epoch 26/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4549 - mean_squared_error: 0.4549 - mean_absolute_error: 0.5226 - val_loss: 2.5671 - val_mean_squared_error: 2.5671 - val_mean_absolute_error: 1.2408
# Epoch 27/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5440 - mean_squared_error: 0.5440 - mean_absolute_error: 0.5566 - val_loss: 2.5243 - val_mean_squared_error: 2.5243 - val_mean_absolute_error: 1.2276
# Epoch 28/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5595 - mean_squared_error: 0.5595 - mean_absolute_error: 0.5383 - val_loss: 2.4533 - val_mean_squared_error: 2.4533 - val_mean_absolute_error: 1.2124
# Epoch 29/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3729 - mean_squared_error: 0.3729 - mean_absolute_error: 0.4600 - val_loss: 2.5407 - val_mean_squared_error: 2.5407 - val_mean_absolute_error: 1.2262
# Epoch 30/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3886 - mean_squared_error: 0.3886 - mean_absolute_error: 0.4628 - val_loss: 2.4013 - val_mean_squared_error: 2.4013 - val_mean_absolute_error: 1.1718
# Epoch 31/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3335 - mean_squared_error: 0.3335 - mean_absolute_error: 0.4423 - val_loss: 2.3964 - val_mean_squared_error: 2.3964 - val_mean_absolute_error: 1.1593
# Epoch 32/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4313 - mean_squared_error: 0.4313 - mean_absolute_error: 0.4927 - val_loss: 2.4237 - val_mean_squared_error: 2.4237 - val_mean_absolute_error: 1.1611
# Epoch 33/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4328 - mean_squared_error: 0.4328 - mean_absolute_error: 0.4910 - val_loss: 2.4534 - val_mean_squared_error: 2.4534 - val_mean_absolute_error: 1.1852
# Epoch 34/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4265 - mean_squared_error: 0.4265 - mean_absolute_error: 0.5022 - val_loss: 2.4843 - val_mean_squared_error: 2.4843 - val_mean_absolute_error: 1.1909
# Epoch 35/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.4127 - mean_squared_error: 0.4127 - mean_absolute_error: 0.4728 - val_loss: 2.4810 - val_mean_squared_error: 2.4810 - val_mean_absolute_error: 1.1881
# Epoch 36/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3659 - mean_squared_error: 0.3659 - mean_absolute_error: 0.4758 - val_loss: 2.5720 - val_mean_squared_error: 2.5720 - val_mean_absolute_error: 1.2147
# Epoch 37/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4629 - mean_squared_error: 0.4629 - mean_absolute_error: 0.5131 - val_loss: 2.5554 - val_mean_squared_error: 2.5554 - val_mean_absolute_error: 1.2050
# Epoch 38/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4267 - mean_squared_error: 0.4267 - mean_absolute_error: 0.4636 - val_loss: 2.6801 - val_mean_squared_error: 2.6801 - val_mean_absolute_error: 1.2383
# Epoch 39/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3892 - mean_squared_error: 0.3892 - mean_absolute_error: 0.4855 - val_loss: 2.6339 - val_mean_squared_error: 2.6339 - val_mean_absolute_error: 1.2294
# Epoch 40/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3672 - mean_squared_error: 0.3672 - mean_absolute_error: 0.4587 - val_loss: 2.4853 - val_mean_squared_error: 2.4853 - val_mean_absolute_error: 1.1905
# EndTime : 2019-12-13 01:30:13.041902
# 17-AAG’s final rmse value is = 1.576468
# 17-AAG R-squared value is = -0.179167
# AEW541_//n
# train_X shape: (302, 21213, 1)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-13 01:30:13.843902
# EndTime : 2019-12-13 01:30:16.930902
# StartTime : 2019-12-13 01:30:16.930902
# Train on 302 samples, validate on 76 samples
# Epoch 1/40
# 302/302 [==============================] - 8s 28ms/step - loss: 3.0469 - mean_squared_error: 3.0469 - mean_absolute_error: 1.5188 - val_loss: 3.4888 - val_mean_squared_error: 3.4888 - val_mean_absolute_error: 1.6621
# Epoch 2/40
# 302/302 [==============================] - 1s 2ms/step - loss: 2.3348 - mean_squared_error: 2.3348 - mean_absolute_error: 1.3379 - val_loss: 3.1289 - val_mean_squared_error: 3.1289 - val_mean_absolute_error: 1.6008
# Epoch 3/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.9901 - mean_squared_error: 1.9901 - mean_absolute_error: 1.2415 - val_loss: 3.2492 - val_mean_squared_error: 3.2492 - val_mean_absolute_error: 1.6588
# Epoch 4/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.7103 - mean_squared_error: 1.7103 - mean_absolute_error: 1.1442 - val_loss: 2.6842 - val_mean_squared_error: 2.6842 - val_mean_absolute_error: 1.4656
# Epoch 5/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.6530 - mean_squared_error: 1.6530 - mean_absolute_error: 1.1044 - val_loss: 2.5238 - val_mean_squared_error: 2.5238 - val_mean_absolute_error: 1.4045
# Epoch 6/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.4760 - mean_squared_error: 1.4760 - mean_absolute_error: 1.0595 - val_loss: 2.7400 - val_mean_squared_error: 2.7400 - val_mean_absolute_error: 1.4827
# Epoch 7/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.2939 - mean_squared_error: 1.2939 - mean_absolute_error: 0.9615 - val_loss: 2.8966 - val_mean_squared_error: 2.8966 - val_mean_absolute_error: 1.5527
# Epoch 8/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.2353 - mean_squared_error: 1.2353 - mean_absolute_error: 0.9161 - val_loss: 2.4163 - val_mean_squared_error: 2.4163 - val_mean_absolute_error: 1.4102
# Epoch 9/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.9571 - mean_squared_error: 0.9571 - mean_absolute_error: 0.8259 - val_loss: 2.4714 - val_mean_squared_error: 2.4714 - val_mean_absolute_error: 1.4151
# Epoch 10/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.8831 - mean_squared_error: 0.8831 - mean_absolute_error: 0.7799 - val_loss: 2.0391 - val_mean_squared_error: 2.0391 - val_mean_absolute_error: 1.2942
# Epoch 11/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.8318 - mean_squared_error: 0.8318 - mean_absolute_error: 0.7477 - val_loss: 1.6605 - val_mean_squared_error: 1.6605 - val_mean_absolute_error: 1.1615
# Epoch 12/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.7957 - mean_squared_error: 0.7957 - mean_absolute_error: 0.7279 - val_loss: 1.5001 - val_mean_squared_error: 1.5001 - val_mean_absolute_error: 1.1040
# Epoch 13/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.9207 - mean_squared_error: 0.9207 - mean_absolute_error: 0.7782 - val_loss: 1.2824 - val_mean_squared_error: 1.2824 - val_mean_absolute_error: 1.0018
# Epoch 14/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.7487 - mean_squared_error: 0.7487 - mean_absolute_error: 0.6821 - val_loss: 1.4676 - val_mean_squared_error: 1.4676 - val_mean_absolute_error: 1.0160
# Epoch 15/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.8002 - mean_squared_error: 0.8002 - mean_absolute_error: 0.7025 - val_loss: 1.9187 - val_mean_squared_error: 1.9187 - val_mean_absolute_error: 1.0703
# Epoch 16/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6218 - mean_squared_error: 0.6218 - mean_absolute_error: 0.6165 - val_loss: 1.3694 - val_mean_squared_error: 1.3694 - val_mean_absolute_error: 0.9805
# Epoch 17/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6666 - mean_squared_error: 0.6666 - mean_absolute_error: 0.6363 - val_loss: 1.1112 - val_mean_squared_error: 1.1112 - val_mean_absolute_error: 0.8986
# Epoch 18/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6850 - mean_squared_error: 0.6850 - mean_absolute_error: 0.6299 - val_loss: 1.1619 - val_mean_squared_error: 1.1619 - val_mean_absolute_error: 0.9256
# Epoch 19/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5915 - mean_squared_error: 0.5915 - mean_absolute_error: 0.6015 - val_loss: 1.1917 - val_mean_squared_error: 1.1917 - val_mean_absolute_error: 0.9270
# Epoch 20/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6382 - mean_squared_error: 0.6382 - mean_absolute_error: 0.6045 - val_loss: 0.9540 - val_mean_squared_error: 0.9540 - val_mean_absolute_error: 0.8310
# Epoch 21/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4887 - mean_squared_error: 0.4887 - mean_absolute_error: 0.5328 - val_loss: 0.8194 - val_mean_squared_error: 0.8194 - val_mean_absolute_error: 0.7764
# Epoch 22/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5227 - mean_squared_error: 0.5227 - mean_absolute_error: 0.5592 - val_loss: 0.7935 - val_mean_squared_error: 0.7935 - val_mean_absolute_error: 0.7729
# Epoch 23/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4175 - mean_squared_error: 0.4175 - mean_absolute_error: 0.5173 - val_loss: 0.7629 - val_mean_squared_error: 0.7629 - val_mean_absolute_error: 0.7548
# Epoch 24/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5018 - mean_squared_error: 0.5018 - mean_absolute_error: 0.5443 - val_loss: 0.8440 - val_mean_squared_error: 0.8440 - val_mean_absolute_error: 0.7840
# Epoch 25/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5080 - mean_squared_error: 0.5080 - mean_absolute_error: 0.5548 - val_loss: 0.8490 - val_mean_squared_error: 0.8490 - val_mean_absolute_error: 0.7816
# Epoch 26/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4432 - mean_squared_error: 0.4432 - mean_absolute_error: 0.5267 - val_loss: 0.8212 - val_mean_squared_error: 0.8212 - val_mean_absolute_error: 0.7720
# Epoch 27/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5392 - mean_squared_error: 0.5392 - mean_absolute_error: 0.5804 - val_loss: 0.7396 - val_mean_squared_error: 0.7396 - val_mean_absolute_error: 0.7148
# Epoch 28/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4484 - mean_squared_error: 0.4484 - mean_absolute_error: 0.5177 - val_loss: 0.7447 - val_mean_squared_error: 0.7447 - val_mean_absolute_error: 0.7297
# Epoch 29/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4622 - mean_squared_error: 0.4622 - mean_absolute_error: 0.5324 - val_loss: 0.8511 - val_mean_squared_error: 0.8511 - val_mean_absolute_error: 0.7788
# Epoch 30/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4587 - mean_squared_error: 0.4587 - mean_absolute_error: 0.5113 - val_loss: 0.8010 - val_mean_squared_error: 0.8010 - val_mean_absolute_error: 0.7268
# Epoch 31/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5270 - mean_squared_error: 0.5270 - mean_absolute_error: 0.5347 - val_loss: 0.7632 - val_mean_squared_error: 0.7632 - val_mean_absolute_error: 0.7082
# Epoch 32/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5097 - mean_squared_error: 0.5097 - mean_absolute_error: 0.5286 - val_loss: 0.7178 - val_mean_squared_error: 0.7178 - val_mean_absolute_error: 0.6833
# Epoch 33/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4615 - mean_squared_error: 0.4615 - mean_absolute_error: 0.5017 - val_loss: 0.7243 - val_mean_squared_error: 0.7243 - val_mean_absolute_error: 0.6842
# Epoch 34/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4031 - mean_squared_error: 0.4031 - mean_absolute_error: 0.4793 - val_loss: 0.7226 - val_mean_squared_error: 0.7226 - val_mean_absolute_error: 0.6810
# Epoch 35/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4068 - mean_squared_error: 0.4068 - mean_absolute_error: 0.4818 - val_loss: 0.7058 - val_mean_squared_error: 0.7058 - val_mean_absolute_error: 0.6892
# Epoch 36/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5149 - mean_squared_error: 0.5149 - mean_absolute_error: 0.5200 - val_loss: 0.6613 - val_mean_squared_error: 0.6613 - val_mean_absolute_error: 0.7190
# Epoch 37/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4167 - mean_squared_error: 0.4167 - mean_absolute_error: 0.4908 - val_loss: 0.7360 - val_mean_squared_error: 0.7360 - val_mean_absolute_error: 0.7644
# Epoch 38/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4181 - mean_squared_error: 0.4181 - mean_absolute_error: 0.5071 - val_loss: 0.7390 - val_mean_squared_error: 0.7390 - val_mean_absolute_error: 0.7466
# Epoch 39/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4356 - mean_squared_error: 0.4356 - mean_absolute_error: 0.5122 - val_loss: 0.8120 - val_mean_squared_error: 0.8120 - val_mean_absolute_error: 0.7619
# Epoch 40/40
# 302/302 [==============================] - 2s 5ms/step - loss: 0.5559 - mean_squared_error: 0.5559 - mean_absolute_error: 0.5820 - val_loss: 0.9148 - val_mean_squared_error: 0.9148 - val_mean_absolute_error: 0.7877
# EndTime : 2019-12-13 01:30:58.637902
# AEW541’s final rmse value is = 0.956474
# AEW541 R-squared value is = -0.701590
# AZD0530_//n
# train_X shape: (302, 21213, 1)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-13 01:31:01.136902
# EndTime : 2019-12-13 01:31:07.630902
# StartTime : 2019-12-13 01:31:07.630902
# Train on 302 samples, validate on 76 samples
# Epoch 1/40
# 302/302 [==============================] - 14s 45ms/step - loss: 2.6299 - mean_squared_error: 2.6299 - mean_absolute_error: 1.3575 - val_loss: 3.3097 - val_mean_squared_error: 3.3097 - val_mean_absolute_error: 1.6159
# Epoch 2/40
# 302/302 [==============================] - 2s 6ms/step - loss: 2.1111 - mean_squared_error: 2.1111 - mean_absolute_error: 1.2483 - val_loss: 3.2473 - val_mean_squared_error: 3.2473 - val_mean_absolute_error: 1.5842
# Epoch 3/40
# 302/302 [==============================] - 2s 6ms/step - loss: 1.6300 - mean_squared_error: 1.6300 - mean_absolute_error: 1.0637 - val_loss: 2.6483 - val_mean_squared_error: 2.6483 - val_mean_absolute_error: 1.4452
# Epoch 4/40
# 302/302 [==============================] - 2s 8ms/step - loss: 1.4338 - mean_squared_error: 1.4338 - mean_absolute_error: 0.9812 - val_loss: 1.8021 - val_mean_squared_error: 1.8021 - val_mean_absolute_error: 1.2403
# Epoch 5/40
# 302/302 [==============================] - 2s 7ms/step - loss: 1.3204 - mean_squared_error: 1.3204 - mean_absolute_error: 0.9627 - val_loss: 1.5025 - val_mean_squared_error: 1.5025 - val_mean_absolute_error: 1.1233
# Epoch 6/40
# 302/302 [==============================] - 2s 6ms/step - loss: 1.2538 - mean_squared_error: 1.2538 - mean_absolute_error: 0.9071 - val_loss: 2.1367 - val_mean_squared_error: 2.1367 - val_mean_absolute_error: 1.2393
# Epoch 7/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.9884 - mean_squared_error: 0.9884 - mean_absolute_error: 0.8224 - val_loss: 1.8558 - val_mean_squared_error: 1.8558 - val_mean_absolute_error: 1.2074
# Epoch 8/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.9017 - mean_squared_error: 0.9017 - mean_absolute_error: 0.7367 - val_loss: 1.9392 - val_mean_squared_error: 1.9392 - val_mean_absolute_error: 1.2102
# Epoch 9/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.9481 - mean_squared_error: 0.9481 - mean_absolute_error: 0.7730 - val_loss: 2.5480 - val_mean_squared_error: 2.5480 - val_mean_absolute_error: 1.3493
# Epoch 10/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.7888 - mean_squared_error: 0.7888 - mean_absolute_error: 0.6986 - val_loss: 2.1870 - val_mean_squared_error: 2.1870 - val_mean_absolute_error: 1.2955
# Epoch 11/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.8774 - mean_squared_error: 0.8774 - mean_absolute_error: 0.6987 - val_loss: 1.6348 - val_mean_squared_error: 1.6348 - val_mean_absolute_error: 1.1849
# Epoch 12/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6112 - mean_squared_error: 0.6112 - mean_absolute_error: 0.6200 - val_loss: 1.5569 - val_mean_squared_error: 1.5569 - val_mean_absolute_error: 1.1672
# Epoch 13/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.7165 - mean_squared_error: 0.7165 - mean_absolute_error: 0.6745 - val_loss: 1.8046 - val_mean_squared_error: 1.8046 - val_mean_absolute_error: 1.2297
# Epoch 14/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.7064 - mean_squared_error: 0.7064 - mean_absolute_error: 0.6496 - val_loss: 1.6057 - val_mean_squared_error: 1.6057 - val_mean_absolute_error: 1.1707
# Epoch 15/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6538 - mean_squared_error: 0.6538 - mean_absolute_error: 0.5902 - val_loss: 1.2012 - val_mean_squared_error: 1.2012 - val_mean_absolute_error: 1.0227
# Epoch 16/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5525 - mean_squared_error: 0.5525 - mean_absolute_error: 0.5721 - val_loss: 1.0869 - val_mean_squared_error: 1.0869 - val_mean_absolute_error: 0.9590
# Epoch 17/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5718 - mean_squared_error: 0.5718 - mean_absolute_error: 0.5969 - val_loss: 1.0858 - val_mean_squared_error: 1.0858 - val_mean_absolute_error: 0.9368
# Epoch 18/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5254 - mean_squared_error: 0.5254 - mean_absolute_error: 0.5405 - val_loss: 0.9678 - val_mean_squared_error: 0.9678 - val_mean_absolute_error: 0.8669
# Epoch 19/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6512 - mean_squared_error: 0.6512 - mean_absolute_error: 0.6020 - val_loss: 0.8825 - val_mean_squared_error: 0.8825 - val_mean_absolute_error: 0.8280
# Epoch 20/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6213 - mean_squared_error: 0.6213 - mean_absolute_error: 0.5916 - val_loss: 0.8244 - val_mean_squared_error: 0.8244 - val_mean_absolute_error: 0.8056
# Epoch 21/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6358 - mean_squared_error: 0.6358 - mean_absolute_error: 0.5755 - val_loss: 0.7334 - val_mean_squared_error: 0.7334 - val_mean_absolute_error: 0.7635
# Epoch 22/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5315 - mean_squared_error: 0.5315 - mean_absolute_error: 0.5368 - val_loss: 0.7235 - val_mean_squared_error: 0.7235 - val_mean_absolute_error: 0.7508
# Epoch 23/40
# 302/302 [==============================] - 2s 6ms/step - loss: 0.4850 - mean_squared_error: 0.4850 - mean_absolute_error: 0.5258 - val_loss: 0.8870 - val_mean_squared_error: 0.8870 - val_mean_absolute_error: 0.8175
# Epoch 24/40
# 302/302 [==============================] - 2s 6ms/step - loss: 0.5910 - mean_squared_error: 0.5910 - mean_absolute_error: 0.5723 - val_loss: 1.0520 - val_mean_squared_error: 1.0520 - val_mean_absolute_error: 0.8417
# Epoch 25/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5686 - mean_squared_error: 0.5686 - mean_absolute_error: 0.5542 - val_loss: 0.8871 - val_mean_squared_error: 0.8871 - val_mean_absolute_error: 0.7706
# Epoch 26/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4940 - mean_squared_error: 0.4940 - mean_absolute_error: 0.5371 - val_loss: 0.7350 - val_mean_squared_error: 0.7350 - val_mean_absolute_error: 0.7180
# Epoch 27/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4129 - mean_squared_error: 0.4129 - mean_absolute_error: 0.4834 - val_loss: 0.6936 - val_mean_squared_error: 0.6936 - val_mean_absolute_error: 0.7128
# Epoch 28/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4434 - mean_squared_error: 0.4434 - mean_absolute_error: 0.5096 - val_loss: 0.6491 - val_mean_squared_error: 0.6491 - val_mean_absolute_error: 0.6926
# Epoch 29/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5863 - mean_squared_error: 0.5863 - mean_absolute_error: 0.5716 - val_loss: 0.6776 - val_mean_squared_error: 0.6776 - val_mean_absolute_error: 0.7152
# Epoch 30/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4191 - mean_squared_error: 0.4191 - mean_absolute_error: 0.4892 - val_loss: 0.6717 - val_mean_squared_error: 0.6717 - val_mean_absolute_error: 0.7153
# Epoch 31/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.4902 - mean_squared_error: 0.4902 - mean_absolute_error: 0.5175 - val_loss: 0.7051 - val_mean_squared_error: 0.7051 - val_mean_absolute_error: 0.7526
# Epoch 32/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5587 - mean_squared_error: 0.5587 - mean_absolute_error: 0.5514 - val_loss: 0.8622 - val_mean_squared_error: 0.8622 - val_mean_absolute_error: 0.8455
# Epoch 33/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5672 - mean_squared_error: 0.5672 - mean_absolute_error: 0.5511 - val_loss: 0.7958 - val_mean_squared_error: 0.7958 - val_mean_absolute_error: 0.8049
# Epoch 34/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6685 - mean_squared_error: 0.6685 - mean_absolute_error: 0.5493 - val_loss: 0.8596 - val_mean_squared_error: 0.8596 - val_mean_absolute_error: 0.8303
# Epoch 35/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.4792 - mean_squared_error: 0.4792 - mean_absolute_error: 0.5316 - val_loss: 0.9598 - val_mean_squared_error: 0.9598 - val_mean_absolute_error: 0.8618
# Epoch 36/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4426 - mean_squared_error: 0.4426 - mean_absolute_error: 0.5063 - val_loss: 0.8229 - val_mean_squared_error: 0.8229 - val_mean_absolute_error: 0.7994
# Epoch 37/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.4032 - mean_squared_error: 0.4032 - mean_absolute_error: 0.4915 - val_loss: 0.9372 - val_mean_squared_error: 0.9372 - val_mean_absolute_error: 0.8557
# Epoch 38/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4169 - mean_squared_error: 0.4169 - mean_absolute_error: 0.4926 - val_loss: 0.9729 - val_mean_squared_error: 0.9729 - val_mean_absolute_error: 0.8568
# Epoch 39/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.4026 - mean_squared_error: 0.4026 - mean_absolute_error: 0.4870 - val_loss: 0.8745 - val_mean_squared_error: 0.8745 - val_mean_absolute_error: 0.8211
# Epoch 40/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4027 - mean_squared_error: 0.4027 - mean_absolute_error: 0.4806 - val_loss: 0.8012 - val_mean_squared_error: 0.8012 - val_mean_absolute_error: 0.7805
# EndTime : 2019-12-13 01:32:11.008902
# AZD0530’s final rmse value is = 0.895125
# AZD0530 R-squared value is = -1.155105
# AZD6244_//n
# train_X shape: (301, 21213, 1)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-13 01:32:12.667902
# EndTime : 2019-12-13 01:32:17.611902
# StartTime : 2019-12-13 01:32:17.611902
# Train on 301 samples, validate on 76 samples
# Epoch 1/40
# 301/301 [==============================] - 19s 62ms/step - loss: 6.8892 - mean_squared_error: 6.8892 - mean_absolute_error: 2.3439 - val_loss: 4.6427 - val_mean_squared_error: 4.6427 - val_mean_absolute_error: 1.8898
# Epoch 2/40
# 301/301 [==============================] - 1s 2ms/step - loss: 5.1202 - mean_squared_error: 5.1202 - mean_absolute_error: 2.0385 - val_loss: 5.4188 - val_mean_squared_error: 5.4188 - val_mean_absolute_error: 2.0259
# Epoch 3/40
# 301/301 [==============================] - 1s 2ms/step - loss: 4.1635 - mean_squared_error: 4.1635 - mean_absolute_error: 1.8197 - val_loss: 7.6725 - val_mean_squared_error: 7.6725 - val_mean_absolute_error: 2.5705
# Epoch 4/40
# 301/301 [==============================] - 1s 2ms/step - loss: 3.5003 - mean_squared_error: 3.5003 - mean_absolute_error: 1.6447 - val_loss: 6.2316 - val_mean_squared_error: 6.2316 - val_mean_absolute_error: 2.3032
# Epoch 5/40
# 301/301 [==============================] - 1s 2ms/step - loss: 3.1617 - mean_squared_error: 3.1617 - mean_absolute_error: 1.5566 - val_loss: 5.2597 - val_mean_squared_error: 5.2597 - val_mean_absolute_error: 2.0847
# Epoch 6/40
# 301/301 [==============================] - 1s 2ms/step - loss: 2.5935 - mean_squared_error: 2.5935 - mean_absolute_error: 1.3964 - val_loss: 5.4446 - val_mean_squared_error: 5.4446 - val_mean_absolute_error: 2.1336
# Epoch 7/40
# 301/301 [==============================] - 1s 2ms/step - loss: 2.1939 - mean_squared_error: 2.1939 - mean_absolute_error: 1.2944 - val_loss: 5.9929 - val_mean_squared_error: 5.9929 - val_mean_absolute_error: 2.2361
# Epoch 8/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.8571 - mean_squared_error: 1.8571 - mean_absolute_error: 1.1746 - val_loss: 5.9429 - val_mean_squared_error: 5.9429 - val_mean_absolute_error: 2.2179
# Epoch 9/40
# 301/301 [==============================] - 2s 6ms/step - loss: 1.7405 - mean_squared_error: 1.7405 - mean_absolute_error: 1.0830 - val_loss: 5.2013 - val_mean_squared_error: 5.2013 - val_mean_absolute_error: 2.0274
# Epoch 10/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.4655 - mean_squared_error: 1.4655 - mean_absolute_error: 1.0427 - val_loss: 4.5971 - val_mean_squared_error: 4.5971 - val_mean_absolute_error: 1.8909
# Epoch 11/40
# 301/301 [==============================] - 1s 4ms/step - loss: 1.1817 - mean_squared_error: 1.1817 - mean_absolute_error: 0.9453 - val_loss: 4.5061 - val_mean_squared_error: 4.5061 - val_mean_absolute_error: 1.9125
# Epoch 12/40
# 301/301 [==============================] - 1s 4ms/step - loss: 1.0210 - mean_squared_error: 1.0210 - mean_absolute_error: 0.8286 - val_loss: 5.0189 - val_mean_squared_error: 5.0189 - val_mean_absolute_error: 2.0394
# Epoch 13/40
# 301/301 [==============================] - 1s 4ms/step - loss: 1.0370 - mean_squared_error: 1.0370 - mean_absolute_error: 0.8060 - val_loss: 4.8022 - val_mean_squared_error: 4.8022 - val_mean_absolute_error: 1.9629
# Epoch 14/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.0245 - mean_squared_error: 1.0245 - mean_absolute_error: 0.8163 - val_loss: 3.6665 - val_mean_squared_error: 3.6665 - val_mean_absolute_error: 1.6319
# Epoch 15/40
# 301/301 [==============================] - 1s 5ms/step - loss: 0.6598 - mean_squared_error: 0.6598 - mean_absolute_error: 0.6427 - val_loss: 3.7056 - val_mean_squared_error: 3.7056 - val_mean_absolute_error: 1.5787
# Epoch 16/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.5669 - mean_squared_error: 0.5669 - mean_absolute_error: 0.5973 - val_loss: 3.8932 - val_mean_squared_error: 3.8932 - val_mean_absolute_error: 1.5912
# Epoch 17/40
# 301/301 [==============================] - 1s 5ms/step - loss: 0.6943 - mean_squared_error: 0.6943 - mean_absolute_error: 0.6530 - val_loss: 3.9158 - val_mean_squared_error: 3.9158 - val_mean_absolute_error: 1.5823
# Epoch 18/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.6339 - mean_squared_error: 0.6339 - mean_absolute_error: 0.6256 - val_loss: 3.4348 - val_mean_squared_error: 3.4348 - val_mean_absolute_error: 1.5199
# Epoch 19/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6551 - mean_squared_error: 0.6551 - mean_absolute_error: 0.6354 - val_loss: 3.4077 - val_mean_squared_error: 3.4077 - val_mean_absolute_error: 1.5063
# Epoch 20/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4043 - mean_squared_error: 0.4043 - mean_absolute_error: 0.4873 - val_loss: 3.2456 - val_mean_squared_error: 3.2456 - val_mean_absolute_error: 1.4454
# Epoch 21/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4639 - mean_squared_error: 0.4639 - mean_absolute_error: 0.5200 - val_loss: 2.9379 - val_mean_squared_error: 2.9379 - val_mean_absolute_error: 1.3127
# Epoch 22/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.6666 - mean_squared_error: 0.6666 - mean_absolute_error: 0.6249 - val_loss: 2.9684 - val_mean_squared_error: 2.9684 - val_mean_absolute_error: 1.2747
# Epoch 23/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4739 - mean_squared_error: 0.4739 - mean_absolute_error: 0.5326 - val_loss: 3.7073 - val_mean_squared_error: 3.7073 - val_mean_absolute_error: 1.4172
# Epoch 24/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3737 - mean_squared_error: 0.3737 - mean_absolute_error: 0.4626 - val_loss: 3.2529 - val_mean_squared_error: 3.2529 - val_mean_absolute_error: 1.3438
# Epoch 25/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4744 - mean_squared_error: 0.4744 - mean_absolute_error: 0.5146 - val_loss: 2.9749 - val_mean_squared_error: 2.9749 - val_mean_absolute_error: 1.2654
# Epoch 26/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.4099 - mean_squared_error: 0.4099 - mean_absolute_error: 0.4717 - val_loss: 3.0162 - val_mean_squared_error: 3.0162 - val_mean_absolute_error: 1.2746
# Epoch 27/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3720 - mean_squared_error: 0.3720 - mean_absolute_error: 0.4489 - val_loss: 3.0009 - val_mean_squared_error: 3.0009 - val_mean_absolute_error: 1.1596
# Epoch 28/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3515 - mean_squared_error: 0.3515 - mean_absolute_error: 0.4368 - val_loss: 2.7337 - val_mean_squared_error: 2.7337 - val_mean_absolute_error: 1.0527
# Epoch 29/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.3348 - mean_squared_error: 0.3348 - mean_absolute_error: 0.4063 - val_loss: 2.7934 - val_mean_squared_error: 2.7934 - val_mean_absolute_error: 1.0999
# Epoch 30/40
# 301/301 [==============================] - 1s 4ms/step - loss: 0.4309 - mean_squared_error: 0.4309 - mean_absolute_error: 0.4926 - val_loss: 2.7263 - val_mean_squared_error: 2.7263 - val_mean_absolute_error: 1.0266
# Epoch 31/40
# 301/301 [==============================] - 1s 4ms/step - loss: 0.3347 - mean_squared_error: 0.3347 - mean_absolute_error: 0.4269 - val_loss: 2.7186 - val_mean_squared_error: 2.7186 - val_mean_absolute_error: 0.9957
# Epoch 32/40
# 301/301 [==============================] - 1s 4ms/step - loss: 0.4146 - mean_squared_error: 0.4146 - mean_absolute_error: 0.5025 - val_loss: 2.7305 - val_mean_squared_error: 2.7305 - val_mean_absolute_error: 1.0378
# Epoch 33/40
# 301/301 [==============================] - 1s 5ms/step - loss: 0.3553 - mean_squared_error: 0.3553 - mean_absolute_error: 0.4285 - val_loss: 2.7507 - val_mean_squared_error: 2.7507 - val_mean_absolute_error: 1.1604
# Epoch 34/40
# 301/301 [==============================] - 1s 4ms/step - loss: 0.3868 - mean_squared_error: 0.3868 - mean_absolute_error: 0.4611 - val_loss: 2.9254 - val_mean_squared_error: 2.9254 - val_mean_absolute_error: 1.2099
# Epoch 35/40
# 301/301 [==============================] - 1s 4ms/step - loss: 0.4795 - mean_squared_error: 0.4795 - mean_absolute_error: 0.5003 - val_loss: 2.6990 - val_mean_squared_error: 2.6990 - val_mean_absolute_error: 1.0773
# Epoch 36/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.3173 - mean_squared_error: 0.3173 - mean_absolute_error: 0.4002 - val_loss: 2.6836 - val_mean_squared_error: 2.6836 - val_mean_absolute_error: 0.9638
# Epoch 37/40
# 301/301 [==============================] - 1s 4ms/step - loss: 0.3280 - mean_squared_error: 0.3280 - mean_absolute_error: 0.4209 - val_loss: 2.5770 - val_mean_squared_error: 2.5770 - val_mean_absolute_error: 0.9816
# Epoch 38/40
# 301/301 [==============================] - 1s 5ms/step - loss: 0.3869 - mean_squared_error: 0.3869 - mean_absolute_error: 0.4759 - val_loss: 2.6159 - val_mean_squared_error: 2.6159 - val_mean_absolute_error: 1.0780
# Epoch 39/40
# 301/301 [==============================] - 1s 2ms/step - loss: 0.3953 - mean_squared_error: 0.3953 - mean_absolute_error: 0.4800 - val_loss: 2.6862 - val_mean_squared_error: 2.6862 - val_mean_absolute_error: 1.1417
# Epoch 40/40
# 301/301 [==============================] - 1s 5ms/step - loss: 0.3240 - mean_squared_error: 0.3240 - mean_absolute_error: 0.3959 - val_loss: 2.6572 - val_mean_squared_error: 2.6572 - val_mean_absolute_error: 1.0874
# EndTime : 2019-12-13 01:33:24.462902
# AZD6244’s final rmse value is = 1.630094
# AZD6244 R-squared value is = 0.000953
# Erlotinib_//n
# train_X shape: (302, 21213, 1)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-13 01:33:26.751902
# EndTime : 2019-12-13 01:33:32.981902
# StartTime : 2019-12-13 01:33:32.981902
# Train on 302 samples, validate on 76 samples
# Epoch 1/40
# 302/302 [==============================] - 16s 53ms/step - loss: 1.8820 - mean_squared_error: 1.8820 - mean_absolute_error: 1.1097 - val_loss: 2.1508 - val_mean_squared_error: 2.1508 - val_mean_absolute_error: 1.2641
# Epoch 2/40
# 302/302 [==============================] - 1s 4ms/step - loss: 1.7407 - mean_squared_error: 1.7407 - mean_absolute_error: 1.0846 - val_loss: 1.6101 - val_mean_squared_error: 1.6101 - val_mean_absolute_error: 1.1765
# Epoch 3/40
# 302/302 [==============================] - 1s 2ms/step - loss: 1.4853 - mean_squared_error: 1.4853 - mean_absolute_error: 0.9667 - val_loss: 1.4466 - val_mean_squared_error: 1.4466 - val_mean_absolute_error: 1.1103
# Epoch 4/40
# 302/302 [==============================] - 1s 4ms/step - loss: 1.0701 - mean_squared_error: 1.0701 - mean_absolute_error: 0.8303 - val_loss: 1.6305 - val_mean_squared_error: 1.6305 - val_mean_absolute_error: 1.1834
# Epoch 5/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.8290 - mean_squared_error: 0.8290 - mean_absolute_error: 0.7139 - val_loss: 1.4747 - val_mean_squared_error: 1.4747 - val_mean_absolute_error: 1.0999
# Epoch 6/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.8358 - mean_squared_error: 0.8358 - mean_absolute_error: 0.7080 - val_loss: 1.4052 - val_mean_squared_error: 1.4052 - val_mean_absolute_error: 1.0649
# Epoch 7/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.7668 - mean_squared_error: 0.7668 - mean_absolute_error: 0.7104 - val_loss: 1.5791 - val_mean_squared_error: 1.5791 - val_mean_absolute_error: 1.0882
# Epoch 8/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.6244 - mean_squared_error: 0.6244 - mean_absolute_error: 0.6343 - val_loss: 1.9571 - val_mean_squared_error: 1.9571 - val_mean_absolute_error: 1.1219
# Epoch 9/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.7112 - mean_squared_error: 0.7112 - mean_absolute_error: 0.6380 - val_loss: 1.3192 - val_mean_squared_error: 1.3192 - val_mean_absolute_error: 0.9679
# Epoch 10/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6164 - mean_squared_error: 0.6164 - mean_absolute_error: 0.6031 - val_loss: 0.9360 - val_mean_squared_error: 0.9360 - val_mean_absolute_error: 0.8385
# Epoch 11/40
# 302/302 [==============================] - 2s 5ms/step - loss: 0.5613 - mean_squared_error: 0.5613 - mean_absolute_error: 0.5713 - val_loss: 0.7793 - val_mean_squared_error: 0.7793 - val_mean_absolute_error: 0.7717
# Epoch 12/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5901 - mean_squared_error: 0.5901 - mean_absolute_error: 0.5822 - val_loss: 0.8344 - val_mean_squared_error: 0.8344 - val_mean_absolute_error: 0.8248
# Epoch 13/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5746 - mean_squared_error: 0.5746 - mean_absolute_error: 0.5802 - val_loss: 0.7644 - val_mean_squared_error: 0.7644 - val_mean_absolute_error: 0.7947
# Epoch 14/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5164 - mean_squared_error: 0.5164 - mean_absolute_error: 0.5576 - val_loss: 0.8892 - val_mean_squared_error: 0.8892 - val_mean_absolute_error: 0.8493
# Epoch 15/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5472 - mean_squared_error: 0.5472 - mean_absolute_error: 0.5691 - val_loss: 1.1819 - val_mean_squared_error: 1.1819 - val_mean_absolute_error: 0.9348
# Epoch 16/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5261 - mean_squared_error: 0.5261 - mean_absolute_error: 0.5638 - val_loss: 1.0637 - val_mean_squared_error: 1.0637 - val_mean_absolute_error: 0.9003
# Epoch 17/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.5789 - mean_squared_error: 0.5789 - mean_absolute_error: 0.5640 - val_loss: 0.6438 - val_mean_squared_error: 0.6438 - val_mean_absolute_error: 0.7202
# Epoch 18/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5239 - mean_squared_error: 0.5239 - mean_absolute_error: 0.5450 - val_loss: 0.6947 - val_mean_squared_error: 0.6947 - val_mean_absolute_error: 0.7469
# Epoch 19/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5374 - mean_squared_error: 0.5374 - mean_absolute_error: 0.5740 - val_loss: 0.6319 - val_mean_squared_error: 0.6319 - val_mean_absolute_error: 0.7117
# Epoch 20/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4145 - mean_squared_error: 0.4145 - mean_absolute_error: 0.5066 - val_loss: 0.6336 - val_mean_squared_error: 0.6336 - val_mean_absolute_error: 0.7088
# Epoch 21/40
# 302/302 [==============================] - 2s 5ms/step - loss: 0.4411 - mean_squared_error: 0.4411 - mean_absolute_error: 0.5171 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_error: 0.7027
# Epoch 22/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.4885 - mean_squared_error: 0.4885 - mean_absolute_error: 0.5246 - val_loss: 0.6076 - val_mean_squared_error: 0.6076 - val_mean_absolute_error: 0.6448
# Epoch 23/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5000 - mean_squared_error: 0.5000 - mean_absolute_error: 0.5453 - val_loss: 0.6051 - val_mean_squared_error: 0.6051 - val_mean_absolute_error: 0.6533
# Epoch 24/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4318 - mean_squared_error: 0.4318 - mean_absolute_error: 0.4897 - val_loss: 0.5879 - val_mean_squared_error: 0.5879 - val_mean_absolute_error: 0.6697
# Epoch 25/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3202 - mean_squared_error: 0.3202 - mean_absolute_error: 0.4501 - val_loss: 0.5772 - val_mean_squared_error: 0.5772 - val_mean_absolute_error: 0.6566
# Epoch 26/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5174 - mean_squared_error: 0.5174 - mean_absolute_error: 0.5439 - val_loss: 0.5409 - val_mean_squared_error: 0.5409 - val_mean_absolute_error: 0.6036
# Epoch 27/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5190 - mean_squared_error: 0.5190 - mean_absolute_error: 0.5199 - val_loss: 0.5275 - val_mean_squared_error: 0.5275 - val_mean_absolute_error: 0.5957
# Epoch 28/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.4981 - mean_squared_error: 0.4981 - mean_absolute_error: 0.5184 - val_loss: 0.5542 - val_mean_squared_error: 0.5542 - val_mean_absolute_error: 0.6161
# Epoch 29/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5383 - mean_squared_error: 0.5383 - mean_absolute_error: 0.5520 - val_loss: 0.5783 - val_mean_squared_error: 0.5783 - val_mean_absolute_error: 0.6221
# Epoch 30/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.4876 - mean_squared_error: 0.4876 - mean_absolute_error: 0.5275 - val_loss: 0.4758 - val_mean_squared_error: 0.4758 - val_mean_absolute_error: 0.5690
# Epoch 31/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.5047 - mean_squared_error: 0.5047 - mean_absolute_error: 0.5386 - val_loss: 0.4638 - val_mean_squared_error: 0.4638 - val_mean_absolute_error: 0.5203
# Epoch 32/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.5056 - mean_squared_error: 0.5056 - mean_absolute_error: 0.5492 - val_loss: 0.4532 - val_mean_squared_error: 0.4532 - val_mean_absolute_error: 0.4850
# Epoch 33/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4572 - mean_squared_error: 0.4572 - mean_absolute_error: 0.5102 - val_loss: 0.4256 - val_mean_squared_error: 0.4256 - val_mean_absolute_error: 0.4835
# Epoch 34/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.3659 - mean_squared_error: 0.3659 - mean_absolute_error: 0.4567 - val_loss: 0.5370 - val_mean_squared_error: 0.5370 - val_mean_absolute_error: 0.5783
# Epoch 35/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4312 - mean_squared_error: 0.4312 - mean_absolute_error: 0.5000 - val_loss: 0.5909 - val_mean_squared_error: 0.5909 - val_mean_absolute_error: 0.6113
# Epoch 36/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.4442 - mean_squared_error: 0.4442 - mean_absolute_error: 0.4825 - val_loss: 0.6006 - val_mean_squared_error: 0.6006 - val_mean_absolute_error: 0.6027
# Epoch 37/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.3393 - mean_squared_error: 0.3393 - mean_absolute_error: 0.4552 - val_loss: 0.5429 - val_mean_squared_error: 0.5429 - val_mean_absolute_error: 0.5768
# Epoch 38/40
# 302/302 [==============================] - 1s 4ms/step - loss: 0.4224 - mean_squared_error: 0.4224 - mean_absolute_error: 0.4895 - val_loss: 0.4507 - val_mean_squared_error: 0.4507 - val_mean_absolute_error: 0.5312
# Epoch 39/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.4019 - mean_squared_error: 0.4019 - mean_absolute_error: 0.4878 - val_loss: 0.4418 - val_mean_squared_error: 0.4418 - val_mean_absolute_error: 0.5195
# Epoch 40/40
# 302/302 [==============================] - 1s 5ms/step - loss: 0.3883 - mean_squared_error: 0.3883 - mean_absolute_error: 0.4761 - val_loss: 0.4243 - val_mean_squared_error: 0.4243 - val_mean_absolute_error: 0.4954
# EndTime : 2019-12-13 01:34:40.507902
# ...
# Epoch 13/40
# 302/302 [==============================] - 1s 3ms/step - loss: 1.0000 - mean_squared_error: 1.0000 - mean_absolute_error: 0.8755 - val_loss: 1.1577 - val_mean_squared_error: 1.1577 - val_mean_absolute_error: 0.9718
# Epoch 14/40
# 302/302 [==============================] - 1s 3ms/step - loss: 1.1290 - mean_squared_error: 1.1290 - mean_absolute_error: 0.8835 - val_loss: 0.7289 - val_mean_squared_error: 0.7289 - val_mean_absolute_error: 0.7821
# Epoch 15/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.9075 - mean_squared_error: 0.9075 - mean_absolute_error: 0.8250 - val_loss: 0.6040 - val_mean_squared_error: 0.6040 - val_mean_absolute_error: 0.6992
# Epoch 16/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.9790 - mean_squared_error: 0.9790 - mean_absolute_error: 0.8052 - val_loss: 0.5953 - val_mean_squared_error: 0.5953 - val_mean_absolute_error: 0.6855
# Epoch 17/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.9131 - mean_squared_error: 0.9131 - mean_absolute_error: 0.7977 - val_loss: 0.7170 - val_mean_squared_error: 0.7170 - val_mean_absolute_error: 0.7337
# Epoch 18/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.8126 - mean_squared_error: 0.8126 - mean_absolute_error: 0.7201 - val_loss: 1.0674 - val_mean_squared_error: 1.0674 - val_mean_absolute_error: 0.8266
# Epoch 19/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.7999 - mean_squared_error: 0.7999 - mean_absolute_error: 0.6874 - val_loss: 1.0655 - val_mean_squared_error: 1.0655 - val_mean_absolute_error: 0.8489
# Epoch 20/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6519 - mean_squared_error: 0.6519 - mean_absolute_error: 0.6505 - val_loss: 0.7152 - val_mean_squared_error: 0.7152 - val_mean_absolute_error: 0.7431
# Epoch 21/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5751 - mean_squared_error: 0.5751 - mean_absolute_error: 0.6059 - val_loss: 0.6464 - val_mean_squared_error: 0.6464 - val_mean_absolute_error: 0.7267
# Epoch 22/40
# 302/302 [==============================] - 1s 2ms/step - loss: 0.6008 - mean_squared_error: 0.6008 - mean_absolute_error: 0.6245 - val_loss: 0.4769 - val_mean_squared_error: 0.4769 - val_mean_absolute_error: 0.6451
# Epoch 23/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6658 - mean_squared_error: 0.6658 - mean_absolute_error: 0.6333 - val_loss: 0.4421 - val_mean_squared_error: 0.4421 - val_mean_absolute_error: 0.6145
# Epoch 24/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.6913 - mean_squared_error: 0.6913 - mean_absolute_error: 0.6131 - val_loss: 0.6301 - val_mean_squared_error: 0.6301 - val_mean_absolute_error: 0.7052
# Epoch 25/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5781 - mean_squared_error: 0.5781 - mean_absolute_error: 0.5672 - val_loss: 0.8637 - val_mean_squared_error: 0.8637 - val_mean_absolute_error: 0.7666
# Epoch 26/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.5589 - mean_squared_error: 0.5589 - mean_absolute_error: 0.5194 - val_loss: 0.6961 - val_mean_squared_error: 0.6961 - val_mean_absolute_error: 0.6864
# Epoch 27/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4957 - mean_squared_error: 0.4957 - mean_absolute_error: 0.5096 - val_loss: 0.5701 - val_mean_squared_error: 0.5701 - val_mean_absolute_error: 0.6130
# Epoch 28/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4443 - mean_squared_error: 0.4443 - mean_absolute_error: 0.4985 - val_loss: 0.5251 - val_mean_squared_error: 0.5251 - val_mean_absolute_error: 0.5773
# Epoch 29/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4017 - mean_squared_error: 0.4017 - mean_absolute_error: 0.4920 - val_loss: 0.4050 - val_mean_squared_error: 0.4050 - val_mean_absolute_error: 0.5184
# Epoch 30/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4314 - mean_squared_error: 0.4314 - mean_absolute_error: 0.5068 - val_loss: 0.3586 - val_mean_squared_error: 0.3586 - val_mean_absolute_error: 0.4707
# Epoch 31/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4203 - mean_squared_error: 0.4203 - mean_absolute_error: 0.4734 - val_loss: 0.4192 - val_mean_squared_error: 0.4192 - val_mean_absolute_error: 0.4966
# Epoch 32/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3276 - mean_squared_error: 0.3276 - mean_absolute_error: 0.4354 - val_loss: 0.4737 - val_mean_squared_error: 0.4737 - val_mean_absolute_error: 0.5298
# Epoch 33/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3542 - mean_squared_error: 0.3542 - mean_absolute_error: 0.4578 - val_loss: 0.5758 - val_mean_squared_error: 0.5758 - val_mean_absolute_error: 0.5693
# Epoch 34/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3681 - mean_squared_error: 0.3681 - mean_absolute_error: 0.4663 - val_loss: 0.7610 - val_mean_squared_error: 0.7610 - val_mean_absolute_error: 0.5918
# Epoch 35/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3525 - mean_squared_error: 0.3525 - mean_absolute_error: 0.4481 - val_loss: 0.7269 - val_mean_squared_error: 0.7269 - val_mean_absolute_error: 0.6030
# Epoch 36/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4230 - mean_squared_error: 0.4230 - mean_absolute_error: 0.4549 - val_loss: 0.5956 - val_mean_squared_error: 0.5956 - val_mean_absolute_error: 0.5913
# Epoch 37/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3456 - mean_squared_error: 0.3456 - mean_absolute_error: 0.4226 - val_loss: 0.4287 - val_mean_squared_error: 0.4287 - val_mean_absolute_error: 0.5337
# Epoch 38/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.3932 - mean_squared_error: 0.3932 - mean_absolute_error: 0.4580 - val_loss: 0.2846 - val_mean_squared_error: 0.2846 - val_mean_absolute_error: 0.4735
# Epoch 39/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4289 - mean_squared_error: 0.4289 - mean_absolute_error: 0.4901 - val_loss: 0.2557 - val_mean_squared_error: 0.2557 - val_mean_absolute_error: 0.4604
# Epoch 40/40
# 302/302 [==============================] - 1s 3ms/step - loss: 0.4329 - mean_squared_error: 0.4329 - mean_absolute_error: 0.4595 - val_loss: 0.2876 - val_mean_squared_error: 0.2876 - val_mean_absolute_error: 0.4749
# EndTime : 2019-12-13 01:40:49.794902
# Nutlin-3’s final rmse value is = 0.536256
# Nutlin-3 R-squared value is = -13.095365
# Paclitaxel_//n
# train_X shape: (301, 21213, 1)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-13 01:40:53.326902
# EndTime : 2019-12-13 01:40:58.902902
# StartTime : 2019-12-13 01:40:58.902902
# Train on 301 samples, validate on 76 samples
# Epoch 1/40
# 301/301 [==============================] - 16s 54ms/step - loss: 16.6045 - mean_squared_error: 16.6045 - mean_absolute_error: 3.8047 - val_loss: 25.1345 - val_mean_squared_error: 25.1345 - val_mean_absolute_error: 4.3986
# Epoch 2/40
# 301/301 [==============================] - 1s 3ms/step - loss: 14.4203 - mean_squared_error: 14.4203 - mean_absolute_error: 3.5747 - val_loss: 21.7028 - val_mean_squared_error: 21.7028 - val_mean_absolute_error: 4.1957
# Epoch 3/40
# 301/301 [==============================] - 1s 3ms/step - loss: 13.1128 - mean_squared_error: 13.1128 - mean_absolute_error: 3.3885 - val_loss: 13.8045 - val_mean_squared_error: 13.8045 - val_mean_absolute_error: 3.4368
# Epoch 4/40
# 301/301 [==============================] - 1s 3ms/step - loss: 11.3628 - mean_squared_error: 11.3628 - mean_absolute_error: 3.1601 - val_loss: 10.3010 - val_mean_squared_error: 10.3010 - val_mean_absolute_error: 2.8302
# Epoch 5/40
# 301/301 [==============================] - 1s 3ms/step - loss: 10.5557 - mean_squared_error: 10.5557 - mean_absolute_error: 3.0332 - val_loss: 11.2210 - val_mean_squared_error: 11.2210 - val_mean_absolute_error: 2.9427
# Epoch 6/40
# 301/301 [==============================] - 1s 3ms/step - loss: 9.8513 - mean_squared_error: 9.8513 - mean_absolute_error: 2.9491 - val_loss: 11.8288 - val_mean_squared_error: 11.8288 - val_mean_absolute_error: 2.9131
# Epoch 7/40
# 301/301 [==============================] - 1s 3ms/step - loss: 8.4969 - mean_squared_error: 8.4969 - mean_absolute_error: 2.7158 - val_loss: 13.5249 - val_mean_squared_error: 13.5249 - val_mean_absolute_error: 3.0317
# Epoch 8/40
# 301/301 [==============================] - 1s 3ms/step - loss: 7.6002 - mean_squared_error: 7.6002 - mean_absolute_error: 2.5739 - val_loss: 14.7974 - val_mean_squared_error: 14.7974 - val_mean_absolute_error: 3.1157
# Epoch 9/40
# 301/301 [==============================] - 1s 3ms/step - loss: 6.9906 - mean_squared_error: 6.9906 - mean_absolute_error: 2.4766 - val_loss: 14.5099 - val_mean_squared_error: 14.5099 - val_mean_absolute_error: 3.1385
# Epoch 10/40
# 301/301 [==============================] - 1s 3ms/step - loss: 6.3544 - mean_squared_error: 6.3544 - mean_absolute_error: 2.3682 - val_loss: 15.9182 - val_mean_squared_error: 15.9182 - val_mean_absolute_error: 3.3189
# Epoch 11/40
# 301/301 [==============================] - 1s 3ms/step - loss: 5.7670 - mean_squared_error: 5.7670 - mean_absolute_error: 2.2347 - val_loss: 15.8811 - val_mean_squared_error: 15.8811 - val_mean_absolute_error: 3.1957
# Epoch 12/40
# 301/301 [==============================] - 1s 3ms/step - loss: 5.3173 - mean_squared_error: 5.3173 - mean_absolute_error: 2.1118 - val_loss: 14.1347 - val_mean_squared_error: 14.1347 - val_mean_absolute_error: 3.0342
# Epoch 13/40
# 301/301 [==============================] - 1s 3ms/step - loss: 4.7167 - mean_squared_error: 4.7167 - mean_absolute_error: 1.9783 - val_loss: 12.6776 - val_mean_squared_error: 12.6776 - val_mean_absolute_error: 2.8616
# Epoch 14/40
# 301/301 [==============================] - 1s 3ms/step - loss: 4.3429 - mean_squared_error: 4.3429 - mean_absolute_error: 1.8871 - val_loss: 12.1946 - val_mean_squared_error: 12.1946 - val_mean_absolute_error: 2.8007
# Epoch 15/40
# 301/301 [==============================] - 1s 3ms/step - loss: 4.1094 - mean_squared_error: 4.1094 - mean_absolute_error: 1.8048 - val_loss: 11.5747 - val_mean_squared_error: 11.5747 - val_mean_absolute_error: 2.6939
# Epoch 16/40
# 301/301 [==============================] - 1s 3ms/step - loss: 3.6606 - mean_squared_error: 3.6606 - mean_absolute_error: 1.7419 - val_loss: 13.0681 - val_mean_squared_error: 13.0681 - val_mean_absolute_error: 2.8525
# Epoch 17/40
# 301/301 [==============================] - 1s 3ms/step - loss: 3.1365 - mean_squared_error: 3.1365 - mean_absolute_error: 1.5903 - val_loss: 13.0986 - val_mean_squared_error: 13.0986 - val_mean_absolute_error: 2.8350
# Epoch 18/40
# 301/301 [==============================] - 1s 3ms/step - loss: 3.1426 - mean_squared_error: 3.1426 - mean_absolute_error: 1.5454 - val_loss: 10.0790 - val_mean_squared_error: 10.0790 - val_mean_absolute_error: 2.4465
# Epoch 19/40
# 301/301 [==============================] - 1s 3ms/step - loss: 2.8099 - mean_squared_error: 2.8099 - mean_absolute_error: 1.4669 - val_loss: 9.2237 - val_mean_squared_error: 9.2237 - val_mean_absolute_error: 2.2848
# Epoch 20/40
# 301/301 [==============================] - 1s 3ms/step - loss: 2.3812 - mean_squared_error: 2.3812 - mean_absolute_error: 1.3785 - val_loss: 9.9074 - val_mean_squared_error: 9.9074 - val_mean_absolute_error: 2.3928
# Epoch 21/40
# 301/301 [==============================] - 1s 3ms/step - loss: 2.1726 - mean_squared_error: 2.1726 - mean_absolute_error: 1.2677 - val_loss: 11.1781 - val_mean_squared_error: 11.1781 - val_mean_absolute_error: 2.5705
# Epoch 22/40
# 301/301 [==============================] - 1s 3ms/step - loss: 2.0953 - mean_squared_error: 2.0953 - mean_absolute_error: 1.2461 - val_loss: 11.0175 - val_mean_squared_error: 11.0175 - val_mean_absolute_error: 2.5362
# Epoch 23/40
# 301/301 [==============================] - 1s 3ms/step - loss: 2.1530 - mean_squared_error: 2.1530 - mean_absolute_error: 1.2281 - val_loss: 9.4961 - val_mean_squared_error: 9.4961 - val_mean_absolute_error: 2.3185
# Epoch 24/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.6660 - mean_squared_error: 1.6660 - mean_absolute_error: 1.0939 - val_loss: 9.0126 - val_mean_squared_error: 9.0126 - val_mean_absolute_error: 2.2186
# Epoch 25/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.6459 - mean_squared_error: 1.6459 - mean_absolute_error: 1.0509 - val_loss: 8.7698 - val_mean_squared_error: 8.7698 - val_mean_absolute_error: 2.1618
# Epoch 26/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.4010 - mean_squared_error: 1.4010 - mean_absolute_error: 0.9837 - val_loss: 9.5184 - val_mean_squared_error: 9.5184 - val_mean_absolute_error: 2.2471
# Epoch 27/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.3710 - mean_squared_error: 1.3710 - mean_absolute_error: 0.9637 - val_loss: 8.8955 - val_mean_squared_error: 8.8955 - val_mean_absolute_error: 2.1635
# Epoch 28/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.2156 - mean_squared_error: 1.2156 - mean_absolute_error: 0.8815 - val_loss: 7.8542 - val_mean_squared_error: 7.8542 - val_mean_absolute_error: 1.9979
# Epoch 29/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.2077 - mean_squared_error: 1.2077 - mean_absolute_error: 0.9122 - val_loss: 7.8379 - val_mean_squared_error: 7.8379 - val_mean_absolute_error: 1.9938
# Epoch 30/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.1128 - mean_squared_error: 1.1128 - mean_absolute_error: 0.8270 - val_loss: 7.9777 - val_mean_squared_error: 7.9777 - val_mean_absolute_error: 2.0360
# Epoch 31/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.2294 - mean_squared_error: 1.2294 - mean_absolute_error: 0.9083 - val_loss: 7.7384 - val_mean_squared_error: 7.7384 - val_mean_absolute_error: 1.9937
# Epoch 32/40
# 301/301 [==============================] - 1s 3ms/step - loss: 1.0178 - mean_squared_error: 1.0178 - mean_absolute_error: 0.7950 - val_loss: 7.6060 - val_mean_squared_error: 7.6060 - val_mean_absolute_error: 1.9416
# Epoch 33/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.9942 - mean_squared_error: 0.9942 - mean_absolute_error: 0.7975 - val_loss: 7.8200 - val_mean_squared_error: 7.8200 - val_mean_absolute_error: 1.9379
# Epoch 34/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.9265 - mean_squared_error: 0.9265 - mean_absolute_error: 0.7232 - val_loss: 7.9386 - val_mean_squared_error: 7.9386 - val_mean_absolute_error: 1.9656
# Epoch 35/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.9006 - mean_squared_error: 0.9006 - mean_absolute_error: 0.6964 - val_loss: 7.8103 - val_mean_squared_error: 7.8103 - val_mean_absolute_error: 1.9573
# Epoch 36/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8222 - mean_squared_error: 0.8222 - mean_absolute_error: 0.7112 - val_loss: 7.6877 - val_mean_squared_error: 7.6877 - val_mean_absolute_error: 1.9401
# Epoch 37/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.7359 - mean_squared_error: 0.7359 - mean_absolute_error: 0.6528 - val_loss: 7.3791 - val_mean_squared_error: 7.3791 - val_mean_absolute_error: 1.8974
# Epoch 38/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.7262 - mean_squared_error: 0.7262 - mean_absolute_error: 0.6447 - val_loss: 7.3899 - val_mean_squared_error: 7.3899 - val_mean_absolute_error: 1.9136
# Epoch 39/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8267 - mean_squared_error: 0.8267 - mean_absolute_error: 0.6981 - val_loss: 7.6471 - val_mean_squared_error: 7.6471 - val_mean_absolute_error: 1.9442
# Epoch 40/40
# 301/301 [==============================] - 1s 3ms/step - loss: 0.8256 - mean_squared_error: 0.8256 - mean_absolute_error: 0.7028 - val_loss: 7.1019 - val_mean_squared_error: 7.1019 - val_mean_absolute_error: 1.8803
# EndTime : 2019-12-13 01:41:52.408902
# Paclitaxel’s final rmse value is = 2.664938
# Paclitaxel R-squared value is = -0.567904

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE    R2value
# 0         17-AAG  1.576468  -0.179167
# 1         AEW541  0.956474  -0.701590
# 2        AZD0530  0.895125  -1.155105
# 3        AZD6244  1.630094   0.000953
# 4      Erlotinib  0.651418  -0.265341
# 5     Irinotecan  1.602560  -0.767164
# 6       L-685458  0.988499  -0.044508
# 7      Lapatinib  0.851284  -2.095526
# 8         LBW242  1.314281  -0.054617
# 9      Nilotinib  1.138019  -0.156814
# 10      Nutlin-3  0.536256 -13.095365
# 11    Paclitaxel  2.664938  -0.567904
# 12  Panobinostat       NaN        NaN
# 13    PD-0325901       NaN        NaN
# 14    PD-0332991       NaN        NaN
# 15     PF2341066       NaN        NaN
# 16    PHA-665752       NaN        NaN
# 17       PLX4720       NaN        NaN
# 18        RAF265       NaN        NaN
# 19     Sorafenib       NaN        NaN
# 20        TAE684       NaN        NaN
# 21        TKI258       NaN        NaN
# 22     Topotecan       NaN        NaN
# 23       ZD-6474       NaN        NaN

# %%
workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Result//MC-9K_individual//ResNet"
result.to_csv(workdir +'//191212_MC9K_one_drug_one_model_ResNet_12drugs_metrics.csv')
