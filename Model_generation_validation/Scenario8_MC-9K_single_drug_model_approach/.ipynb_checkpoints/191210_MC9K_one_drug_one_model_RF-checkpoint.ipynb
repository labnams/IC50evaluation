# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario8_MC-9K_single_drug_model_approach

workdir = "path"

# %%
file_list = os.listdir(workdir)

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[-1].split(".")[0]
    drug_list.append(drug_file)

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//190509_ccle_mut_ic50_aron_%s.npz" % dname) # input file
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-RF-and-RF-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    # https://towardsdatascience.com/how-to-perform-RF-and-RF-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    

    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    # #############################################################################
    # Fit regression model
    rf = RandomForestRegressor(random_state = 84)
    # Train the model on training data
    rf.fit(train_X, train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)


    predicted_classes = rf.predict(test_X)
    predicted_value = predicted_classes
    
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//RF//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='blue')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//RF"   

plt.savefig(workdir +'//191212_MC9K_one_drug_one_model_RF.png', dpi=400)
workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"
# Out:
# 17-AAG_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:43:37.940549
# StartTime : 2019-12-12 18:43:37.940549
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:43:44.872043
# 17-AAG’s final rmse value is = 1.515649
# 17-AAG R-squared value is = -0.089940
# AEW541_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:43:45.005685
# StartTime : 2019-12-12 18:43:45.005685
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:43:52.183496
# AEW541’s final rmse value is = 0.816844
# AEW541 R-squared value is = -0.241044
# AZD0530_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:43:52.313120
# StartTime : 2019-12-12 18:43:52.313120
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:43:58.616293
# AZD0530’s final rmse value is = 0.653317
# AZD0530 R-squared value is = -0.148020
# AZD6244_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:43:58.758891
# StartTime : 2019-12-12 18:43:58.759895
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:03.671779
# AZD6244’s final rmse value is = 1.546536
# AZD6244 R-squared value is = 0.100750
# Erlotinib_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:03.810405
# StartTime : 2019-12-12 18:44:03.810405
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:09.209968
# Erlotinib’s final rmse value is = 0.648159
# Erlotinib R-squared value is = -0.252713
# Irinotecan_//n
# train_X shape: (182, 21213)
# 182 train samples
# 46 test samples
# StartTime : 2019-12-12 18:44:09.293744
# StartTime : 2019-12-12 18:44:09.293744
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:10.941311
# Irinotecan’s final rmse value is = 1.860263
# Irinotecan R-squared value is = -1.381206
# L-685458_//n
# train_X shape: (292, 21213)
# 292 train samples
# 73 test samples
# StartTime : 2019-12-12 18:44:11.066977
# StartTime : 2019-12-12 18:44:11.066977
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:16.006799
# L-685458’s final rmse value is = 1.249555
# L-685458 R-squared value is = -0.669050
# Lapatinib_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:16.145397
# StartTime : 2019-12-12 18:44:16.145397
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:22.929258
# Lapatinib’s final rmse value is = 0.891960
# Lapatinib R-squared value is = -2.398419
# LBW242_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:23.070880
# StartTime : 2019-12-12 18:44:23.070880
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:26.100778
# LBW242’s final rmse value is = 1.321105
# LBW242 R-squared value is = -0.065596
# Nilotinib_//n
# train_X shape: (247, 21213)
# 247 train samples
# 62 test samples
# StartTime : 2019-12-12 18:44:26.211481
# StartTime : 2019-12-12 18:44:26.211481
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:29.709160
# Nilotinib’s final rmse value is = 1.158123
# Nilotinib R-squared value is = -0.198048
# Nutlin-3_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:29.836810
# StartTime : 2019-12-12 18:44:29.836810
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:32.337104
# Nutlin-3’s final rmse value is = 0.340301
# Nutlin-3 R-squared value is = -4.676202
# Paclitaxel_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:32.463794
# StartTime : 2019-12-12 18:44:32.464761
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:39.455098
# Paclitaxel’s final rmse value is = 2.591616
# Paclitaxel R-squared value is = -0.482814
# Panobinostat_//n
# train_X shape: (300, 21213)
# 300 train samples
# 75 test samples
# StartTime : 2019-12-12 18:44:39.585750
# StartTime : 2019-12-12 18:44:39.585750
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:45.552797
# Panobinostat’s final rmse value is = 1.206987
# Panobinostat R-squared value is = -1.135264
# PD-0325901_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:45.687408
# StartTime : 2019-12-12 18:44:45.687408
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:50.343956
# PD-0325901’s final rmse value is = 2.082279
# PD-0325901 R-squared value is = 0.107947
# PD-0332991_//n
# train_X shape: (257, 21213)
# 257 train samples
# 65 test samples
# StartTime : 2019-12-12 18:44:50.461643
# StartTime : 2019-12-12 18:44:50.462640
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:52.666775
# PD-0332991’s final rmse value is = 0.766209
# PD-0332991 R-squared value is = -0.120854
# PF2341066_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:52.815348
# StartTime : 2019-12-12 18:44:52.815348
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:44:59.555328
# PF2341066’s final rmse value is = 0.631940
# PF2341066 R-squared value is = -0.145143
# PHA-665752_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:44:59.688970
# StartTime : 2019-12-12 18:44:59.688970
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:03.110820
# PHA-665752’s final rmse value is = 0.291499
# PHA-665752 R-squared value is = -2.374611
# PLX4720_//n
# train_X shape: (297, 21213)
# 297 train samples
# 75 test samples
# StartTime : 2019-12-12 18:45:03.240473
# StartTime : 2019-12-12 18:45:03.240473
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:06.089856
# PLX4720’s final rmse value is = 1.054853
# PLX4720 R-squared value is = -0.765577
# RAF265_//n
# train_X shape: (273, 21213)
# 273 train samples
# 69 test samples
# StartTime : 2019-12-12 18:45:06.215519
# StartTime : 2019-12-12 18:45:06.215519
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:10.816221
# RAF265’s final rmse value is = 1.274272
# RAF265 R-squared value is = -0.023630
# Sorafenib_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:10.958838
# StartTime : 2019-12-12 18:45:10.958838
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:17.776634
# Sorafenib’s final rmse value is = 0.715830
# Sorafenib R-squared value is = -0.048415
# TAE684_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:17.915239
# StartTime : 2019-12-12 18:45:17.915239
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:25.859235
# TAE684’s final rmse value is = 0.975838
# TAE684 R-squared value is = -0.073175
# TKI258_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:25.993876
# StartTime : 2019-12-12 18:45:25.993876
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:33.230527
# TKI258’s final rmse value is = 0.728777
# TKI258 R-squared value is = -0.531239
# Topotecan_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:33.362174
# StartTime : 2019-12-12 18:45:33.362174
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:40.176954
# Topotecan’s final rmse value is = 2.112663
# Topotecan R-squared value is = -0.990360
# ZD-6474_//n
# train_X shape: (297, 21213)
# 297 train samples
# 75 test samples
# StartTime : 2019-12-12 18:45:40.315598
# StartTime : 2019-12-12 18:45:40.315598
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 18:45:46.693530
# ZD-6474’s final rmse value is = 0.795095
# ZD-6474 R-squared value is = 0.004283

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.515649 -0.089940
# 1         AEW541  0.816844 -0.241044
# 2        AZD0530  0.653317 -0.148020
# 3        AZD6244  1.546536  0.100750
# 4      Erlotinib  0.648159 -0.252713
# 5     Irinotecan  1.860263 -1.381206
# 6       L-685458  1.249555 -0.669050
# 7      Lapatinib  0.891960 -2.398419
# 8         LBW242  1.321105 -0.065596
# 9      Nilotinib  1.158123 -0.198048
# 10      Nutlin-3  0.340301 -4.676202
# 11    Paclitaxel  2.591616 -0.482814
# 12  Panobinostat  1.206987 -1.135264
# 13    PD-0325901  2.082279  0.107947
# 14    PD-0332991  0.766209 -0.120854
# 15     PF2341066  0.631940 -0.145143
# 16    PHA-665752  0.291499 -2.374611
# 17       PLX4720  1.054853 -0.765577
# 18        RAF265  1.274272 -0.023630
# 19     Sorafenib  0.715830 -0.048415
# 20        TAE684  0.975838 -0.073175
# 21        TKI258  0.728777 -0.531239
# 22     Topotecan  2.112663 -0.990360
# 23       ZD-6474  0.795095  0.004283

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//RF" 
result.to_csv(workdir +'//191212_MC9K_one_drug_one_model_RF_24drugs_metrics.csv')
