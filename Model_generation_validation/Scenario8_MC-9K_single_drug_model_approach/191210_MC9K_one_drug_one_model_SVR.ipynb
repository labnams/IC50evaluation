# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"

# %%
file_list = os.listdir(workdir)

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[-1].split(".")[0]
    drug_list.append(drug_file)

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//190509_ccle_mut_ic50_aron_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-SVR-and-SVR-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    # https://towardsdatascience.com/how-to-perform-SVR-and-SVR-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    from sklearn.svm import SVR

    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    # #############################################################################
    # Fit regression model
    svr_lin = SVR(C=0.01)
    svr_lin.fit(train_X, train_y).predict(test_X)
    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = svr_lin.predict(test_X)
    predicted_value = predicted_classes
    
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//SVR//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='blue')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//SVR"   

plt.savefig(workdir +'//191212_MC9K_one_drug_one_model_SVR.png', dpi=400)
workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"
# Out:
# 17-AAG_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:41:45.100261
# StartTime : 2019-12-12 18:41:45.100261
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:47.718261
# 17-AAG’s final rmse value is = 1.453392
# 17-AAG R-squared value is = -0.002237
# AEW541_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:41:48.366527
# StartTime : 2019-12-12 18:41:48.366527
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:50.843903
# AEW541’s final rmse value is = 0.846220
# AEW541 R-squared value is = -0.331912
# AZD0530_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:41:51.448314
# StartTime : 2019-12-12 18:41:51.448314
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:53.054993
# AZD0530’s final rmse value is = 0.637160
# AZD0530 R-squared value is = -0.091938
# AZD6244_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:41:53.499803
# StartTime : 2019-12-12 18:41:53.499803
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:55.021765
# AZD6244’s final rmse value is = 1.754696
# AZD6244 R-squared value is = -0.157615
# Erlotinib_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:41:55.447622
# StartTime : 2019-12-12 18:41:55.447622
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:56.461882
# Erlotinib’s final rmse value is = 0.586790
# Erlotinib R-squared value is = -0.026725
# Irinotecan_//n
# train_X shape: (182, 21213)
# 182 train samples
# 46 test samples
# StartTime : 2019-12-12 18:41:56.737174
# StartTime : 2019-12-12 18:41:56.737174
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:57.686607
# Irinotecan’s final rmse value is = 1.205523
# Irinotecan R-squared value is = 0.000002
# L-685458_//n
# train_X shape: (292, 21213)
# 292 train samples
# 73 test samples
# StartTime : 2019-12-12 18:41:57.992793
# StartTime : 2019-12-12 18:41:57.992793
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:41:58.827564
# L-685458’s final rmse value is = 0.990012
# L-685458 R-squared value is = -0.047708
# Lapatinib_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:41:59.120774
# StartTime : 2019-12-12 18:41:59.120774
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:00.475178
# Lapatinib’s final rmse value is = 0.504300
# Lapatinib R-squared value is = -0.086335
# LBW242_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:00.858159
# StartTime : 2019-12-12 18:42:00.858159
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:01.413671
# LBW242’s final rmse value is = 1.292260
# LBW242 R-squared value is = -0.019572
# Nilotinib_//n
# train_X shape: (247, 21213)
# 247 train samples
# 62 test samples
# StartTime : 2019-12-12 18:42:01.616101
# StartTime : 2019-12-12 18:42:01.616101
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:02.337173
# Nilotinib’s final rmse value is = 1.087426
# Nilotinib R-squared value is = -0.056244
# Nutlin-3_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:02.603488
# StartTime : 2019-12-12 18:42:02.603488
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:03.001424
# Nutlin-3’s final rmse value is = 0.160140
# Nutlin-3 R-squared value is = -0.256990
# Paclitaxel_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:03.205851
# StartTime : 2019-12-12 18:42:03.205851
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:05.824847
# Paclitaxel’s final rmse value is = 2.244718
# Paclitaxel R-squared value is = -0.112420
# Panobinostat_//n
# train_X shape: (300, 21213)
# 300 train samples
# 75 test samples
# StartTime : 2019-12-12 18:42:06.469125
# StartTime : 2019-12-12 18:42:06.469125
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:08.887686
# Panobinostat’s final rmse value is = 0.829740
# Panobinostat R-squared value is = -0.009091
# PD-0325901_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:09.502015
# StartTime : 2019-12-12 18:42:09.503012
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:11.965429
# PD-0325901’s final rmse value is = 2.615285
# PD-0325901 R-squared value is = -0.407183
# PD-0332991_//n
# train_X shape: (257, 21213)
# 257 train samples
# 65 test samples
# StartTime : 2019-12-12 18:42:12.549867
# StartTime : 2019-12-12 18:42:12.549867
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:13.188195
# PD-0332991’s final rmse value is = 0.756109
# PD-0332991 R-squared value is = -0.091499
# PF2341066_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:13.453459
# StartTime : 2019-12-12 18:42:13.453459
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:15.365339
# PF2341066’s final rmse value is = 0.612765
# PF2341066 R-squared value is = -0.076707
# PHA-665752_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:15.892928
# StartTime : 2019-12-12 18:42:15.892928
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:16.563136
# PHA-665752’s final rmse value is = 0.171763
# PHA-665752 R-squared value is = -0.171676
# PLX4720_//n
# train_X shape: (297, 21213)
# 297 train samples
# 75 test samples
# StartTime : 2019-12-12 18:42:16.814464
# StartTime : 2019-12-12 18:42:16.815461
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:17.524564
# PLX4720’s final rmse value is = 0.800232
# PLX4720 R-squared value is = -0.016096
# RAF265_//n
# train_X shape: (273, 21213)
# 273 train samples
# 69 test samples
# StartTime : 2019-12-12 18:42:17.787860
# StartTime : 2019-12-12 18:42:17.787860
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:19.998950
# RAF265’s final rmse value is = 1.270580
# RAF265 R-squared value is = -0.017706
# Sorafenib_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:20.545488
# StartTime : 2019-12-12 18:42:20.545488
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:21.690453
# Sorafenib’s final rmse value is = 0.704843
# Sorafenib R-squared value is = -0.016477
# TAE684_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:22.028525
# StartTime : 2019-12-12 18:42:22.029520
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:24.752276
# TAE684’s final rmse value is = 1.026261
# TAE684 R-squared value is = -0.186946
# TKI258_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:25.413472
# StartTime : 2019-12-12 18:42:25.413472
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:27.831008
# TKI258’s final rmse value is = 0.655791
# TKI258 R-squared value is = -0.239892
# Topotecan_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:42:28.431429
# StartTime : 2019-12-12 18:42:28.431429
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:31.192041
# Topotecan’s final rmse value is = 1.570611
# Topotecan R-squared value is = -0.100040
# ZD-6474_//n
# train_X shape: (297, 21213)
# 297 train samples
# 75 test samples
# StartTime : 2019-12-12 18:42:31.869211
# StartTime : 2019-12-12 18:42:31.870207
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 18:42:33.852909
# ZD-6474’s final rmse value is = 0.883110
# ZD-6474 R-squared value is = -0.228365

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.453392 -0.002237
# 1         AEW541  0.846220 -0.331912
# 2        AZD0530  0.637160 -0.091938
# 3        AZD6244  1.754696 -0.157615
# 4      Erlotinib  0.586790 -0.026725
# 5     Irinotecan  1.205523  0.000002
# 6       L-685458  0.990012 -0.047708
# 7      Lapatinib  0.504300 -0.086335
# 8         LBW242  1.292260 -0.019572
# 9      Nilotinib  1.087426 -0.056244
# 10      Nutlin-3  0.160140 -0.256990
# 11    Paclitaxel  2.244718 -0.112420
# 12  Panobinostat  0.829740 -0.009091
# 13    PD-0325901  2.615285 -0.407183
# 14    PD-0332991  0.756109 -0.091499
# 15     PF2341066  0.612765 -0.076707
# 16    PHA-665752  0.171763 -0.171676
# 17       PLX4720  0.800232 -0.016096
# 18        RAF265  1.270580 -0.017706
# 19     Sorafenib  0.704843 -0.016477
# 20        TAE684  1.026261 -0.186946
# 21        TKI258  0.655791 -0.239892
# 22     Topotecan  1.570611 -0.100040
# 23       ZD-6474  0.883110 -0.228365

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//SVR" 
result.to_csv(workdir +'//191212_MC9K_one_drug_one_model_SVR_24drugs_metrics.csv')
