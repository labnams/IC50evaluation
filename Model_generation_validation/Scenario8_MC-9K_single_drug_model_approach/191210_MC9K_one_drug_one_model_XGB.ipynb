# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario8_MC-9K_single_drug_model_approach

workdir = "path"

# %%
file_list = os.listdir(workdir)

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[-1].split(".")[0]
    drug_list.append(drug_file)

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//190509_ccle_mut_ic50_aron_%s.npz" % dname) # input file names. please make indified prefix of each file names
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-peXGBorm-XGB-and-XGB-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    # https://towardsdatascience.com/how-to-peXGBorm-XGB-and-XGB-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    

    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    import xgboost as xgb
    model = xgb.XGBRegressor()
    model.fit(train_X,train_y)
    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)


    predicted_classes = model.predict(test_X)
    predicted_value = predicted_classes
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//XGB//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='blue')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//XGB"   

plt.savefig(workdir +'//191212_MC9K_one_drug_one_model_XGB.png', dpi=400)
workdir = "D://ResIC50_finalized_data//Dataset//Small_dataset_CCLE//ccle_each_24_drugs//mut"
# Out:
# 17-AAG_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:09.012044
# StartTime : 2019-12-12 18:45:09.012044
# StartTime : 2019-12-12 18:45:09.013040
# StartTime : 2019-12-12 18:45:09.013040
# [18:45:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:45:33.133785
# 17-AAG’s final rmse value is = 1.474992
# 17-AAG R-squared value is = -0.032249
# AEW541_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:33.308346
# StartTime : 2019-12-12 18:45:33.308346
# StartTime : 2019-12-12 18:45:33.308346
# StartTime : 2019-12-12 18:45:33.308346
# [18:45:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:45:57.991321
# AEW541’s final rmse value is = 0.792848
# AEW541 R-squared value is = -0.169200
# AZD0530_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:45:58.188821
# StartTime : 2019-12-12 18:45:58.189790
# StartTime : 2019-12-12 18:45:58.189790
# StartTime : 2019-12-12 18:45:58.189790
# [18:45:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:46:22.453942
# AZD0530’s final rmse value is = 0.625005
# AZD0530 R-squared value is = -0.050674
# AZD6244_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:46:22.666372
# StartTime : 2019-12-12 18:46:22.666372
# StartTime : 2019-12-12 18:46:22.666372
# StartTime : 2019-12-12 18:46:22.666372
# [18:46:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:46:44.551436
# AZD6244’s final rmse value is = 1.557034
# AZD6244 R-squared value is = 0.088499
# Erlotinib_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:46:44.714002
# StartTime : 2019-12-12 18:46:44.714002
# StartTime : 2019-12-12 18:46:44.714002
# StartTime : 2019-12-12 18:46:44.714002
# [18:46:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:47:06.666308
# Erlotinib’s final rmse value is = 0.709853
# Erlotinib R-squared value is = -0.502539
# Irinotecan_//n
# train_X shape: (182, 21213)
# 182 train samples
# 46 test samples
# StartTime : 2019-12-12 18:47:06.793992
# StartTime : 2019-12-12 18:47:06.793992
# StartTime : 2019-12-12 18:47:06.793992
# StartTime : 2019-12-12 18:47:06.793992
# [18:47:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:47:21.552503
# Irinotecan’s final rmse value is = 1.203831
# Irinotecan R-squared value is = 0.002808
# L-685458_//n
# train_X shape: (292, 21213)
# 292 train samples
# 73 test samples
# StartTime : 2019-12-12 18:47:21.707091
# StartTime : 2019-12-12 18:47:21.707091
# StartTime : 2019-12-12 18:47:21.707091
# StartTime : 2019-12-12 18:47:21.707091
# [18:47:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:47:42.930371
# L-685458’s final rmse value is = 1.013198
# L-685458 R-squared value is = -0.097355
# Lapatinib_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:47:43.105883
# StartTime : 2019-12-12 18:47:43.105883
# StartTime : 2019-12-12 18:47:43.105883
# StartTime : 2019-12-12 18:47:43.105883
# [18:47:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:48:05.463097
# Lapatinib’s final rmse value is = 0.523967
# Lapatinib R-squared value is = -0.172718
# LBW242_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:48:05.628680
# StartTime : 2019-12-12 18:48:05.628680
# StartTime : 2019-12-12 18:48:05.628680
# StartTime : 2019-12-12 18:48:05.628680
# [18:48:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:48:27.354563
# LBW242’s final rmse value is = 1.316326
# LBW242 R-squared value is = -0.057902
# Nilotinib_//n
# train_X shape: (247, 21213)
# 247 train samples
# 62 test samples
# StartTime : 2019-12-12 18:48:27.499187
# StartTime : 2019-12-12 18:48:27.499187
# StartTime : 2019-12-12 18:48:27.499187
# StartTime : 2019-12-12 18:48:27.499187
# [18:48:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:48:46.658946
# Nilotinib’s final rmse value is = 1.375383
# Nilotinib R-squared value is = -0.689710
# Nutlin-3_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:48:46.822510
# StartTime : 2019-12-12 18:48:46.822510
# StartTime : 2019-12-12 18:48:46.822510
# StartTime : 2019-12-12 18:48:46.822510
# [18:48:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:49:08.461651
# Nutlin-3’s final rmse value is = 0.151099
# Nutlin-3 R-squared value is = -0.119072
# Paclitaxel_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:49:08.636185
# StartTime : 2019-12-12 18:49:08.636185
# StartTime : 2019-12-12 18:49:08.636185
# StartTime : 2019-12-12 18:49:08.636185
# [18:49:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:49:30.427917
# Paclitaxel’s final rmse value is = 2.136202
# Paclitaxel R-squared value is = -0.007465
# Panobinostat_//n
# train_X shape: (300, 21213)
# 300 train samples
# 75 test samples
# StartTime : 2019-12-12 18:49:30.600457
# StartTime : 2019-12-12 18:49:30.600457
# StartTime : 2019-12-12 18:49:30.600457
# StartTime : 2019-12-12 18:49:30.600457
# [18:49:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:49:52.483973
# Panobinostat’s final rmse value is = 0.801382
# Panobinostat R-squared value is = 0.058704
# PD-0325901_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:49:52.662468
# StartTime : 2019-12-12 18:49:52.663478
# StartTime : 2019-12-12 18:49:52.663478
# StartTime : 2019-12-12 18:49:52.663478
# [18:49:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:50:14.560139
# PD-0325901’s final rmse value is = 1.914340
# PD-0325901 R-squared value is = 0.246036
# PD-0332991_//n
# train_X shape: (257, 21213)
# 257 train samples
# 65 test samples
# StartTime : 2019-12-12 18:50:14.710734
# StartTime : 2019-12-12 18:50:14.710734
# StartTime : 2019-12-12 18:50:14.710734
# StartTime : 2019-12-12 18:50:14.710734
# [18:50:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:50:33.929282
# PD-0332991’s final rmse value is = 0.768932
# PD-0332991 R-squared value is = -0.128836
# PF2341066_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:50:34.096833
# StartTime : 2019-12-12 18:50:34.096833
# StartTime : 2019-12-12 18:50:34.096833
# StartTime : 2019-12-12 18:50:34.096833
# [18:50:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:50:56.015398
# PF2341066’s final rmse value is = 0.688984
# PF2341066 R-squared value is = -0.361217
# PHA-665752_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:50:56.180928
# StartTime : 2019-12-12 18:50:56.180928
# StartTime : 2019-12-12 18:50:56.180928
# StartTime : 2019-12-12 18:50:56.180928
# [18:50:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:51:17.867047
# PHA-665752’s final rmse value is = 0.158822
# PHA-665752 R-squared value is = -0.001780
# PLX4720_//n
# train_X shape: (297, 21213)
# 297 train samples
# 75 test samples
# StartTime : 2019-12-12 18:51:18.045050
# StartTime : 2019-12-12 18:51:18.045050
# StartTime : 2019-12-12 18:51:18.045050
# StartTime : 2019-12-12 18:51:18.045050
# [18:51:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:51:39.538249
# PLX4720’s final rmse value is = 0.698798
# PLX4720 R-squared value is = 0.225169
# RAF265_//n
# train_X shape: (273, 21213)
# 273 train samples
# 69 test samples
# StartTime : 2019-12-12 18:51:39.713813
# StartTime : 2019-12-12 18:51:39.713813
# StartTime : 2019-12-12 18:51:39.713813
# StartTime : 2019-12-12 18:51:39.713813
# [18:51:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:51:59.771088
# RAF265’s final rmse value is = 1.243252
# RAF265 R-squared value is = 0.025600
# Sorafenib_//n
# train_X shape: (301, 21213)
# 301 train samples
# 76 test samples
# StartTime : 2019-12-12 18:51:59.939638
# StartTime : 2019-12-12 18:51:59.939638
# StartTime : 2019-12-12 18:51:59.939638
# StartTime : 2019-12-12 18:51:59.939638
# [18:52:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:52:21.339092
# Sorafenib’s final rmse value is = 0.713959
# Sorafenib R-squared value is = -0.042940
# TAE684_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:52:21.503624
# StartTime : 2019-12-12 18:52:21.503624
# StartTime : 2019-12-12 18:52:21.503624
# StartTime : 2019-12-12 18:52:21.503624
# [18:52:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:52:43.003168
# TAE684’s final rmse value is = 1.014414
# TAE684 R-squared value is = -0.159701
# TKI258_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:52:43.169716
# StartTime : 2019-12-12 18:52:43.170691
# StartTime : 2019-12-12 18:52:43.170691
# StartTime : 2019-12-12 18:52:43.170691
# [18:52:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:53:05.014312
# TKI258’s final rmse value is = 0.602448
# TKI258 R-squared value is = -0.046385
# Topotecan_//n
# train_X shape: (302, 21213)
# 302 train samples
# 76 test samples
# StartTime : 2019-12-12 18:53:05.188819
# StartTime : 2019-12-12 18:53:05.188819
# StartTime : 2019-12-12 18:53:05.188819
# StartTime : 2019-12-12 18:53:05.188819
# [18:53:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:53:26.828957
# Topotecan’s final rmse value is = 1.563471
# Topotecan R-squared value is = -0.090062
# ZD-6474_//n
# train_X shape: (297, 21213)
# 297 train samples
# 75 test samples
# StartTime : 2019-12-12 18:53:27.004488
# StartTime : 2019-12-12 18:53:27.004488
# StartTime : 2019-12-12 18:53:27.004488
# StartTime : 2019-12-12 18:53:27.004488
# [18:53:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 18:53:48.204804
# ZD-6474’s final rmse value is = 0.768437
# ZD-6474 R-squared value is = 0.069934

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.474992 -0.032249
# 1         AEW541  0.792848 -0.169200
# 2        AZD0530  0.625005 -0.050674
# 3        AZD6244  1.557034  0.088499
# 4      Erlotinib  0.709853 -0.502539
# 5     Irinotecan  1.203831  0.002808
# 6       L-685458  1.013198 -0.097355
# 7      Lapatinib  0.523967 -0.172718
# 8         LBW242  1.316326 -0.057902
# 9      Nilotinib  1.375383 -0.689710
# 10      Nutlin-3  0.151099 -0.119072
# 11    Paclitaxel  2.136202 -0.007465
# 12  Panobinostat  0.801382  0.058704
# 13    PD-0325901  1.914340  0.246036
# 14    PD-0332991  0.768932 -0.128836
# 15     PF2341066  0.688984 -0.361217
# 16    PHA-665752  0.158822 -0.001780
# 17       PLX4720  0.698798  0.225169
# 18        RAF265  1.243252  0.025600
# 19     Sorafenib  0.713959 -0.042940
# 20        TAE684  1.014414 -0.159701
# 21        TKI258  0.602448 -0.046385
# 22     Topotecan  1.563471 -0.090062
# 23       ZD-6474  0.768437  0.069934

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//MC-9K//individual_drugs//XGB" 
result.to_csv(workdir +'//191212_MC9K_one_drug_one_model_XGB_24drugs_metrics.csv')
