# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario4_EC-11K_znorm_single_drug_model_approach//individual_drugs

workdir = "path//individual_drugs"

# %%
file_list = os.listdir(workdir)[0:-1]

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[2].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list)
# Out:
# 24

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//191212_EC11K_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-RF-and-RF-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    # #############################################################################
    # Fit regression model
    rf = RandomForestRegressor(random_state = 84)
    # Train the model on training data
    rf.fit(train_X, train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)


    predicted_classes = rf.predict(test_X)
    predicted_value = predicted_classes
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//RF//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//RF"    

plt.savefig(workdir +'//191210_EC11K_one_drug_one_model_RF.png', dpi=400)
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
# Out:
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:20:28.043528
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:20:52.164036
# 17-AAG’s final rmse value is = 1.321049
# 17-AAG R-squared value is = 0.077565
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:20:52.434310
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:21:41.641769
# AEW541’s final rmse value is = 0.879752
# AEW541 R-squared value is = 0.117912
# AZD0530_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:21:41.904070
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:22:33.090980
# AZD0530’s final rmse value is = 0.829584
# AZD0530 R-squared value is = -0.120143
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:22:33.355241
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:23:05.123547
# AZD6244’s final rmse value is = 1.445645
# AZD6244 R-squared value is = 0.107870
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:23:05.402802
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:23:53.796982
# Erlotinib’s final rmse value is = 0.609853
# Erlotinib R-squared value is = -0.156908
# Irinotecan_//n
# train_X shape: (244, 18988)
# 244 train samples
# 62 test samples
# StartTime : 2019-12-12 17:23:53.971548
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:24:05.590450
# Irinotecan’s final rmse value is = 1.407915
# Irinotecan R-squared value is = 0.168204
# L-685458_//n
# train_X shape: (382, 18988)
# 382 train samples
# 96 test samples
# StartTime : 2019-12-12 17:24:05.847763
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:24:57.569470
# L-685458’s final rmse value is = 0.582502
# L-685458 R-squared value is = 0.109228
# Lapatinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:24:57.873655
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:25:55.232290
# Lapatinib’s final rmse value is = 0.656735
# Lapatinib R-squared value is = 0.197452
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:25:55.523523
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:26:22.030668
# LBW242’s final rmse value is = 1.178801
# LBW242 R-squared value is = -0.067275
# Nilotinib_//n
# train_X shape: (325, 18988)
# 325 train samples
# 82 test samples
# StartTime : 2019-12-12 17:26:22.275980
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:27:10.987764
# Nilotinib’s final rmse value is = 0.987952
# Nilotinib R-squared value is = 0.125873
# Nutlin-3_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:27:11.252059
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:27:40.017181
# Nutlin-3’s final rmse value is = 0.247769
# Nutlin-3 R-squared value is = -0.080880
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:27:40.369232
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:28:18.616251
# Paclitaxel’s final rmse value is = 1.820378
# Paclitaxel R-squared value is = 0.002848
# Panobinostat_//n
# train_X shape: (389, 18988)
# 389 train samples
# 98 test samples
# StartTime : 2019-12-12 17:28:18.895504
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:28:42.099461
# Panobinostat’s final rmse value is = 0.725995
# Panobinostat R-squared value is = 0.351089
# PD-0325901_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:28:42.376752
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:29:20.440979
# PD-0325901’s final rmse value is = 2.037787
# PD-0325901 R-squared value is = 0.184778
# PD-0332991_//n
# train_X shape: (336, 18988)
# 336 train samples
# 85 test samples
# StartTime : 2019-12-12 17:29:20.704241
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:29:50.973337
# PD-0332991’s final rmse value is = 0.650126
# PD-0332991 R-squared value is = -0.132600
# PF2341066_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:29:51.280486
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:30:50.912070
# PF2341066’s final rmse value is = 0.714078
# PF2341066 R-squared value is = 0.025842
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:30:51.190319
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:31:25.616280
# PHA-665752’s final rmse value is = 0.472480
# PHA-665752 R-squared value is = -0.390665
# PLX4720_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:31:25.896529
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:31:59.356066
# PLX4720’s final rmse value is = 0.641534
# PLX4720 R-squared value is = 0.307121
# RAF265_//n
# train_X shape: (357, 18988)
# 357 train samples
# 90 test samples
# StartTime : 2019-12-12 17:31:59.606368
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:32:22.065018
# RAF265’s final rmse value is = 1.231417
# RAF265 R-squared value is = -0.040210
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:32:22.363221
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:33:23.876776
# Sorafenib’s final rmse value is = 0.312308
# Sorafenib R-squared value is = -0.567194
# TAE684_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:33:24.174949
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:34:02.908411
# TAE684’s final rmse value is = 0.979178
# TAE684 R-squared value is = 0.104817
# TKI258_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:34:03.199603
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:34:52.484410
# TKI258’s final rmse value is = 0.793213
# TKI258 R-squared value is = 0.187956
# Topotecan_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:34:52.786602
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:35:15.171720
# Topotecan’s final rmse value is = 1.351833
# Topotecan R-squared value is = 0.308989
# ZD-6474_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:35:15.452969
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# EndTime : 2019-12-12 17:36:02.136945
# ZD-6474’s final rmse value is = 0.752095
# ZD-6474 R-squared value is = 0.151779

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.321049  0.077565
# 1         AEW541  0.879752  0.117912
# 2        AZD0530  0.829584 -0.120143
# 3        AZD6244  1.445645  0.107870
# 4      Erlotinib  0.609853 -0.156908
# 5     Irinotecan  1.407915  0.168204
# 6       L-685458  0.582502  0.109228
# 7      Lapatinib  0.656735  0.197452
# 8         LBW242  1.178801 -0.067275
# 9      Nilotinib  0.987952  0.125873
# 10      Nutlin-3  0.247769 -0.080880
# 11    Paclitaxel  1.820378  0.002848
# 12  Panobinostat  0.725995  0.351089
# 13    PD-0325901  2.037787  0.184778
# 14    PD-0332991  0.650126 -0.132600
# 15     PF2341066  0.714078  0.025842
# 16    PHA-665752  0.472480 -0.390665
# 17       PLX4720  0.641534  0.307121
# 18        RAF265  1.231417 -0.040210
# 19     Sorafenib  0.312308 -0.567194
# 20        TAE684  0.979178  0.104817
# 21        TKI258  0.793213  0.187956
# 22     Topotecan  1.351833  0.308989
# 23       ZD-6474  0.752095  0.151779

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//RF" 
result.to_csv(workdir +'//191212_EC11K_one_drug_one_model_RF_24drugs_metrics.csv')
