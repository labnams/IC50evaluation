# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario4_EC-11K_znorm_single_drug_model_approach//individual_drugs

workdir = "path//individual_drugs"

# %%
file_list = os.listdir(workdir)[0:-1]

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[2].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list)
# Out:
# 24

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//191212_EC11K_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-ridge-and-ridge-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    ridge_regressor = Ridge(alpha=0.001)
    ridge_regressor.fit(train_X,train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = ridge_regressor.predict(test_X)
    predicted_value = predicted_classes
        
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//Ridge//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//ridge"    

plt.savefig(workdir +'//191210_EC11K_one_drug_one_model_ridge.png', dpi=400)
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
# Out:
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:21.909356
# EndTime : 2019-12-12 17:19:21.966203
# 17-AAG’s final rmse value is = 1.206891
# 17-AAG R-squared value is = 0.230100
# AEW541_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.194198e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:22.239494
# EndTime : 2019-12-12 17:19:22.289338
# AEW541’s final rmse value is = 0.868574
# AEW541 R-squared value is = 0.140184
# AZD0530_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.209163e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:22.553654
# EndTime : 2019-12-12 17:19:22.603499
# AZD0530’s final rmse value is = 0.790930
# AZD0530 R-squared value is = -0.018189
# AZD6244_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:22.880757
# EndTime : 2019-12-12 17:19:22.934613
# AZD6244’s final rmse value is = 1.552694
# AZD6244 R-squared value is = -0.029146
# Erlotinib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number9.081139e-10
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:23.210876
# EndTime : 2019-12-12 17:19:23.268720
# Erlotinib’s final rmse value is = 0.626565
# Erlotinib R-squared value is = -0.221183
# Irinotecan_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.209163e-09
#   overwrite_a=False)
# train_X shape: (244, 18988)
# 244 train samples
# 62 test samples
# StartTime : 2019-12-12 17:19:23.463201
# EndTime : 2019-12-12 17:19:23.510075
# Irinotecan’s final rmse value is = 1.340346
# Irinotecan R-squared value is = 0.246127
# L-685458_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.319066e-09
#   overwrite_a=False)
# train_X shape: (382, 18988)
# 382 train samples
# 96 test samples
# StartTime : 2019-12-12 17:19:23.777361
# EndTime : 2019-12-12 17:19:23.829221
# L-685458’s final rmse value is = 0.564195
# L-685458 R-squared value is = 0.164340
# Lapatinib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number6.066736e-10
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:24.094512
# EndTime : 2019-12-12 17:19:24.144378
# Lapatinib’s final rmse value is = 0.746447
# Lapatinib R-squared value is = -0.036785
# LBW242_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:24.412662
# EndTime : 2019-12-12 17:19:24.464524
# LBW242’s final rmse value is = 1.186578
# LBW242 R-squared value is = -0.081404
# Nilotinib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number9.081139e-10
#   overwrite_a=False)
# train_X shape: (325, 18988)
# 325 train samples
# 82 test samples
# StartTime : 2019-12-12 17:19:24.694907
# EndTime : 2019-12-12 17:19:24.736795
# Nilotinib’s final rmse value is = 1.007042
# Nilotinib R-squared value is = 0.091765
# Nutlin-3_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.154755e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:25.009068
# EndTime : 2019-12-12 17:19:25.059931
# Nutlin-3’s final rmse value is = 0.276950
# Nutlin-3 R-squared value is = -0.350468
# Paclitaxel_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:25.326219
# EndTime : 2019-12-12 17:19:25.378080
# Paclitaxel’s final rmse value is = 1.829317
# Paclitaxel R-squared value is = -0.006970
# Panobinostat_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number7.294511e-10
#   overwrite_a=False)
# train_X shape: (389, 18988)
# 389 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:25.640380
# EndTime : 2019-12-12 17:19:25.691243
# Panobinostat’s final rmse value is = 0.696859
# Panobinostat R-squared value is = 0.402128
# PD-0325901_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269713e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:25.963515
# EndTime : 2019-12-12 17:19:26.022357
# PD-0325901’s final rmse value is = 1.988263
# PD-0325901 R-squared value is = 0.223921
# PD-0332991_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (336, 18988)
# 336 train samples
# 85 test samples
# StartTime : 2019-12-12 17:19:26.259756
# EndTime : 2019-12-12 17:19:26.304603
# PD-0332991’s final rmse value is = 0.648885
# PD-0332991 R-squared value is = -0.128283
# PF2341066_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.113948e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:26.571916
# EndTime : 2019-12-12 17:19:26.624747
# PF2341066’s final rmse value is = 0.685082
# PF2341066 R-squared value is = 0.103349
# PHA-665752_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:26.888071
# EndTime : 2019-12-12 17:19:26.944890
# PHA-665752’s final rmse value is = 0.491214
# PHA-665752 R-squared value is = -0.503131
# PLX4720_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number9.081139e-10
#   overwrite_a=False)
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:19:27.232125
# EndTime : 2019-12-12 17:19:27.288971
# PLX4720’s final rmse value is = 0.648137
# PLX4720 R-squared value is = 0.292784
# RAF265_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.186116e-09
#   overwrite_a=False)
# train_X shape: (357, 18988)
# 357 train samples
# 90 test samples
# StartTime : 2019-12-12 17:19:27.549275
# EndTime : 2019-12-12 17:19:27.597147
# RAF265’s final rmse value is = 1.174782
# RAF265 R-squared value is = 0.053272
# Sorafenib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.207884e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:19:27.941227
# EndTime : 2019-12-12 17:19:27.997077
# Sorafenib’s final rmse value is = 0.372292
# Sorafenib R-squared value is = -1.227022
# TAE684_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.031193e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:28.261371
# EndTime : 2019-12-12 17:19:28.311237
# TAE684’s final rmse value is = 0.947786
# TAE684 R-squared value is = 0.161295
# TKI258_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:28.565591
# EndTime : 2019-12-12 17:19:28.616421
# TKI258’s final rmse value is = 0.850872
# TKI258 R-squared value is = 0.065609
# Topotecan_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:19:28.886701
# EndTime : 2019-12-12 17:19:28.942551
# Topotecan’s final rmse value is = 1.400154
# Topotecan R-squared value is = 0.258707
# ZD-6474_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.269684e-09
#   overwrite_a=False)
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:19:29.212854
# EndTime : 2019-12-12 17:19:29.262693
# ZD-6474’s final rmse value is = 0.743308
# ZD-6474 R-squared value is = 0.171484
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\ridge.py:165: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number1.186116e-09
#   overwrite_a=False)

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.206891  0.230100
# 1         AEW541  0.868574  0.140184
# 2        AZD0530  0.790930 -0.018189
# 3        AZD6244  1.552694 -0.029146
# 4      Erlotinib  0.626565 -0.221183
# 5     Irinotecan  1.340346  0.246127
# 6       L-685458  0.564195  0.164340
# 7      Lapatinib  0.746447 -0.036785
# 8         LBW242  1.186578 -0.081404
# 9      Nilotinib  1.007042  0.091765
# 10      Nutlin-3  0.276950 -0.350468
# 11    Paclitaxel  1.829317 -0.006970
# 12  Panobinostat  0.696859  0.402128
# 13    PD-0325901  1.988263  0.223921
# 14    PD-0332991  0.648885 -0.128283
# 15     PF2341066  0.685082  0.103349
# 16    PHA-665752  0.491214 -0.503131
# 17       PLX4720  0.648137  0.292784
# 18        RAF265  1.174782  0.053272
# 19     Sorafenib  0.372292 -1.227022
# 20        TAE684  0.947786  0.161295
# 21        TKI258  0.850872  0.065609
# 22     Topotecan  1.400154  0.258707
# 23       ZD-6474  0.743308  0.171484

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//Ridge" 
result.to_csv(workdir +'//191212_EC11K_one_drug_one_model_Ridge_24drugs_metrics.csv')
