# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import random
from pandas import DataFrame
from datetime import datetime
import keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten, Reshape, Activation
from keras.layers import Conv1D, MaxPooling1D ,AveragePooling1D
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras import backend as K
# from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
#from tensorflow.keras.optimizers import Adam
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario4_EC-11K_znorm_single_drug_model_approach//individual_drugs

workdir = "path//individual_drugs"
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())


# 출처: https://3months.tistory.com/206 [Deep Play]
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4887251895674363940
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 18038862643
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15492829506255343551
# physical_device_desc: "device: 0, name: TITAN RTX, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
file_list = os.listdir(workdir)

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[2].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list[0:12])
# Out:
# 12

# %%
# In[21]:

num_classes = 1
learning_rate = 0.0002
training_epochs = 40
batch_size = 50
# img_rows, img_cols = 154, 154

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list[12::])):
    dname = drug_list[num+12]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//191212_EC11K_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.reshape(train_X.shape[0], train_X.shape[1],1)
    test_X = test_X.reshape(test_X.shape[0], test_X.shape[1],1)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-lasso-and-lasso-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    # In[10]:
    with K.tf.device('/GPU:0'):
        inputs = Input(shape=(train_X.shape[1],1),name='inputs')

        x = Conv1D(16, kernel_size=3, strides=2, padding="same")(inputs)
        x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
    #     y = x
        x = Activation('tanh')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)


        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)


        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)

        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)


        x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=2, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
    #     x = BatchNormalization()(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)


        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=2, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
    #     x = BatchNormalization()(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)


        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        y = x
        x = Activation('relu')(x)

        x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
    #     x = MaxPooling1D(pool_size=5)(x)
        x = BatchNormalization()(x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

    #     x = AveragePooling1D(pool_size=8)(x)
        x = Flatten()(x)
        x = Dense(units=2048, name='dense1'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout1') (x)
        x = Activation('relu')(x)

    #    x = Reshape((300,1))(x)

    #    x = Conv1D(30, kernel_size=150, strides=1, activation = 'relu')(x)
    #    x = MaxPooling1D(pool_size=2)(x)
    #    x = BatchNormalization()(x)

        x = Dense(units=1024, name='dense5'  ) (x)
        x = BatchNormalization()(x)
        y = x
        x = Dropout(0.1, name='dropout5') (x)
        x = Activation('relu')(x)

        x = Dense(units=512, name='dense6'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout6') (x)
        x = Activation('relu')(x)

        x = Dense(units=1024, name='dense7'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout7') (x)
        x = keras.layers.add([x,y])
        x = Activation('relu')(x)

        x = Dense(units=512, name='dense8'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout8') (x)
        x = Activation('relu')(x)

        x = Dense(units=256, name='dense9'  ) (x)
        x = BatchNormalization()(x)
        x = Dropout(0.1, name='dropout9') (x)
        x = Activation('relu')(x)

        x = Dense(units=128, name='dense10'  ) (x)
        x = BatchNormalization()(x)
        y = x
        x = Dropout(0.1, name='dropout10') (x)
        x = Activation('relu')(x)


        predictions = Dense(1, activation='linear', name='predictions', kernel_initializer='he_normal')(x)
    #     predictions = Dense(1, activation='linear', name='predictions')(x)



        model = Model(inputs=inputs, outputs=predictions, name='Test_v2_DNN20190327')
        model.compile(loss=keras.losses.mean_squared_error,
                      optimizer=keras.optimizers.Adam(learning_rate),
                      metrics=['mse','mae'])
        EndTime8 = datetime.now()
        print("EndTime :", EndTime8)
    
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    with K.tf.device('/GPU:0'):
        model_train = model.fit(train_X, train_y, batch_size=batch_size,epochs=training_epochs,verbose=1,
                            validation_data=(test_X, test_y))

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = model.predict(test_X)
    predicted_value = predicted_classes
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Result//EC-11K_individual_drugs//191212//ResNet//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)

    config = tf.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 0.7
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    # status initialize

    import os
    os.environ['CUDA_VISIBLE_DEVICES'] = '0' 

    # out of memory
    import tensorflow as tf
    with tf.Graph().as_default():
      gpu_options = tf.GPUOptions(allow_growth=True)

    workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Dataset//EC11K_Znorm//191212_EC11K_individual_drugs"
workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Result//EC-11K_individual_drugs//191212//ResNet"

plt.savefig(workdir +'//191210_EC11K_one_drug_one_model_other_12drugs_ResNet.png', dpi=400)
workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Dataset//EC11K_Znorm//191212_EC11K_individual_drugs"
# Out:
# Panobinostat_//n
# train_X shape: (389, 18988, 1)
# 389 train samples
# 98 test samples
# StartTime : 2019-12-13 00:04:07.702902
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ronnytf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ronnytf\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# EndTime : 2019-12-13 00:04:10.635902
# StartTime : 2019-12-13 00:04:10.635902
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\ronnytf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 389 samples, validate on 98 samples
# Epoch 1/40
# 389/389 [==============================] - 10s 26ms/step - loss: 7.1558 - mean_squared_error: 7.1558 - mean_absolute_error: 2.4018 - val_loss: 6.8723 - val_mean_squared_error: 6.8723 - val_mean_absolute_error: 2.3380
# Epoch 2/40
# 389/389 [==============================] - 1s 2ms/step - loss: 6.2037 - mean_squared_error: 6.2037 - mean_absolute_error: 2.2846 - val_loss: 6.9331 - val_mean_squared_error: 6.9331 - val_mean_absolute_error: 2.4456
# Epoch 3/40
# 389/389 [==============================] - 1s 2ms/step - loss: 5.5021 - mean_squared_error: 5.5021 - mean_absolute_error: 2.1571 - val_loss: 5.9037 - val_mean_squared_error: 5.9037 - val_mean_absolute_error: 2.2592
# Epoch 4/40
# 389/389 [==============================] - 1s 2ms/step - loss: 5.0552 - mean_squared_error: 5.0552 - mean_absolute_error: 2.0688 - val_loss: 5.2722 - val_mean_squared_error: 5.2722 - val_mean_absolute_error: 2.1158
# Epoch 5/40
# 389/389 [==============================] - 1s 2ms/step - loss: 4.3888 - mean_squared_error: 4.3888 - mean_absolute_error: 1.9313 - val_loss: 4.9062 - val_mean_squared_error: 4.9062 - val_mean_absolute_error: 2.0271
# Epoch 6/40
# 389/389 [==============================] - 1s 2ms/step - loss: 3.9942 - mean_squared_error: 3.9942 - mean_absolute_error: 1.8177 - val_loss: 5.2214 - val_mean_squared_error: 5.2214 - val_mean_absolute_error: 2.0985
# Epoch 7/40
# 389/389 [==============================] - 1s 2ms/step - loss: 3.5453 - mean_squared_error: 3.5453 - mean_absolute_error: 1.7212 - val_loss: 5.1167 - val_mean_squared_error: 5.1167 - val_mean_absolute_error: 2.0710
# Epoch 8/40
# 389/389 [==============================] - 1s 2ms/step - loss: 3.2352 - mean_squared_error: 3.2352 - mean_absolute_error: 1.6221 - val_loss: 5.0188 - val_mean_squared_error: 5.0188 - val_mean_absolute_error: 2.0640
# Epoch 9/40
# 389/389 [==============================] - 1s 2ms/step - loss: 2.8468 - mean_squared_error: 2.8468 - mean_absolute_error: 1.5027 - val_loss: 5.0424 - val_mean_squared_error: 5.0424 - val_mean_absolute_error: 2.0801
# Epoch 10/40
# 389/389 [==============================] - 1s 2ms/step - loss: 2.7398 - mean_squared_error: 2.7398 - mean_absolute_error: 1.4740 - val_loss: 5.0304 - val_mean_squared_error: 5.0304 - val_mean_absolute_error: 2.0787
# Epoch 11/40
# 389/389 [==============================] - 1s 2ms/step - loss: 2.1894 - mean_squared_error: 2.1894 - mean_absolute_error: 1.3007 - val_loss: 5.0534 - val_mean_squared_error: 5.0534 - val_mean_absolute_error: 2.0827
# Epoch 12/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.9712 - mean_squared_error: 1.9712 - mean_absolute_error: 1.2375 - val_loss: 5.5534 - val_mean_squared_error: 5.5534 - val_mean_absolute_error: 2.1945
# Epoch 13/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.7681 - mean_squared_error: 1.7681 - mean_absolute_error: 1.1645 - val_loss: 5.6316 - val_mean_squared_error: 5.6316 - val_mean_absolute_error: 2.2135
# Epoch 14/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.6965 - mean_squared_error: 1.6965 - mean_absolute_error: 1.0952 - val_loss: 5.4915 - val_mean_squared_error: 5.4915 - val_mean_absolute_error: 2.1833
# Epoch 15/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.5126 - mean_squared_error: 1.5126 - mean_absolute_error: 1.0410 - val_loss: 5.2412 - val_mean_squared_error: 5.2412 - val_mean_absolute_error: 2.1208
# Epoch 16/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.4656 - mean_squared_error: 1.4656 - mean_absolute_error: 1.0167 - val_loss: 4.8077 - val_mean_squared_error: 4.8077 - val_mean_absolute_error: 2.0184
# Epoch 17/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.2816 - mean_squared_error: 1.2816 - mean_absolute_error: 0.9360 - val_loss: 4.8284 - val_mean_squared_error: 4.8284 - val_mean_absolute_error: 2.0206
# Epoch 18/40
# 389/389 [==============================] - 1s 2ms/step - loss: 1.0800 - mean_squared_error: 1.0800 - mean_absolute_error: 0.8645 - val_loss: 5.1395 - val_mean_squared_error: 5.1395 - val_mean_absolute_error: 2.0928
# Epoch 19/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.9551 - mean_squared_error: 0.9551 - mean_absolute_error: 0.8097 - val_loss: 5.0069 - val_mean_squared_error: 5.0069 - val_mean_absolute_error: 2.0626
# Epoch 20/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.9969 - mean_squared_error: 0.9969 - mean_absolute_error: 0.8126 - val_loss: 4.8978 - val_mean_squared_error: 4.8978 - val_mean_absolute_error: 2.0352
# Epoch 21/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.7969 - mean_squared_error: 0.7969 - mean_absolute_error: 0.7178 - val_loss: 4.6262 - val_mean_squared_error: 4.6262 - val_mean_absolute_error: 1.9668
# Epoch 22/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.6736 - mean_squared_error: 0.6736 - mean_absolute_error: 0.6701 - val_loss: 4.5620 - val_mean_squared_error: 4.5620 - val_mean_absolute_error: 1.9490
# Epoch 23/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.8023 - mean_squared_error: 0.8023 - mean_absolute_error: 0.7039 - val_loss: 4.5504 - val_mean_squared_error: 4.5504 - val_mean_absolute_error: 1.9439
# Epoch 24/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.7675 - mean_squared_error: 0.7675 - mean_absolute_error: 0.6843 - val_loss: 4.6515 - val_mean_squared_error: 4.6515 - val_mean_absolute_error: 1.9725
# Epoch 25/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.6263 - mean_squared_error: 0.6263 - mean_absolute_error: 0.6277 - val_loss: 4.9212 - val_mean_squared_error: 4.9212 - val_mean_absolute_error: 2.0361
# Epoch 26/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5709 - mean_squared_error: 0.5709 - mean_absolute_error: 0.5598 - val_loss: 4.9249 - val_mean_squared_error: 4.9249 - val_mean_absolute_error: 2.0354
# Epoch 27/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5598 - mean_squared_error: 0.5598 - mean_absolute_error: 0.5916 - val_loss: 4.8351 - val_mean_squared_error: 4.8351 - val_mean_absolute_error: 2.0179
# Epoch 28/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5443 - mean_squared_error: 0.5443 - mean_absolute_error: 0.5893 - val_loss: 4.7356 - val_mean_squared_error: 4.7356 - val_mean_absolute_error: 1.9896
# Epoch 29/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5546 - mean_squared_error: 0.5546 - mean_absolute_error: 0.5841 - val_loss: 4.6640 - val_mean_squared_error: 4.6640 - val_mean_absolute_error: 1.9725
# Epoch 30/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5702 - mean_squared_error: 0.5702 - mean_absolute_error: 0.5770 - val_loss: 4.5372 - val_mean_squared_error: 4.5372 - val_mean_absolute_error: 1.9385
# Epoch 31/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5753 - mean_squared_error: 0.5753 - mean_absolute_error: 0.5737 - val_loss: 4.3492 - val_mean_squared_error: 4.3492 - val_mean_absolute_error: 1.8929
# Epoch 32/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5597 - mean_squared_error: 0.5597 - mean_absolute_error: 0.5776 - val_loss: 4.0886 - val_mean_squared_error: 4.0886 - val_mean_absolute_error: 1.8283
# Epoch 33/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.4911 - mean_squared_error: 0.4911 - mean_absolute_error: 0.5433 - val_loss: 3.8997 - val_mean_squared_error: 3.8997 - val_mean_absolute_error: 1.7815
# Epoch 34/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5537 - mean_squared_error: 0.5537 - mean_absolute_error: 0.5490 - val_loss: 4.0094 - val_mean_squared_error: 4.0094 - val_mean_absolute_error: 1.8074
# Epoch 35/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5146 - mean_squared_error: 0.5146 - mean_absolute_error: 0.5481 - val_loss: 3.9202 - val_mean_squared_error: 3.9202 - val_mean_absolute_error: 1.7823
# Epoch 36/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.4915 - mean_squared_error: 0.4915 - mean_absolute_error: 0.5246 - val_loss: 3.7812 - val_mean_squared_error: 3.7812 - val_mean_absolute_error: 1.7501
# Epoch 37/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.4363 - mean_squared_error: 0.4363 - mean_absolute_error: 0.5302 - val_loss: 3.6403 - val_mean_squared_error: 3.6403 - val_mean_absolute_error: 1.7149
# Epoch 38/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.4873 - mean_squared_error: 0.4873 - mean_absolute_error: 0.5325 - val_loss: 3.4734 - val_mean_squared_error: 3.4734 - val_mean_absolute_error: 1.6664
# Epoch 39/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.5041 - mean_squared_error: 0.5041 - mean_absolute_error: 0.5299 - val_loss: 3.3897 - val_mean_squared_error: 3.3897 - val_mean_absolute_error: 1.6394
# Epoch 40/40
# 389/389 [==============================] - 1s 2ms/step - loss: 0.4304 - mean_squared_error: 0.4304 - mean_absolute_error: 0.5051 - val_loss: 3.2680 - val_mean_squared_error: 3.2680 - val_mean_absolute_error: 1.6035
# EndTime : 2019-12-13 00:04:55.350902
# Panobinostat’s final rmse value is = 1.807748
# Panobinostat R-squared value is = -3.023403
# PD-0325901_//n
# train_X shape: (392, 18988, 1)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-13 00:04:56.282902
# EndTime : 2019-12-13 00:04:59.291902
# StartTime : 2019-12-13 00:04:59.291902
# Train on 392 samples, validate on 99 samples
# Epoch 1/40
# 392/392 [==============================] - 9s 22ms/step - loss: 5.5175 - mean_squared_error: 5.5175 - mean_absolute_error: 1.9193 - val_loss: 5.9879 - val_mean_squared_error: 5.9879 - val_mean_absolute_error: 1.9371
# Epoch 2/40
# 392/392 [==============================] - 1s 2ms/step - loss: 3.5065 - mean_squared_error: 3.5065 - mean_absolute_error: 1.4654 - val_loss: 5.3765 - val_mean_squared_error: 5.3765 - val_mean_absolute_error: 2.0262
# Epoch 3/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.9272 - mean_squared_error: 1.9272 - mean_absolute_error: 1.0729 - val_loss: 5.3112 - val_mean_squared_error: 5.3112 - val_mean_absolute_error: 2.0106
# Epoch 4/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.0844 - mean_squared_error: 1.0844 - mean_absolute_error: 0.8239 - val_loss: 5.0700 - val_mean_squared_error: 5.0700 - val_mean_absolute_error: 1.8851
# Epoch 5/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.7411 - mean_squared_error: 0.7411 - mean_absolute_error: 0.6684 - val_loss: 5.0407 - val_mean_squared_error: 5.0407 - val_mean_absolute_error: 1.7969
# Epoch 6/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.8162 - mean_squared_error: 0.8162 - mean_absolute_error: 0.7013 - val_loss: 5.1064 - val_mean_squared_error: 5.1064 - val_mean_absolute_error: 1.7859
# Epoch 7/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.7660 - mean_squared_error: 0.7660 - mean_absolute_error: 0.6658 - val_loss: 5.1139 - val_mean_squared_error: 5.1139 - val_mean_absolute_error: 1.8027
# Epoch 8/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.7565 - mean_squared_error: 0.7565 - mean_absolute_error: 0.6738 - val_loss: 5.1570 - val_mean_squared_error: 5.1570 - val_mean_absolute_error: 1.8062
# Epoch 9/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.8294 - mean_squared_error: 0.8294 - mean_absolute_error: 0.7192 - val_loss: 5.2378 - val_mean_squared_error: 5.2378 - val_mean_absolute_error: 1.8112
# Epoch 10/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.7804 - mean_squared_error: 0.7804 - mean_absolute_error: 0.6885 - val_loss: 5.2285 - val_mean_squared_error: 5.2285 - val_mean_absolute_error: 1.8013
# Epoch 11/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6796 - mean_squared_error: 0.6796 - mean_absolute_error: 0.6526 - val_loss: 5.2455 - val_mean_squared_error: 5.2455 - val_mean_absolute_error: 1.7998
# Epoch 12/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6755 - mean_squared_error: 0.6755 - mean_absolute_error: 0.6391 - val_loss: 5.2234 - val_mean_squared_error: 5.2234 - val_mean_absolute_error: 1.7945
# Epoch 13/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5878 - mean_squared_error: 0.5878 - mean_absolute_error: 0.5932 - val_loss: 5.1976 - val_mean_squared_error: 5.1976 - val_mean_absolute_error: 1.7899
# Epoch 14/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5630 - mean_squared_error: 0.5630 - mean_absolute_error: 0.5835 - val_loss: 5.2167 - val_mean_squared_error: 5.2167 - val_mean_absolute_error: 1.7663
# Epoch 15/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5624 - mean_squared_error: 0.5624 - mean_absolute_error: 0.5984 - val_loss: 5.2540 - val_mean_squared_error: 5.2540 - val_mean_absolute_error: 1.7466
# Epoch 16/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5890 - mean_squared_error: 0.5890 - mean_absolute_error: 0.5691 - val_loss: 5.2807 - val_mean_squared_error: 5.2807 - val_mean_absolute_error: 1.7308
# Epoch 17/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6493 - mean_squared_error: 0.6493 - mean_absolute_error: 0.6129 - val_loss: 5.3434 - val_mean_squared_error: 5.3434 - val_mean_absolute_error: 1.7287
# Epoch 18/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5508 - mean_squared_error: 0.5508 - mean_absolute_error: 0.5552 - val_loss: 5.3800 - val_mean_squared_error: 5.3800 - val_mean_absolute_error: 1.7225
# Epoch 19/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5447 - mean_squared_error: 0.5447 - mean_absolute_error: 0.5821 - val_loss: 5.4007 - val_mean_squared_error: 5.4007 - val_mean_absolute_error: 1.7145
# Epoch 20/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5906 - mean_squared_error: 0.5906 - mean_absolute_error: 0.5958 - val_loss: 5.4319 - val_mean_squared_error: 5.4319 - val_mean_absolute_error: 1.7142
# Epoch 21/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6551 - mean_squared_error: 0.6551 - mean_absolute_error: 0.6173 - val_loss: 5.5326 - val_mean_squared_error: 5.5326 - val_mean_absolute_error: 1.7078
# Epoch 22/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4984 - mean_squared_error: 0.4984 - mean_absolute_error: 0.5531 - val_loss: 5.5108 - val_mean_squared_error: 5.5108 - val_mean_absolute_error: 1.7109
# Epoch 23/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5318 - mean_squared_error: 0.5318 - mean_absolute_error: 0.5463 - val_loss: 5.4868 - val_mean_squared_error: 5.4868 - val_mean_absolute_error: 1.7108
# Epoch 24/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4721 - mean_squared_error: 0.4721 - mean_absolute_error: 0.5423 - val_loss: 5.4671 - val_mean_squared_error: 5.4671 - val_mean_absolute_error: 1.7023
# Epoch 25/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4333 - mean_squared_error: 0.4333 - mean_absolute_error: 0.5047 - val_loss: 5.4850 - val_mean_squared_error: 5.4850 - val_mean_absolute_error: 1.7011
# Epoch 26/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5438 - mean_squared_error: 0.5438 - mean_absolute_error: 0.5565 - val_loss: 5.5226 - val_mean_squared_error: 5.5226 - val_mean_absolute_error: 1.7048
# Epoch 27/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4402 - mean_squared_error: 0.4402 - mean_absolute_error: 0.5043 - val_loss: 5.5377 - val_mean_squared_error: 5.5377 - val_mean_absolute_error: 1.7119
# Epoch 28/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4833 - mean_squared_error: 0.4833 - mean_absolute_error: 0.5331 - val_loss: 5.5511 - val_mean_squared_error: 5.5511 - val_mean_absolute_error: 1.7186
# Epoch 29/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4392 - mean_squared_error: 0.4392 - mean_absolute_error: 0.5197 - val_loss: 5.5878 - val_mean_squared_error: 5.5878 - val_mean_absolute_error: 1.7169
# Epoch 30/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4185 - mean_squared_error: 0.4185 - mean_absolute_error: 0.4952 - val_loss: 5.6632 - val_mean_squared_error: 5.6632 - val_mean_absolute_error: 1.7089
# Epoch 31/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4241 - mean_squared_error: 0.4241 - mean_absolute_error: 0.4957 - val_loss: 5.7203 - val_mean_squared_error: 5.7203 - val_mean_absolute_error: 1.6999
# Epoch 32/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4937 - mean_squared_error: 0.4937 - mean_absolute_error: 0.5511 - val_loss: 5.7066 - val_mean_squared_error: 5.7066 - val_mean_absolute_error: 1.6984
# Epoch 33/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4200 - mean_squared_error: 0.4200 - mean_absolute_error: 0.5076 - val_loss: 5.6648 - val_mean_squared_error: 5.6648 - val_mean_absolute_error: 1.6995
# Epoch 34/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4620 - mean_squared_error: 0.4620 - mean_absolute_error: 0.5244 - val_loss: 5.6658 - val_mean_squared_error: 5.6658 - val_mean_absolute_error: 1.6974
# Epoch 35/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4973 - mean_squared_error: 0.4973 - mean_absolute_error: 0.5400 - val_loss: 5.6815 - val_mean_squared_error: 5.6815 - val_mean_absolute_error: 1.6906
# Epoch 36/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3738 - mean_squared_error: 0.3738 - mean_absolute_error: 0.4815 - val_loss: 5.7503 - val_mean_squared_error: 5.7503 - val_mean_absolute_error: 1.6784
# Epoch 37/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3386 - mean_squared_error: 0.3386 - mean_absolute_error: 0.4577 - val_loss: 5.8158 - val_mean_squared_error: 5.8158 - val_mean_absolute_error: 1.6673
# Epoch 38/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3586 - mean_squared_error: 0.3586 - mean_absolute_error: 0.4616 - val_loss: 5.8409 - val_mean_squared_error: 5.8409 - val_mean_absolute_error: 1.6638
# Epoch 39/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3741 - mean_squared_error: 0.3741 - mean_absolute_error: 0.4924 - val_loss: 5.8290 - val_mean_squared_error: 5.8290 - val_mean_absolute_error: 1.6660
# Epoch 40/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4403 - mean_squared_error: 0.4403 - mean_absolute_error: 0.5048 - val_loss: 5.8188 - val_mean_squared_error: 5.8188 - val_mean_absolute_error: 1.6724
# EndTime : 2019-12-13 00:05:42.881902
# PD-0325901’s final rmse value is = 2.412222
# PD-0325901 R-squared value is = -0.142333
# PD-0332991_//n
# train_X shape: (336, 18988, 1)
# 336 train samples
# 85 test samples
# StartTime : 2019-12-13 00:05:43.943902
# EndTime : 2019-12-13 00:05:47.471902
# StartTime : 2019-12-13 00:05:47.471902
# Train on 336 samples, validate on 85 samples
# Epoch 1/40
# 336/336 [==============================] - 9s 28ms/step - loss: 3.3206 - mean_squared_error: 3.3206 - mean_absolute_error: 1.6157 - val_loss: 4.5386 - val_mean_squared_error: 4.5386 - val_mean_absolute_error: 1.9678
# Epoch 2/40
# 336/336 [==============================] - 1s 2ms/step - loss: 2.9576 - mean_squared_error: 2.9576 - mean_absolute_error: 1.4840 - val_loss: 2.6098 - val_mean_squared_error: 2.6098 - val_mean_absolute_error: 1.4731
# Epoch 3/40
# 336/336 [==============================] - 1s 2ms/step - loss: 2.4418 - mean_squared_error: 2.4418 - mean_absolute_error: 1.3878 - val_loss: 1.7721 - val_mean_squared_error: 1.7721 - val_mean_absolute_error: 1.2290
# Epoch 4/40
# 336/336 [==============================] - 1s 2ms/step - loss: 1.9669 - mean_squared_error: 1.9669 - mean_absolute_error: 1.2535 - val_loss: 1.9735 - val_mean_squared_error: 1.9735 - val_mean_absolute_error: 1.3045
# Epoch 5/40
# 336/336 [==============================] - 1s 2ms/step - loss: 1.8404 - mean_squared_error: 1.8404 - mean_absolute_error: 1.1863 - val_loss: 1.8190 - val_mean_squared_error: 1.8190 - val_mean_absolute_error: 1.2437
# Epoch 6/40
# 336/336 [==============================] - 1s 2ms/step - loss: 1.6005 - mean_squared_error: 1.6005 - mean_absolute_error: 1.0586 - val_loss: 1.3149 - val_mean_squared_error: 1.3149 - val_mean_absolute_error: 1.0551
# Epoch 7/40
# 336/336 [==============================] - 1s 2ms/step - loss: 1.3661 - mean_squared_error: 1.3661 - mean_absolute_error: 1.0181 - val_loss: 1.0460 - val_mean_squared_error: 1.0460 - val_mean_absolute_error: 0.9492
# Epoch 8/40
# 336/336 [==============================] - 1s 2ms/step - loss: 1.2136 - mean_squared_error: 1.2136 - mean_absolute_error: 0.9451 - val_loss: 0.9814 - val_mean_squared_error: 0.9814 - val_mean_absolute_error: 0.9260
# Epoch 9/40
# 336/336 [==============================] - 1s 2ms/step - loss: 1.0014 - mean_squared_error: 1.0014 - mean_absolute_error: 0.8333 - val_loss: 0.9725 - val_mean_squared_error: 0.9725 - val_mean_absolute_error: 0.9161
# Epoch 10/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.8368 - mean_squared_error: 0.8368 - mean_absolute_error: 0.7433 - val_loss: 0.8251 - val_mean_squared_error: 0.8251 - val_mean_absolute_error: 0.8351
# Epoch 11/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.8078 - mean_squared_error: 0.8078 - mean_absolute_error: 0.7357 - val_loss: 0.6877 - val_mean_squared_error: 0.6877 - val_mean_absolute_error: 0.7504
# Epoch 12/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.5921 - mean_squared_error: 0.5921 - mean_absolute_error: 0.6407 - val_loss: 0.6162 - val_mean_squared_error: 0.6162 - val_mean_absolute_error: 0.6822
# Epoch 13/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.6449 - mean_squared_error: 0.6449 - mean_absolute_error: 0.6537 - val_loss: 0.5849 - val_mean_squared_error: 0.5849 - val_mean_absolute_error: 0.6425
# Epoch 14/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.5375 - mean_squared_error: 0.5375 - mean_absolute_error: 0.6015 - val_loss: 0.5110 - val_mean_squared_error: 0.5110 - val_mean_absolute_error: 0.5755
# Epoch 15/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.5588 - mean_squared_error: 0.5588 - mean_absolute_error: 0.6013 - val_loss: 0.4625 - val_mean_squared_error: 0.4625 - val_mean_absolute_error: 0.5213
# Epoch 16/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.4657 - mean_squared_error: 0.4657 - mean_absolute_error: 0.5423 - val_loss: 0.4644 - val_mean_squared_error: 0.4644 - val_mean_absolute_error: 0.5148
# Epoch 17/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.4121 - mean_squared_error: 0.4121 - mean_absolute_error: 0.5113 - val_loss: 0.4811 - val_mean_squared_error: 0.4811 - val_mean_absolute_error: 0.5207
# Epoch 18/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.4397 - mean_squared_error: 0.4397 - mean_absolute_error: 0.5149 - val_loss: 0.4789 - val_mean_squared_error: 0.4789 - val_mean_absolute_error: 0.5125
# Epoch 19/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3858 - mean_squared_error: 0.3858 - mean_absolute_error: 0.4804 - val_loss: 0.4720 - val_mean_squared_error: 0.4720 - val_mean_absolute_error: 0.5078
# Epoch 20/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3857 - mean_squared_error: 0.3857 - mean_absolute_error: 0.4816 - val_loss: 0.4535 - val_mean_squared_error: 0.4535 - val_mean_absolute_error: 0.4935
# Epoch 21/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3793 - mean_squared_error: 0.3793 - mean_absolute_error: 0.4902 - val_loss: 0.4480 - val_mean_squared_error: 0.4480 - val_mean_absolute_error: 0.4926
# Epoch 22/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3403 - mean_squared_error: 0.3403 - mean_absolute_error: 0.4508 - val_loss: 0.4410 - val_mean_squared_error: 0.4410 - val_mean_absolute_error: 0.4878
# Epoch 23/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3863 - mean_squared_error: 0.3863 - mean_absolute_error: 0.4771 - val_loss: 0.4430 - val_mean_squared_error: 0.4430 - val_mean_absolute_error: 0.4835
# Epoch 24/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3696 - mean_squared_error: 0.3696 - mean_absolute_error: 0.4579 - val_loss: 0.4415 - val_mean_squared_error: 0.4415 - val_mean_absolute_error: 0.4738
# Epoch 25/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3415 - mean_squared_error: 0.3415 - mean_absolute_error: 0.4608 - val_loss: 0.4283 - val_mean_squared_error: 0.4283 - val_mean_absolute_error: 0.4559
# Epoch 26/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.4342 - mean_squared_error: 0.4342 - mean_absolute_error: 0.4757 - val_loss: 0.4176 - val_mean_squared_error: 0.4176 - val_mean_absolute_error: 0.4362
# Epoch 27/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3243 - mean_squared_error: 0.3243 - mean_absolute_error: 0.4503 - val_loss: 0.4043 - val_mean_squared_error: 0.4043 - val_mean_absolute_error: 0.4182
# Epoch 28/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3291 - mean_squared_error: 0.3291 - mean_absolute_error: 0.4368 - val_loss: 0.4060 - val_mean_squared_error: 0.4060 - val_mean_absolute_error: 0.4109
# Epoch 29/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3021 - mean_squared_error: 0.3021 - mean_absolute_error: 0.3927 - val_loss: 0.4119 - val_mean_squared_error: 0.4119 - val_mean_absolute_error: 0.4008
# Epoch 30/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2759 - mean_squared_error: 0.2759 - mean_absolute_error: 0.4092 - val_loss: 0.4133 - val_mean_squared_error: 0.4133 - val_mean_absolute_error: 0.3992
# Epoch 31/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2643 - mean_squared_error: 0.2643 - mean_absolute_error: 0.3922 - val_loss: 0.4012 - val_mean_squared_error: 0.4012 - val_mean_absolute_error: 0.3827
# Epoch 32/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2495 - mean_squared_error: 0.2495 - mean_absolute_error: 0.3775 - val_loss: 0.3919 - val_mean_squared_error: 0.3919 - val_mean_absolute_error: 0.3615
# Epoch 33/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.3031 - mean_squared_error: 0.3031 - mean_absolute_error: 0.4174 - val_loss: 0.3895 - val_mean_squared_error: 0.3895 - val_mean_absolute_error: 0.3497
# Epoch 34/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2978 - mean_squared_error: 0.2978 - mean_absolute_error: 0.3977 - val_loss: 0.3881 - val_mean_squared_error: 0.3881 - val_mean_absolute_error: 0.3485
# Epoch 35/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2475 - mean_squared_error: 0.2475 - mean_absolute_error: 0.3855 - val_loss: 0.3924 - val_mean_squared_error: 0.3924 - val_mean_absolute_error: 0.3469
# Epoch 36/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2717 - mean_squared_error: 0.2717 - mean_absolute_error: 0.4013 - val_loss: 0.3880 - val_mean_squared_error: 0.3880 - val_mean_absolute_error: 0.3529
# Epoch 37/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2367 - mean_squared_error: 0.2367 - mean_absolute_error: 0.3792 - val_loss: 0.3968 - val_mean_squared_error: 0.3968 - val_mean_absolute_error: 0.3618
# Epoch 38/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2463 - mean_squared_error: 0.2463 - mean_absolute_error: 0.3819 - val_loss: 0.4081 - val_mean_squared_error: 0.4081 - val_mean_absolute_error: 0.3654
# Epoch 39/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2935 - mean_squared_error: 0.2935 - mean_absolute_error: 0.3997 - val_loss: 0.3994 - val_mean_squared_error: 0.3994 - val_mean_absolute_error: 0.3536
# Epoch 40/40
# 336/336 [==============================] - 1s 2ms/step - loss: 0.2883 - mean_squared_error: 0.2883 - mean_absolute_error: 0.3934 - val_loss: 0.3928 - val_mean_squared_error: 0.3928 - val_mean_absolute_error: 0.3504
# EndTime : 2019-12-13 00:06:29.232902
# PD-0332991’s final rmse value is = 0.626771
# PD-0332991 R-squared value is = -0.052690
# PF2341066_//n
# train_X shape: (392, 18988, 1)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-13 00:06:30.582902
# EndTime : 2019-12-13 00:06:34.127902
# StartTime : 2019-12-13 00:06:34.128902
# Train on 392 samples, validate on 99 samples
# Epoch 1/40
# 392/392 [==============================] - 10s 25ms/step - loss: 3.9661 - mean_squared_error: 3.9661 - mean_absolute_error: 1.7920 - val_loss: 4.9485 - val_mean_squared_error: 4.9485 - val_mean_absolute_error: 2.1069
# Epoch 2/40
# 392/392 [==============================] - 1s 2ms/step - loss: 3.4280 - mean_squared_error: 3.4280 - mean_absolute_error: 1.6645 - val_loss: 4.5451 - val_mean_squared_error: 4.5451 - val_mean_absolute_error: 2.0344
# Epoch 3/40
# 392/392 [==============================] - 1s 2ms/step - loss: 2.8509 - mean_squared_error: 2.8509 - mean_absolute_error: 1.4916 - val_loss: 3.7829 - val_mean_squared_error: 3.7829 - val_mean_absolute_error: 1.8478
# Epoch 4/40
# 392/392 [==============================] - 1s 2ms/step - loss: 2.3861 - mean_squared_error: 2.3861 - mean_absolute_error: 1.3585 - val_loss: 2.9802 - val_mean_squared_error: 2.9802 - val_mean_absolute_error: 1.6296
# Epoch 5/40
# 392/392 [==============================] - 1s 2ms/step - loss: 2.1076 - mean_squared_error: 2.1076 - mean_absolute_error: 1.2648 - val_loss: 2.3989 - val_mean_squared_error: 2.3989 - val_mean_absolute_error: 1.4473
# Epoch 6/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.8391 - mean_squared_error: 1.8391 - mean_absolute_error: 1.1805 - val_loss: 2.1538 - val_mean_squared_error: 2.1538 - val_mean_absolute_error: 1.3709
# Epoch 7/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.5664 - mean_squared_error: 1.5664 - mean_absolute_error: 1.0758 - val_loss: 1.9947 - val_mean_squared_error: 1.9947 - val_mean_absolute_error: 1.3172
# Epoch 8/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.3510 - mean_squared_error: 1.3510 - mean_absolute_error: 0.9805 - val_loss: 1.8594 - val_mean_squared_error: 1.8594 - val_mean_absolute_error: 1.2656
# Epoch 9/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.4424 - mean_squared_error: 1.4424 - mean_absolute_error: 1.0255 - val_loss: 1.7003 - val_mean_squared_error: 1.7003 - val_mean_absolute_error: 1.2064
# Epoch 10/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.0855 - mean_squared_error: 1.0855 - mean_absolute_error: 0.8983 - val_loss: 1.4862 - val_mean_squared_error: 1.4862 - val_mean_absolute_error: 1.1135
# Epoch 11/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.9383 - mean_squared_error: 0.9383 - mean_absolute_error: 0.7845 - val_loss: 1.3671 - val_mean_squared_error: 1.3671 - val_mean_absolute_error: 1.0568
# Epoch 12/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.8061 - mean_squared_error: 0.8061 - mean_absolute_error: 0.7414 - val_loss: 1.2740 - val_mean_squared_error: 1.2740 - val_mean_absolute_error: 1.0087
# Epoch 13/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.7271 - mean_squared_error: 0.7271 - mean_absolute_error: 0.6939 - val_loss: 1.2007 - val_mean_squared_error: 1.2007 - val_mean_absolute_error: 0.9671
# Epoch 14/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6799 - mean_squared_error: 0.6799 - mean_absolute_error: 0.6905 - val_loss: 1.1392 - val_mean_squared_error: 1.1392 - val_mean_absolute_error: 0.9362
# Epoch 15/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5779 - mean_squared_error: 0.5779 - mean_absolute_error: 0.6193 - val_loss: 1.0730 - val_mean_squared_error: 1.0730 - val_mean_absolute_error: 0.9044
# Epoch 16/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5247 - mean_squared_error: 0.5247 - mean_absolute_error: 0.5734 - val_loss: 1.0205 - val_mean_squared_error: 1.0205 - val_mean_absolute_error: 0.8781
# Epoch 17/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5565 - mean_squared_error: 0.5565 - mean_absolute_error: 0.5887 - val_loss: 0.9481 - val_mean_squared_error: 0.9481 - val_mean_absolute_error: 0.8346
# Epoch 18/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5394 - mean_squared_error: 0.5394 - mean_absolute_error: 0.5516 - val_loss: 0.9012 - val_mean_squared_error: 0.9012 - val_mean_absolute_error: 0.8072
# Epoch 19/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4993 - mean_squared_error: 0.4993 - mean_absolute_error: 0.5578 - val_loss: 0.8725 - val_mean_squared_error: 0.8725 - val_mean_absolute_error: 0.7876
# Epoch 20/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4271 - mean_squared_error: 0.4271 - mean_absolute_error: 0.5160 - val_loss: 0.8466 - val_mean_squared_error: 0.8466 - val_mean_absolute_error: 0.7688
# Epoch 21/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3946 - mean_squared_error: 0.3946 - mean_absolute_error: 0.4974 - val_loss: 0.7989 - val_mean_squared_error: 0.7989 - val_mean_absolute_error: 0.7339
# Epoch 22/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4223 - mean_squared_error: 0.4223 - mean_absolute_error: 0.5006 - val_loss: 0.7780 - val_mean_squared_error: 0.7780 - val_mean_absolute_error: 0.7204
# Epoch 23/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3659 - mean_squared_error: 0.3659 - mean_absolute_error: 0.4706 - val_loss: 0.7843 - val_mean_squared_error: 0.7843 - val_mean_absolute_error: 0.7261
# Epoch 24/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3896 - mean_squared_error: 0.3896 - mean_absolute_error: 0.4858 - val_loss: 0.7707 - val_mean_squared_error: 0.7707 - val_mean_absolute_error: 0.7163
# Epoch 25/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3659 - mean_squared_error: 0.3659 - mean_absolute_error: 0.4726 - val_loss: 0.7551 - val_mean_squared_error: 0.7551 - val_mean_absolute_error: 0.7067
# Epoch 26/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3410 - mean_squared_error: 0.3410 - mean_absolute_error: 0.4705 - val_loss: 0.7522 - val_mean_squared_error: 0.7522 - val_mean_absolute_error: 0.7048
# Epoch 27/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3966 - mean_squared_error: 0.3966 - mean_absolute_error: 0.4769 - val_loss: 0.7353 - val_mean_squared_error: 0.7353 - val_mean_absolute_error: 0.6900
# Epoch 28/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3255 - mean_squared_error: 0.3255 - mean_absolute_error: 0.4390 - val_loss: 0.7051 - val_mean_squared_error: 0.7051 - val_mean_absolute_error: 0.6655
# Epoch 29/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3230 - mean_squared_error: 0.3230 - mean_absolute_error: 0.4588 - val_loss: 0.6700 - val_mean_squared_error: 0.6700 - val_mean_absolute_error: 0.6377
# Epoch 30/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3682 - mean_squared_error: 0.3682 - mean_absolute_error: 0.4573 - val_loss: 0.6514 - val_mean_squared_error: 0.6514 - val_mean_absolute_error: 0.6232
# Epoch 31/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3559 - mean_squared_error: 0.3559 - mean_absolute_error: 0.4556 - val_loss: 0.6445 - val_mean_squared_error: 0.6445 - val_mean_absolute_error: 0.6204
# Epoch 32/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3304 - mean_squared_error: 0.3304 - mean_absolute_error: 0.4416 - val_loss: 0.6545 - val_mean_squared_error: 0.6545 - val_mean_absolute_error: 0.6280
# Epoch 33/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3130 - mean_squared_error: 0.3130 - mean_absolute_error: 0.4362 - val_loss: 0.6585 - val_mean_squared_error: 0.6585 - val_mean_absolute_error: 0.6293
# Epoch 34/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3766 - mean_squared_error: 0.3766 - mean_absolute_error: 0.4642 - val_loss: 0.6467 - val_mean_squared_error: 0.6467 - val_mean_absolute_error: 0.6135
# Epoch 35/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3666 - mean_squared_error: 0.3666 - mean_absolute_error: 0.4675 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_error: 0.6009
# Epoch 36/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3535 - mean_squared_error: 0.3535 - mean_absolute_error: 0.4583 - val_loss: 0.6314 - val_mean_squared_error: 0.6314 - val_mean_absolute_error: 0.5949
# Epoch 37/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.2877 - mean_squared_error: 0.2877 - mean_absolute_error: 0.4150 - val_loss: 0.6232 - val_mean_squared_error: 0.6232 - val_mean_absolute_error: 0.5851
# Epoch 38/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3166 - mean_squared_error: 0.3166 - mean_absolute_error: 0.4290 - val_loss: 0.6125 - val_mean_squared_error: 0.6125 - val_mean_absolute_error: 0.5725
# Epoch 39/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3579 - mean_squared_error: 0.3579 - mean_absolute_error: 0.4430 - val_loss: 0.5955 - val_mean_squared_error: 0.5955 - val_mean_absolute_error: 0.5480
# Epoch 40/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.2714 - mean_squared_error: 0.2714 - mean_absolute_error: 0.3969 - val_loss: 0.5801 - val_mean_squared_error: 0.5801 - val_mean_absolute_error: 0.5248
# EndTime : 2019-12-13 00:07:20.700902
# PF2341066’s final rmse value is = 0.761654
# PF2341066 R-squared value is = -0.108292
# PHA-665752_//n
# train_X shape: (392, 18988, 1)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-13 00:07:22.244902
# EndTime : 2019-12-13 00:07:26.018902
# StartTime : 2019-12-13 00:07:26.018902
# Train on 392 samples, validate on 98 samples
# Epoch 1/40
# 392/392 [==============================] - 10s 27ms/step - loss: 4.7605 - mean_squared_error: 4.7605 - mean_absolute_error: 1.9986 - val_loss: 9.2673 - val_mean_squared_error: 9.2673 - val_mean_absolute_error: 2.8790
# Epoch 2/40
# 392/392 [==============================] - 1s 2ms/step - loss: 4.2856 - mean_squared_error: 4.2856 - mean_absolute_error: 1.8669 - val_loss: 5.6753 - val_mean_squared_error: 5.6753 - val_mean_absolute_error: 2.2760
# Epoch 3/40
# 392/392 [==============================] - 1s 2ms/step - loss: 3.8709 - mean_squared_error: 3.8709 - mean_absolute_error: 1.7822 - val_loss: 4.4577 - val_mean_squared_error: 4.4577 - val_mean_absolute_error: 2.0203
# Epoch 4/40
# 392/392 [==============================] - 1s 2ms/step - loss: 3.2803 - mean_squared_error: 3.2803 - mean_absolute_error: 1.6458 - val_loss: 4.7476 - val_mean_squared_error: 4.7476 - val_mean_absolute_error: 2.1008
# Epoch 5/40
# 392/392 [==============================] - 1s 2ms/step - loss: 2.7925 - mean_squared_error: 2.7925 - mean_absolute_error: 1.5175 - val_loss: 4.4335 - val_mean_squared_error: 4.4335 - val_mean_absolute_error: 2.0362
# Epoch 6/40
# 392/392 [==============================] - 1s 2ms/step - loss: 2.4088 - mean_squared_error: 2.4088 - mean_absolute_error: 1.3850 - val_loss: 3.6472 - val_mean_squared_error: 3.6472 - val_mean_absolute_error: 1.8440
# Epoch 7/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.9574 - mean_squared_error: 1.9574 - mean_absolute_error: 1.2480 - val_loss: 3.2899 - val_mean_squared_error: 3.2899 - val_mean_absolute_error: 1.7605
# Epoch 8/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.9574 - mean_squared_error: 1.9574 - mean_absolute_error: 1.2336 - val_loss: 3.2491 - val_mean_squared_error: 3.2491 - val_mean_absolute_error: 1.7350
# Epoch 9/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.4937 - mean_squared_error: 1.4937 - mean_absolute_error: 1.0667 - val_loss: 3.5098 - val_mean_squared_error: 3.5098 - val_mean_absolute_error: 1.7436
# Epoch 10/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.3635 - mean_squared_error: 1.3635 - mean_absolute_error: 1.0043 - val_loss: 2.6050 - val_mean_squared_error: 2.6050 - val_mean_absolute_error: 1.5443
# Epoch 11/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.3566 - mean_squared_error: 1.3566 - mean_absolute_error: 0.9818 - val_loss: 2.2799 - val_mean_squared_error: 2.2799 - val_mean_absolute_error: 1.4560
# Epoch 12/40
# 392/392 [==============================] - 1s 2ms/step - loss: 1.1340 - mean_squared_error: 1.1340 - mean_absolute_error: 0.8919 - val_loss: 2.3955 - val_mean_squared_error: 2.3955 - val_mean_absolute_error: 1.4627
# Epoch 13/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.9769 - mean_squared_error: 0.9769 - mean_absolute_error: 0.8354 - val_loss: 2.4711 - val_mean_squared_error: 2.4711 - val_mean_absolute_error: 1.4511
# Epoch 14/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.7321 - mean_squared_error: 0.7321 - mean_absolute_error: 0.7119 - val_loss: 2.3095 - val_mean_squared_error: 2.3095 - val_mean_absolute_error: 1.4044
# Epoch 15/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6661 - mean_squared_error: 0.6661 - mean_absolute_error: 0.6504 - val_loss: 2.0260 - val_mean_squared_error: 2.0260 - val_mean_absolute_error: 1.3282
# Epoch 16/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6414 - mean_squared_error: 0.6414 - mean_absolute_error: 0.6373 - val_loss: 1.7438 - val_mean_squared_error: 1.7438 - val_mean_absolute_error: 1.2552
# Epoch 17/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6299 - mean_squared_error: 0.6299 - mean_absolute_error: 0.6371 - val_loss: 1.9567 - val_mean_squared_error: 1.9567 - val_mean_absolute_error: 1.2640
# Epoch 18/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6301 - mean_squared_error: 0.6301 - mean_absolute_error: 0.5784 - val_loss: 1.2669 - val_mean_squared_error: 1.2669 - val_mean_absolute_error: 1.0644
# Epoch 19/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5313 - mean_squared_error: 0.5313 - mean_absolute_error: 0.5807 - val_loss: 1.2323 - val_mean_squared_error: 1.2323 - val_mean_absolute_error: 1.0470
# Epoch 20/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4399 - mean_squared_error: 0.4399 - mean_absolute_error: 0.5112 - val_loss: 1.5293 - val_mean_squared_error: 1.5293 - val_mean_absolute_error: 1.1232
# Epoch 21/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4257 - mean_squared_error: 0.4257 - mean_absolute_error: 0.4937 - val_loss: 1.4858 - val_mean_squared_error: 1.4858 - val_mean_absolute_error: 1.0903
# Epoch 22/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3802 - mean_squared_error: 0.3802 - mean_absolute_error: 0.4924 - val_loss: 0.9853 - val_mean_squared_error: 0.9853 - val_mean_absolute_error: 0.9257
# Epoch 23/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4827 - mean_squared_error: 0.4827 - mean_absolute_error: 0.5119 - val_loss: 0.8671 - val_mean_squared_error: 0.8671 - val_mean_absolute_error: 0.8609
# Epoch 24/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3302 - mean_squared_error: 0.3302 - mean_absolute_error: 0.4479 - val_loss: 0.8108 - val_mean_squared_error: 0.8108 - val_mean_absolute_error: 0.8230
# Epoch 25/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3610 - mean_squared_error: 0.3610 - mean_absolute_error: 0.4605 - val_loss: 0.6769 - val_mean_squared_error: 0.6769 - val_mean_absolute_error: 0.7488
# Epoch 26/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3619 - mean_squared_error: 0.3619 - mean_absolute_error: 0.4565 - val_loss: 0.6232 - val_mean_squared_error: 0.6232 - val_mean_absolute_error: 0.6939
# Epoch 27/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3593 - mean_squared_error: 0.3593 - mean_absolute_error: 0.4715 - val_loss: 0.6017 - val_mean_squared_error: 0.6017 - val_mean_absolute_error: 0.6788
# Epoch 28/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3098 - mean_squared_error: 0.3098 - mean_absolute_error: 0.4418 - val_loss: 0.5621 - val_mean_squared_error: 0.5621 - val_mean_absolute_error: 0.6504
# Epoch 29/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3359 - mean_squared_error: 0.3359 - mean_absolute_error: 0.4216 - val_loss: 0.5392 - val_mean_squared_error: 0.5392 - val_mean_absolute_error: 0.6328
# Epoch 30/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3440 - mean_squared_error: 0.3440 - mean_absolute_error: 0.4397 - val_loss: 0.4992 - val_mean_squared_error: 0.4992 - val_mean_absolute_error: 0.5992
# Epoch 31/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3497 - mean_squared_error: 0.3497 - mean_absolute_error: 0.4363 - val_loss: 0.5084 - val_mean_squared_error: 0.5084 - val_mean_absolute_error: 0.6000
# Epoch 32/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3652 - mean_squared_error: 0.3652 - mean_absolute_error: 0.4281 - val_loss: 0.4459 - val_mean_squared_error: 0.4459 - val_mean_absolute_error: 0.5602
# Epoch 33/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3808 - mean_squared_error: 0.3808 - mean_absolute_error: 0.4259 - val_loss: 0.3985 - val_mean_squared_error: 0.3985 - val_mean_absolute_error: 0.5203
# Epoch 34/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3116 - mean_squared_error: 0.3116 - mean_absolute_error: 0.4189 - val_loss: 0.3629 - val_mean_squared_error: 0.3629 - val_mean_absolute_error: 0.4906
# Epoch 35/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3023 - mean_squared_error: 0.3023 - mean_absolute_error: 0.4269 - val_loss: 0.3413 - val_mean_squared_error: 0.3413 - val_mean_absolute_error: 0.4674
# Epoch 36/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3547 - mean_squared_error: 0.3547 - mean_absolute_error: 0.4444 - val_loss: 0.3313 - val_mean_squared_error: 0.3313 - val_mean_absolute_error: 0.4530
# Epoch 37/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3431 - mean_squared_error: 0.3431 - mean_absolute_error: 0.4263 - val_loss: 0.3325 - val_mean_squared_error: 0.3325 - val_mean_absolute_error: 0.4605
# Epoch 38/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3505 - mean_squared_error: 0.3505 - mean_absolute_error: 0.4425 - val_loss: 0.3266 - val_mean_squared_error: 0.3266 - val_mean_absolute_error: 0.4557
# Epoch 39/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.2971 - mean_squared_error: 0.2971 - mean_absolute_error: 0.4098 - val_loss: 0.3372 - val_mean_squared_error: 0.3372 - val_mean_absolute_error: 0.4575
# Epoch 40/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.2956 - mean_squared_error: 0.2956 - mean_absolute_error: 0.4105 - val_loss: 0.3611 - val_mean_squared_error: 0.3611 - val_mean_absolute_error: 0.4728
# ...
# Epoch 13/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5399 - mean_squared_error: 0.5399 - mean_absolute_error: 0.5934 - val_loss: 3.3144 - val_mean_squared_error: 3.3144 - val_mean_absolute_error: 1.5223
# Epoch 14/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.6362 - mean_squared_error: 0.6362 - mean_absolute_error: 0.6044 - val_loss: 3.3427 - val_mean_squared_error: 3.3427 - val_mean_absolute_error: 1.5304
# Epoch 15/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5934 - mean_squared_error: 0.5934 - mean_absolute_error: 0.6024 - val_loss: 3.1452 - val_mean_squared_error: 3.1452 - val_mean_absolute_error: 1.4881
# Epoch 16/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5363 - mean_squared_error: 0.5363 - mean_absolute_error: 0.5607 - val_loss: 3.2594 - val_mean_squared_error: 3.2594 - val_mean_absolute_error: 1.5098
# Epoch 17/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4742 - mean_squared_error: 0.4742 - mean_absolute_error: 0.5274 - val_loss: 3.2099 - val_mean_squared_error: 3.2099 - val_mean_absolute_error: 1.5054
# Epoch 18/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4546 - mean_squared_error: 0.4546 - mean_absolute_error: 0.5203 - val_loss: 3.0036 - val_mean_squared_error: 3.0036 - val_mean_absolute_error: 1.4608
# Epoch 19/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4977 - mean_squared_error: 0.4977 - mean_absolute_error: 0.5505 - val_loss: 3.0206 - val_mean_squared_error: 3.0206 - val_mean_absolute_error: 1.4666
# Epoch 20/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4817 - mean_squared_error: 0.4817 - mean_absolute_error: 0.5358 - val_loss: 3.2922 - val_mean_squared_error: 3.2922 - val_mean_absolute_error: 1.5233
# Epoch 21/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4753 - mean_squared_error: 0.4753 - mean_absolute_error: 0.5214 - val_loss: 3.1987 - val_mean_squared_error: 3.1987 - val_mean_absolute_error: 1.5065
# Epoch 22/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5028 - mean_squared_error: 0.5028 - mean_absolute_error: 0.5650 - val_loss: 3.0061 - val_mean_squared_error: 3.0061 - val_mean_absolute_error: 1.4629
# Epoch 23/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.5282 - mean_squared_error: 0.5282 - mean_absolute_error: 0.5514 - val_loss: 2.7282 - val_mean_squared_error: 2.7282 - val_mean_absolute_error: 1.3786
# Epoch 24/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4672 - mean_squared_error: 0.4672 - mean_absolute_error: 0.5135 - val_loss: 2.7276 - val_mean_squared_error: 2.7276 - val_mean_absolute_error: 1.3820
# Epoch 25/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4434 - mean_squared_error: 0.4434 - mean_absolute_error: 0.5342 - val_loss: 3.0344 - val_mean_squared_error: 3.0344 - val_mean_absolute_error: 1.4764
# Epoch 26/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4197 - mean_squared_error: 0.4197 - mean_absolute_error: 0.4823 - val_loss: 3.1351 - val_mean_squared_error: 3.1351 - val_mean_absolute_error: 1.5000
# Epoch 27/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4076 - mean_squared_error: 0.4076 - mean_absolute_error: 0.4911 - val_loss: 2.9019 - val_mean_squared_error: 2.9019 - val_mean_absolute_error: 1.4458
# Epoch 28/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3425 - mean_squared_error: 0.3425 - mean_absolute_error: 0.4484 - val_loss: 2.7780 - val_mean_squared_error: 2.7780 - val_mean_absolute_error: 1.4101
# Epoch 29/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4560 - mean_squared_error: 0.4560 - mean_absolute_error: 0.5242 - val_loss: 2.8608 - val_mean_squared_error: 2.8608 - val_mean_absolute_error: 1.4364
# Epoch 30/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3290 - mean_squared_error: 0.3290 - mean_absolute_error: 0.4564 - val_loss: 2.7962 - val_mean_squared_error: 2.7962 - val_mean_absolute_error: 1.4194
# Epoch 31/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3778 - mean_squared_error: 0.3778 - mean_absolute_error: 0.4693 - val_loss: 2.6894 - val_mean_squared_error: 2.6894 - val_mean_absolute_error: 1.3858
# Epoch 32/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3339 - mean_squared_error: 0.3339 - mean_absolute_error: 0.4495 - val_loss: 2.6854 - val_mean_squared_error: 2.6854 - val_mean_absolute_error: 1.3825
# Epoch 33/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.4458 - mean_squared_error: 0.4458 - mean_absolute_error: 0.4980 - val_loss: 2.7642 - val_mean_squared_error: 2.7642 - val_mean_absolute_error: 1.4105
# Epoch 34/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3088 - mean_squared_error: 0.3088 - mean_absolute_error: 0.4285 - val_loss: 2.6437 - val_mean_squared_error: 2.6437 - val_mean_absolute_error: 1.3738
# Epoch 35/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3943 - mean_squared_error: 0.3943 - mean_absolute_error: 0.4895 - val_loss: 2.5941 - val_mean_squared_error: 2.5941 - val_mean_absolute_error: 1.3582
# Epoch 36/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3691 - mean_squared_error: 0.3691 - mean_absolute_error: 0.4685 - val_loss: 2.6408 - val_mean_squared_error: 2.6408 - val_mean_absolute_error: 1.3702
# Epoch 37/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3078 - mean_squared_error: 0.3078 - mean_absolute_error: 0.4297 - val_loss: 2.7387 - val_mean_squared_error: 2.7387 - val_mean_absolute_error: 1.3993
# Epoch 38/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3411 - mean_squared_error: 0.3411 - mean_absolute_error: 0.4362 - val_loss: 2.7168 - val_mean_squared_error: 2.7168 - val_mean_absolute_error: 1.3958
# Epoch 39/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3697 - mean_squared_error: 0.3697 - mean_absolute_error: 0.4606 - val_loss: 2.6903 - val_mean_squared_error: 2.6903 - val_mean_absolute_error: 1.3905
# Epoch 40/40
# 392/392 [==============================] - 1s 2ms/step - loss: 0.3652 - mean_squared_error: 0.3652 - mean_absolute_error: 0.4531 - val_loss: 2.6446 - val_mean_squared_error: 2.6446 - val_mean_absolute_error: 1.3707
# EndTime : 2019-12-13 00:14:19.091902
# Topotecan’s final rmse value is = 1.626226
# Topotecan R-squared value is = -0.000001
# ZD-6474_//n
# train_X shape: (386, 18988, 1)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-13 00:14:23.033902
# EndTime : 2019-12-13 00:14:28.668902
# StartTime : 2019-12-13 00:14:28.668902
# Train on 386 samples, validate on 97 samples
# Epoch 1/40
# 386/386 [==============================] - 16s 43ms/step - loss: 7.9448 - mean_squared_error: 7.9448 - mean_absolute_error: 2.6005 - val_loss: 5.9384 - val_mean_squared_error: 5.9384 - val_mean_absolute_error: 2.2527
# Epoch 2/40
# 386/386 [==============================] - 1s 2ms/step - loss: 6.7895 - mean_squared_error: 6.7895 - mean_absolute_error: 2.4491 - val_loss: 4.0993 - val_mean_squared_error: 4.0993 - val_mean_absolute_error: 1.8697
# Epoch 3/40
# 386/386 [==============================] - 1s 2ms/step - loss: 6.0179 - mean_squared_error: 6.0179 - mean_absolute_error: 2.3018 - val_loss: 3.7750 - val_mean_squared_error: 3.7750 - val_mean_absolute_error: 1.8011
# Epoch 4/40
# 386/386 [==============================] - 1s 2ms/step - loss: 5.5662 - mean_squared_error: 5.5662 - mean_absolute_error: 2.2296 - val_loss: 3.3982 - val_mean_squared_error: 3.3982 - val_mean_absolute_error: 1.7014
# Epoch 5/40
# 386/386 [==============================] - 1s 2ms/step - loss: 4.9346 - mean_squared_error: 4.9346 - mean_absolute_error: 2.0886 - val_loss: 2.8638 - val_mean_squared_error: 2.8638 - val_mean_absolute_error: 1.5459
# Epoch 6/40
# 386/386 [==============================] - 1s 2ms/step - loss: 4.4466 - mean_squared_error: 4.4466 - mean_absolute_error: 1.9861 - val_loss: 2.8368 - val_mean_squared_error: 2.8368 - val_mean_absolute_error: 1.5467
# Epoch 7/40
# 386/386 [==============================] - 1s 2ms/step - loss: 3.9580 - mean_squared_error: 3.9580 - mean_absolute_error: 1.8459 - val_loss: 2.9096 - val_mean_squared_error: 2.9096 - val_mean_absolute_error: 1.5706
# Epoch 8/40
# 386/386 [==============================] - 1s 2ms/step - loss: 3.4011 - mean_squared_error: 3.4011 - mean_absolute_error: 1.7189 - val_loss: 2.9033 - val_mean_squared_error: 2.9033 - val_mean_absolute_error: 1.5727
# Epoch 9/40
# 386/386 [==============================] - 1s 2ms/step - loss: 3.0245 - mean_squared_error: 3.0245 - mean_absolute_error: 1.5964 - val_loss: 2.8401 - val_mean_squared_error: 2.8401 - val_mean_absolute_error: 1.5587
# Epoch 10/40
# 386/386 [==============================] - 1s 2ms/step - loss: 2.6929 - mean_squared_error: 2.6929 - mean_absolute_error: 1.4980 - val_loss: 2.5201 - val_mean_squared_error: 2.5201 - val_mean_absolute_error: 1.4579
# Epoch 11/40
# 386/386 [==============================] - 1s 3ms/step - loss: 2.3047 - mean_squared_error: 2.3047 - mean_absolute_error: 1.3851 - val_loss: 2.4643 - val_mean_squared_error: 2.4643 - val_mean_absolute_error: 1.4412
# Epoch 12/40
# 386/386 [==============================] - 1s 2ms/step - loss: 2.2197 - mean_squared_error: 2.2197 - mean_absolute_error: 1.3388 - val_loss: 2.3555 - val_mean_squared_error: 2.3555 - val_mean_absolute_error: 1.4036
# Epoch 13/40
# 386/386 [==============================] - 1s 2ms/step - loss: 1.9280 - mean_squared_error: 1.9280 - mean_absolute_error: 1.2500 - val_loss: 2.3391 - val_mean_squared_error: 2.3391 - val_mean_absolute_error: 1.4015
# Epoch 14/40
# 386/386 [==============================] - 1s 2ms/step - loss: 1.6520 - mean_squared_error: 1.6520 - mean_absolute_error: 1.1540 - val_loss: 2.3804 - val_mean_squared_error: 2.3804 - val_mean_absolute_error: 1.4170
# Epoch 15/40
# 386/386 [==============================] - 1s 2ms/step - loss: 1.4935 - mean_squared_error: 1.4935 - mean_absolute_error: 1.0688 - val_loss: 2.3698 - val_mean_squared_error: 2.3698 - val_mean_absolute_error: 1.4132
# Epoch 16/40
# 386/386 [==============================] - 1s 2ms/step - loss: 1.2650 - mean_squared_error: 1.2650 - mean_absolute_error: 0.9761 - val_loss: 2.2260 - val_mean_squared_error: 2.2260 - val_mean_absolute_error: 1.3697
# Epoch 17/40
# 386/386 [==============================] - 1s 2ms/step - loss: 1.0887 - mean_squared_error: 1.0887 - mean_absolute_error: 0.9028 - val_loss: 2.1114 - val_mean_squared_error: 2.1114 - val_mean_absolute_error: 1.3326
# Epoch 18/40
# 386/386 [==============================] - 1s 2ms/step - loss: 1.0996 - mean_squared_error: 1.0996 - mean_absolute_error: 0.8947 - val_loss: 2.0743 - val_mean_squared_error: 2.0743 - val_mean_absolute_error: 1.3191
# Epoch 19/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.9887 - mean_squared_error: 0.9887 - mean_absolute_error: 0.8366 - val_loss: 2.0921 - val_mean_squared_error: 2.0921 - val_mean_absolute_error: 1.3249
# Epoch 20/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.7615 - mean_squared_error: 0.7615 - mean_absolute_error: 0.7259 - val_loss: 1.9814 - val_mean_squared_error: 1.9814 - val_mean_absolute_error: 1.2901
# Epoch 21/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.7395 - mean_squared_error: 0.7395 - mean_absolute_error: 0.7127 - val_loss: 1.8880 - val_mean_squared_error: 1.8880 - val_mean_absolute_error: 1.2633
# Epoch 22/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.7726 - mean_squared_error: 0.7726 - mean_absolute_error: 0.7291 - val_loss: 1.9483 - val_mean_squared_error: 1.9483 - val_mean_absolute_error: 1.2865
# Epoch 23/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.6586 - mean_squared_error: 0.6586 - mean_absolute_error: 0.6213 - val_loss: 1.9412 - val_mean_squared_error: 1.9412 - val_mean_absolute_error: 1.2873
# Epoch 24/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.6146 - mean_squared_error: 0.6146 - mean_absolute_error: 0.6204 - val_loss: 1.8073 - val_mean_squared_error: 1.8073 - val_mean_absolute_error: 1.2347
# Epoch 25/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.6758 - mean_squared_error: 0.6758 - mean_absolute_error: 0.6462 - val_loss: 1.7112 - val_mean_squared_error: 1.7112 - val_mean_absolute_error: 1.1993
# Epoch 26/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.4505 - mean_squared_error: 0.4505 - mean_absolute_error: 0.5386 - val_loss: 1.6655 - val_mean_squared_error: 1.6655 - val_mean_absolute_error: 1.1878
# Epoch 27/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.4314 - mean_squared_error: 0.4314 - mean_absolute_error: 0.5180 - val_loss: 1.5923 - val_mean_squared_error: 1.5923 - val_mean_absolute_error: 1.1615
# Epoch 28/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.4495 - mean_squared_error: 0.4495 - mean_absolute_error: 0.5158 - val_loss: 1.5209 - val_mean_squared_error: 1.5209 - val_mean_absolute_error: 1.1358
# Epoch 29/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.4166 - mean_squared_error: 0.4166 - mean_absolute_error: 0.5085 - val_loss: 1.4878 - val_mean_squared_error: 1.4878 - val_mean_absolute_error: 1.1235
# Epoch 30/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.4526 - mean_squared_error: 0.4526 - mean_absolute_error: 0.5193 - val_loss: 1.4488 - val_mean_squared_error: 1.4488 - val_mean_absolute_error: 1.1069
# Epoch 31/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3981 - mean_squared_error: 0.3981 - mean_absolute_error: 0.4762 - val_loss: 1.4240 - val_mean_squared_error: 1.4240 - val_mean_absolute_error: 1.0966
# Epoch 32/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3983 - mean_squared_error: 0.3983 - mean_absolute_error: 0.4824 - val_loss: 1.3423 - val_mean_squared_error: 1.3423 - val_mean_absolute_error: 1.0648
# Epoch 33/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3984 - mean_squared_error: 0.3984 - mean_absolute_error: 0.4869 - val_loss: 1.2815 - val_mean_squared_error: 1.2815 - val_mean_absolute_error: 1.0414
# Epoch 34/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3658 - mean_squared_error: 0.3658 - mean_absolute_error: 0.4704 - val_loss: 1.2330 - val_mean_squared_error: 1.2330 - val_mean_absolute_error: 1.0217
# Epoch 35/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3214 - mean_squared_error: 0.3214 - mean_absolute_error: 0.4475 - val_loss: 1.1859 - val_mean_squared_error: 1.1859 - val_mean_absolute_error: 0.9999
# Epoch 36/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3360 - mean_squared_error: 0.3360 - mean_absolute_error: 0.4284 - val_loss: 1.1560 - val_mean_squared_error: 1.1560 - val_mean_absolute_error: 0.9863
# Epoch 37/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.3527 - mean_squared_error: 0.3527 - mean_absolute_error: 0.4612 - val_loss: 1.1313 - val_mean_squared_error: 1.1313 - val_mean_absolute_error: 0.9749
# Epoch 38/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.2965 - mean_squared_error: 0.2965 - mean_absolute_error: 0.4163 - val_loss: 1.0962 - val_mean_squared_error: 1.0962 - val_mean_absolute_error: 0.9592
# Epoch 39/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.2659 - mean_squared_error: 0.2659 - mean_absolute_error: 0.3920 - val_loss: 1.0559 - val_mean_squared_error: 1.0559 - val_mean_absolute_error: 0.9424
# Epoch 40/40
# 386/386 [==============================] - 1s 2ms/step - loss: 0.2996 - mean_squared_error: 0.2996 - mean_absolute_error: 0.4137 - val_loss: 1.0303 - val_mean_squared_error: 1.0303 - val_mean_absolute_error: 0.9295
# EndTime : 2019-12-13 00:15:26.991902
# ZD-6474’s final rmse value is = 1.015025
# ZD-6474 R-squared value is = -0.544958

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE       R2value
# 0         17-AAG  1.807748 -3.023403e+00
# 1         AEW541  2.412222 -1.423331e-01
# 2        AZD0530  0.626771 -5.268961e-02
# 3        AZD6244  0.761654 -1.082915e-01
# 4      Erlotinib  0.600938 -1.249648e+00
# 5     Irinotecan  0.783823 -3.431606e-02
# 6       L-685458  1.232565 -4.215073e-02
# 7      Lapatinib  0.915624 -1.247073e+01
# 8         LBW242  1.018206  3.203358e-02
# 9      Nilotinib  0.873169  1.599685e-02
# 10      Nutlin-3  1.626226 -8.841240e-07
# 11    Paclitaxel  1.015025 -5.449578e-01
# 12  Panobinostat       NaN           NaN
# 13    PD-0325901       NaN           NaN
# 14    PD-0332991       NaN           NaN
# 15     PF2341066       NaN           NaN
# 16    PHA-665752       NaN           NaN
# 17       PLX4720       NaN           NaN
# 18        RAF265       NaN           NaN
# 19     Sorafenib       NaN           NaN
# 20        TAE684       NaN           NaN
# 21        TKI258       NaN           NaN
# 22     Topotecan       NaN           NaN
# 23       ZD-6474       NaN           NaN

# %%
workdir = "E://Ronny_TF//DrugResponsivenessGuidelines//Experiments//191205_rerun//ResNet//Result//EC-11K_individual_drugs//191212//ResNet"
result.to_csv(workdir +'//191212_EC11K_one_drug_one_model_ResNet_other_12drugs_metrics.csv')

# %%
x
# Out:
# <tf.Tensor 'activation_324/Relu:0' shape=(?, 128) dtype=float32>

# %%
num
# Out:
# 11
