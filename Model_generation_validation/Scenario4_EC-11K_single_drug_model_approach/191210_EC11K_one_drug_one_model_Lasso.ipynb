# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
import matplotlib
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score

workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"

# %%
file_list = os.listdir(workdir)[0:-1]

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[2].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list)
# Out:
# 24

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//191212_EC11K_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-lasso-and-lasso-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    lasso_regressor = Lasso(alpha=0.001)
    lasso_regressor.fit(train_X,train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = lasso_regressor.predict(test_X)
    predicted_value = predicted_classes
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//Lasso//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//Lasso"    

plt.savefig(workdir +'//191210_EC11K_one_drug_one_model_Lasso.png', dpi=400)
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
# Out:
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:13.471369
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:15.911845
# 17-AAG’s final rmse value is = 1.364540
# 17-AAG R-squared value is = 0.015828
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:16.184117
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:18.628579
# AEW541’s final rmse value is = 1.038675
# AEW541 R-squared value is = -0.229562
# AZD0530_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:30:18.905840
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:21.639529
# AZD0530’s final rmse value is = 0.856732
# AZD0530 R-squared value is = -0.194656
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:21.999566
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:24.853966
# AZD6244’s final rmse value is = 1.540872
# AZD6244 R-squared value is = -0.013534
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:25.124212
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:27.644834
# Erlotinib’s final rmse value is = 0.726615
# Erlotinib R-squared value is = -0.642318
# Irinotecan_//n
# train_X shape: (244, 18988)
# 244 train samples
# 62 test samples
# StartTime : 2019-12-12 18:30:27.827369
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:29.590653
# Irinotecan’s final rmse value is = 1.313791
# Irinotecan R-squared value is = 0.275703
# L-685458_//n
# train_X shape: (382, 18988)
# 382 train samples
# 96 test samples
# StartTime : 2019-12-12 18:30:29.841983
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:32.339303
# L-685458’s final rmse value is = 0.530718
# L-685458 R-squared value is = 0.260567
# Lapatinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:30:32.602601
# EndTime : 2019-12-12 18:30:34.920402
# Lapatinib’s final rmse value is = 0.768101
# Lapatinib R-squared value is = -0.097811
# LBW242_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:35.176717
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:37.512471
# LBW242’s final rmse value is = 1.231431
# LBW242 R-squared value is = -0.164703
# Nilotinib_//n
# train_X shape: (325, 18988)
# 325 train samples
# 82 test samples
# StartTime : 2019-12-12 18:30:37.739865
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:39.723559
# Nilotinib’s final rmse value is = 0.991664
# Nilotinib R-squared value is = 0.119291
# Nutlin-3_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:30:39.992839
# EndTime : 2019-12-12 18:30:42.685640
# Nutlin-3’s final rmse value is = 0.289099
# Nutlin-3 R-squared value is = -0.471549
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:42.939986
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:45.300649
# Paclitaxel’s final rmse value is = 1.688257
# Paclitaxel R-squared value is = 0.142340
# Panobinostat_//n
# train_X shape: (389, 18988)
# 389 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:45.560956
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:47.887730
# Panobinostat’s final rmse value is = 0.692281
# Panobinostat R-squared value is = 0.409959
# PD-0325901_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:30:48.159006
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:50.508722
# PD-0325901’s final rmse value is = 1.927858
# PD-0325901 R-squared value is = 0.270361
# PD-0332991_//n
# train_X shape: (336, 18988)
# 336 train samples
# 85 test samples
# StartTime : 2019-12-12 18:30:50.745091
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:52.802589
# PD-0332991’s final rmse value is = 0.685281
# PD-0332991 R-squared value is = -0.258404
# PF2341066_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:30:53.056909
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:55.359751
# PF2341066’s final rmse value is = 0.754645
# PF2341066 R-squared value is = -0.087986
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:30:55.619060
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:30:58.618040
# PHA-665752’s final rmse value is = 0.547971
# PHA-665752 R-squared value is = -0.870556
# PLX4720_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 18:30:58.875379
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:01.178193
# PLX4720’s final rmse value is = 0.641685
# PLX4720 R-squared value is = 0.306795
# RAF265_//n
# train_X shape: (357, 18988)
# 357 train samples
# 90 test samples
# StartTime : 2019-12-12 18:31:01.413587
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:03.605703
# RAF265’s final rmse value is = 1.230977
# RAF265 R-squared value is = -0.039467
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 18:31:03.860051
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:06.144914
# Sorafenib’s final rmse value is = 0.445046
# Sorafenib R-squared value is = -2.182496
# TAE684_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:31:06.410205
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:08.704073
# TAE684’s final rmse value is = 1.047531
# TAE684 R-squared value is = -0.024524
# TKI258_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:31:08.978340
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:11.272204
# TKI258’s final rmse value is = 0.905907
# TKI258 R-squared value is = -0.059174
# Topotecan_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 18:31:11.527554
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:13.808423
# Topotecan’s final rmse value is = 1.400407
# Topotecan R-squared value is = 0.258438
# ZD-6474_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 18:31:14.063740
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# EndTime : 2019-12-12 18:31:16.361596
# ZD-6474’s final rmse value is = 0.810170
# ZD-6474 R-squared value is = 0.015727

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.364540  0.015828
# 1         AEW541  1.038675 -0.229562
# 2        AZD0530  0.856732 -0.194656
# 3        AZD6244  1.540872 -0.013534
# 4      Erlotinib  0.726615 -0.642318
# 5     Irinotecan  1.313791  0.275703
# 6       L-685458  0.530718  0.260567
# 7      Lapatinib  0.768101 -0.097811
# 8         LBW242  1.231431 -0.164703
# 9      Nilotinib  0.991664  0.119291
# 10      Nutlin-3  0.289099 -0.471549
# 11    Paclitaxel  1.688257  0.142340
# 12  Panobinostat  0.692281  0.409959
# 13    PD-0325901  1.927858  0.270361
# 14    PD-0332991  0.685281 -0.258404
# 15     PF2341066  0.754645 -0.087986
# 16    PHA-665752  0.547971 -0.870556
# 17       PLX4720  0.641685  0.306795
# 18        RAF265  1.230977 -0.039467
# 19     Sorafenib  0.445046 -2.182496
# 20        TAE684  1.047531 -0.024524
# 21        TKI258  0.905907 -0.059174
# 22     Topotecan  1.400407  0.258438
# 23       ZD-6474  0.810170  0.015727

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//Lasso" 
result.to_csv(workdir +'//191212_EC11K_one_drug_one_model_Lasso_24drugs_metrics.csv')
