# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"

# %%
file_list = os.listdir(workdir)[0:-1]

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[2].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list)
# Out:
# 24

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.3)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//191212_EC11K_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-peXGBorm-XGB-and-XGB-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    import xgboost as xgb
    model = xgb.XGBRegressor()
    model.fit(train_X,train_y)
    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)


    predicted_classes = model.predict(test_X)
    predicted_value = predicted_classes
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//XGB//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=10)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//XGB"    

plt.savefig(workdir +'//191210_EC11K_one_drug_one_model_XGB.png', dpi=400)
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
# Out:
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:22:13.314364
# StartTime : 2019-12-12 17:22:13.314364
# [17:22:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:23:10.482221
# 17-AAG’s final rmse value is = 1.341247
# 17-AAG R-squared value is = 0.049141
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:23:10.824327
# StartTime : 2019-12-12 17:23:10.824327
# [17:23:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:24:14.550493
# AEW541’s final rmse value is = 0.889154
# AEW541 R-squared value is = 0.098958
# AZD0530_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:24:14.896567
# StartTime : 2019-12-12 17:24:14.896567
# [17:24:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:25:22.517783
# AZD0530’s final rmse value is = 0.838664
# AZD0530 R-squared value is = -0.144799
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:25:22.838905
# StartTime : 2019-12-12 17:25:22.838905
# [17:25:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:26:28.919240
# AZD6244’s final rmse value is = 1.530886
# AZD6244 R-squared value is = -0.000440
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:26:29.246367
# StartTime : 2019-12-12 17:26:29.246367
# [17:26:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:27:34.264528
# Erlotinib’s final rmse value is = 0.548198
# Erlotinib R-squared value is = 0.065188
# Irinotecan_//n
# train_X shape: (244, 18988)
# 244 train samples
# 62 test samples
# StartTime : 2019-12-12 17:27:34.498901
# StartTime : 2019-12-12 17:27:34.498901
# [17:27:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:28:15.841670
# Irinotecan’s final rmse value is = 1.288024
# Irinotecan R-squared value is = 0.303836
# L-685458_//n
# train_X shape: (382, 18988)
# 382 train samples
# 96 test samples
# StartTime : 2019-12-12 17:28:16.151839
# StartTime : 2019-12-12 17:28:16.151839
# [17:28:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:29:14.394141
# L-685458’s final rmse value is = 0.546482
# L-685458 R-squared value is = 0.215990
# Lapatinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:29:14.760134
# StartTime : 2019-12-12 17:29:14.760134
# [17:29:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:30:17.258058
# Lapatinib’s final rmse value is = 0.718303
# Lapatinib R-squared value is = 0.039923
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:30:17.571188
# StartTime : 2019-12-12 17:30:17.571188
# [17:30:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:31:15.532212
# LBW242’s final rmse value is = 1.192169
# LBW242 R-squared value is = -0.091618
# Nilotinib_//n
# train_X shape: (325, 18988)
# 325 train samples
# 82 test samples
# StartTime : 2019-12-12 17:31:15.807476
# StartTime : 2019-12-12 17:31:15.807476
# [17:31:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:32:05.117632
# Nilotinib’s final rmse value is = 1.040951
# Nilotinib R-squared value is = 0.029571
# Nutlin-3_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:32:05.413873
# StartTime : 2019-12-12 17:32:05.413873
# [17:32:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:33:01.407851
# Nutlin-3’s final rmse value is = 0.650818
# Nutlin-3 R-squared value is = -6.457650
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:33:01.739949
# StartTime : 2019-12-12 17:33:01.740932
# [17:33:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:34:06.319261
# Paclitaxel’s final rmse value is = 1.619254
# Paclitaxel R-squared value is = 0.211016
# Panobinostat_//n
# train_X shape: (389, 18988)
# 389 train samples
# 98 test samples
# StartTime : 2019-12-12 17:34:06.652402
# StartTime : 2019-12-12 17:34:06.652402
# [17:34:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:35:10.131229
# Panobinostat’s final rmse value is = 0.747040
# Panobinostat R-squared value is = 0.312923
# PD-0325901_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:35:10.486247
# StartTime : 2019-12-12 17:35:10.486247
# [17:35:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:36:10.523499
# PD-0325901’s final rmse value is = 2.044801
# PD-0325901 R-squared value is = 0.179157
# PD-0332991_//n
# train_X shape: (336, 18988)
# 336 train samples
# 85 test samples
# StartTime : 2019-12-12 17:36:10.826689
# StartTime : 2019-12-12 17:36:10.826689
# [17:36:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:36:57.601651
# PD-0332991’s final rmse value is = 0.636216
# PD-0332991 R-squared value is = -0.084654
# PF2341066_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:36:57.907824
# StartTime : 2019-12-12 17:36:57.907824
# [17:36:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:37:53.321638
# PF2341066’s final rmse value is = 0.621644
# PF2341066 R-squared value is = 0.261720
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:37:53.620837
# StartTime : 2019-12-12 17:37:53.620837
# [17:37:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:38:46.011784
# PHA-665752’s final rmse value is = 0.561834
# PHA-665752 R-squared value is = -0.966398
# PLX4720_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:38:46.321955
# StartTime : 2019-12-12 17:38:46.321955
# [17:38:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:39:38.647020
# PLX4720’s final rmse value is = 0.618548
# PLX4720 R-squared value is = 0.355884
# RAF265_//n
# train_X shape: (357, 18988)
# 357 train samples
# 90 test samples
# StartTime : 2019-12-12 17:39:38.933254
# StartTime : 2019-12-12 17:39:38.933254
# [17:39:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:40:30.547283
# RAF265’s final rmse value is = 1.210216
# RAF265 R-squared value is = -0.004701
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:40:30.884348
# StartTime : 2019-12-12 17:40:30.884348
# [17:40:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:41:24.794203
# Sorafenib’s final rmse value is = 0.389497
# Sorafenib R-squared value is = -1.437623
# TAE684_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:41:25.119361
# StartTime : 2019-12-12 17:41:25.119361
# [17:41:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:42:21.077741
# TAE684’s final rmse value is = 0.857383
# TAE684 R-squared value is = 0.313660
# TKI258_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:42:21.379931
# StartTime : 2019-12-12 17:42:21.379931
# [17:42:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:43:16.299091
# TKI258’s final rmse value is = 0.794511
# TKI258 R-squared value is = 0.185296
# Topotecan_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:43:16.627185
# StartTime : 2019-12-12 17:43:16.628182
# [17:43:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:44:13.364480
# Topotecan’s final rmse value is = 1.365983
# Topotecan R-squared value is = 0.294448
# ZD-6474_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:44:13.686618
# StartTime : 2019-12-12 17:44:13.686618
# [17:44:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2019-12-12 17:45:07.404988
# ZD-6474’s final rmse value is = 0.790490
# ZD-6474 R-squared value is = 0.062965

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.341247  0.049141
# 1         AEW541  0.889154  0.098958
# 2        AZD0530  0.838664 -0.144799
# 3        AZD6244  1.530886 -0.000440
# 4      Erlotinib  0.548198  0.065188
# 5     Irinotecan  1.288024  0.303836
# 6       L-685458  0.546482  0.215990
# 7      Lapatinib  0.718303  0.039923
# 8         LBW242  1.192169 -0.091618
# 9      Nilotinib  1.040951  0.029571
# 10      Nutlin-3  0.650818 -6.457650
# 11    Paclitaxel  1.619254  0.211016
# 12  Panobinostat  0.747040  0.312923
# 13    PD-0325901  2.044801  0.179157
# 14    PD-0332991  0.636216 -0.084654
# 15     PF2341066  0.621644  0.261720
# 16    PHA-665752  0.561834 -0.966398
# 17       PLX4720  0.618548  0.355884
# 18        RAF265  1.210216 -0.004701
# 19     Sorafenib  0.389497 -1.437623
# 20        TAE684  0.857383  0.313660
# 21        TKI258  0.794511  0.185296
# 22     Topotecan  1.365983  0.294448
# 23       ZD-6474  0.790490  0.062965

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//XGB" 
result.to_csv(workdir +'//191212_EC11K_one_drug_one_model_XGB_24drugs_metrics.csv')
