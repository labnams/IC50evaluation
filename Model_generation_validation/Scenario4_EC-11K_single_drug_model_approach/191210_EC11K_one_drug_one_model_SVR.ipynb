# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt

from sklearn.metrics import r2_score

workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"

# %%
file_list = os.listdir(workdir)[0:-1]

# %%
drug_list = []
for x in range(len(file_list)):
    drug_file = file_list[x].split("_")[2].split(".")[0]
    drug_list.append(drug_file)

# %%
len(drug_list)
# Out:
# 24

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for num in range(len(drug_list)):
    dname = drug_list[num]
    print('%s_//n' % dname)
    dataset = np.load(workdir + "//191212_EC11K_%s.npz" % dname)
    x = dataset['x']
    y = dataset['y']
    train_X, test_X, train_y, test_y = train_test_split(x,y,test_size=0.2,random_state=42)
    
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # https://towardsdatascience.com/how-to-perform-SVR-and-SVR-regression-in-python-3b3b75541ad8
    # https://brunch.co.kr/@itschloe1/11
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    import numpy as np
    from sklearn.svm import SVR

    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    # #############################################################################
    # Fit regression model
    svr_lin = SVR(C=0.01)
    svr_lin.fit(train_X, train_y).predict(test_X)
    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = svr_lin.predict(test_X)
    predicted_value = predicted_classes
        
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//SVR//one_drug_one_model"
    c.to_csv(workdir + '//%s_result.csv' % dname)
    
    
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num+1)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//SVR"    

plt.savefig(workdir +'//191210_EC11K_one_drug_one_model_SVR.png', dpi=400)
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Dataset//EC11K_Znorm//individual_drugs"
# Out:
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:16:17.840525
# StartTime : 2019-12-12 17:16:17.841521
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:21.705206
# 17-AAG’s final rmse value is = 1.373287
# 17-AAG R-squared value is = 0.003171
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:16:22.733435
# StartTime : 2019-12-12 17:16:22.734432
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:26.460470
# AEW541’s final rmse value is = 1.069271
# AEW541 R-squared value is = -0.303067
# AZD0530_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:16:27.457824
# StartTime : 2019-12-12 17:16:27.457824
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:31.087126
# AZD0530’s final rmse value is = 0.851975
# AZD0530 R-squared value is = -0.181427
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:16:32.063489
# StartTime : 2019-12-12 17:16:32.063489
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:35.532246
# AZD6244’s final rmse value is = 1.664215
# AZD6244 R-squared value is = -0.182290
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:16:36.483669
# StartTime : 2019-12-12 17:16:36.483669
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:39.575404
# Erlotinib’s final rmse value is = 0.575323
# Erlotinib R-squared value is = -0.029607
# Irinotecan_//n
# train_X shape: (244, 18988)
# 244 train samples
# 62 test samples
# StartTime : 2019-12-12 17:16:40.347368
# StartTime : 2019-12-12 17:16:40.347368
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:41.849351
# Irinotecan’s final rmse value is = 1.534196
# Irinotecan R-squared value is = 0.012299
# L-685458_//n
# train_X shape: (382, 18988)
# 382 train samples
# 96 test samples
# StartTime : 2019-12-12 17:16:42.484654
# StartTime : 2019-12-12 17:16:42.484654
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:44.744603
# L-685458’s final rmse value is = 0.621741
# L-685458 R-squared value is = -0.014823
# Lapatinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:16:45.438755
# StartTime : 2019-12-12 17:16:45.438755
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:48.574343
# Lapatinib’s final rmse value is = 0.749692
# Lapatinib R-squared value is = -0.045818
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:16:49.459975
# StartTime : 2019-12-12 17:16:49.459975
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:51.531434
# LBW242’s final rmse value is = 1.163647
# LBW242 R-squared value is = -0.040010
# Nilotinib_//n
# train_X shape: (325, 18988)
# 325 train samples
# 82 test samples
# StartTime : 2019-12-12 17:16:52.131832
# StartTime : 2019-12-12 17:16:52.131832
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:54.474596
# Nilotinib’s final rmse value is = 1.076924
# Nilotinib R-squared value is = -0.038659
# Nutlin-3_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:16:55.203617
# StartTime : 2019-12-12 17:16:55.203617
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:16:56.737516
# Nutlin-3’s final rmse value is = 0.242679
# Nutlin-3 R-squared value is = -0.036921
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:16:57.285052
# StartTime : 2019-12-12 17:16:57.285052
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:01.103840
# Paclitaxel’s final rmse value is = 1.826282
# Paclitaxel R-squared value is = -0.003631
# Panobinostat_//n
# train_X shape: (389, 18988)
# 389 train samples
# 98 test samples
# StartTime : 2019-12-12 17:17:02.098211
# StartTime : 2019-12-12 17:17:02.098211
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:05.924949
# Panobinostat’s final rmse value is = 0.908141
# Panobinostat R-squared value is = -0.015369
# PD-0325901_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:17:06.941254
# StartTime : 2019-12-12 17:17:06.941254
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:10.858757
# PD-0325901’s final rmse value is = 2.690096
# PD-0325901 R-squared value is = -0.420672
# PD-0332991_//n
# train_X shape: (336, 18988)
# 336 train samples
# 85 test samples
# StartTime : 2019-12-12 17:17:11.853099
# StartTime : 2019-12-12 17:17:11.853099
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:13.770998
# PD-0332991’s final rmse value is = 0.623181
# PD-0332991 R-squared value is = -0.040663
# PF2341066_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:17:14.398321
# StartTime : 2019-12-12 17:17:14.398321
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:17.882008
# PF2341066’s final rmse value is = 0.752690
# PF2341066 R-squared value is = -0.082357
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:17:18.830443
# StartTime : 2019-12-12 17:17:18.830443
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:20.975735
# PHA-665752’s final rmse value is = 0.401040
# PHA-665752 R-squared value is = -0.001914
# PLX4720_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:17:21.641928
# StartTime : 2019-12-12 17:17:21.641928
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:24.099384
# PLX4720’s final rmse value is = 0.786776
# PLX4720 R-squared value is = -0.042126
# RAF265_//n
# train_X shape: (357, 18988)
# 357 train samples
# 90 test samples
# StartTime : 2019-12-12 17:17:24.812448
# StartTime : 2019-12-12 17:17:24.812448
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:27.927120
# RAF265’s final rmse value is = 1.221347
# RAF265 R-squared value is = -0.023268
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2019-12-12 17:17:28.793830
# StartTime : 2019-12-12 17:17:28.793830
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:31.833705
# Sorafenib’s final rmse value is = 0.247854
# Sorafenib R-squared value is = 0.012926
# TAE684_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:17:32.690385
# StartTime : 2019-12-12 17:17:32.690385
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:36.424434
# TAE684’s final rmse value is = 1.084906
# TAE684 R-squared value is = -0.098937
# TKI258_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:17:37.433701
# StartTime : 2019-12-12 17:17:37.433701
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:40.995206
# TKI258’s final rmse value is = 0.987842
# TKI258 R-squared value is = -0.259434
# Topotecan_//n
# train_X shape: (392, 18988)
# 392 train samples
# 99 test samples
# StartTime : 2019-12-12 17:17:41.959628
# StartTime : 2019-12-12 17:17:41.959628
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:45.836262
# Topotecan’s final rmse value is = 1.613811
# Topotecan R-squared value is = 0.015209
# ZD-6474_//n
# train_X shape: (386, 18988)
# 386 train samples
# 97 test samples
# StartTime : 2019-12-12 17:17:46.876481
# StartTime : 2019-12-12 17:17:46.876481
# C:\Users\ylab\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# EndTime : 2019-12-12 17:17:50.674327
# ZD-6474’s final rmse value is = 0.908041
# ZD-6474 R-squared value is = -0.236444

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE   R2value
# 0         17-AAG  1.373287  0.003171
# 1         AEW541  1.069271 -0.303067
# 2        AZD0530  0.851975 -0.181427
# 3        AZD6244  1.664215 -0.182290
# 4      Erlotinib  0.575323 -0.029607
# 5     Irinotecan  1.534196  0.012299
# 6       L-685458  0.621741 -0.014823
# 7      Lapatinib  0.749692 -0.045818
# 8         LBW242  1.163647 -0.040010
# 9      Nilotinib  1.076924 -0.038659
# 10      Nutlin-3  0.242679 -0.036921
# 11    Paclitaxel  1.826282 -0.003631
# 12  Panobinostat  0.908141 -0.015369
# 13    PD-0325901  2.690096 -0.420672
# 14    PD-0332991  0.623181 -0.040663
# 15     PF2341066  0.752690 -0.082357
# 16    PHA-665752  0.401040 -0.001914
# 17       PLX4720  0.786776 -0.042126
# 18        RAF265  1.221347 -0.023268
# 19     Sorafenib  0.247854  0.012926
# 20        TAE684  1.084906 -0.098937
# 21        TKI258  0.987842 -0.259434
# 22     Topotecan  1.613811  0.015209
# 23       ZD-6474  0.908041 -0.236444

# %%
workdir = "D://ResIC50_finalized_data//191205_rerun//ResNet//Result//EC-11K_znorm//Individual_drugs//SVR" 
result.to_csv(workdir +'//191212_EC11K_one_drug_one_model_SVR_24drugs_metrics.csv')
