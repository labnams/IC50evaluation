# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import matplotlib
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score


# input file path
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario5_individual_model_approach"

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(workdir + "//200914_EC11K_%s.npz" % dname)
    ss0 = np.load(workdir + '//200914_EC11K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]

    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    ridge_regressor = Ridge(alpha=0.001)
    ridge_regressor.fit(train_X,train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = ridge_regressor.predict(test_X)
    predicted_value = predicted_classes
        
    
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Table//Ridge"
    c.to_csv(workdir + '//200915_scenario5_Ridge_%s_pred_and_val_result.csv'% dname, index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario5_individual_model_approach"
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Figure"    

plt.savefig(workdir +'//200915_scenario5_Ridge_plot.png', dpi=400)
# Out:
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:08.661032
# EndTime : 2020-09-18 09:56:08.732840
# AEW541’s final rmse value is = 0.814540
# AEW541 R-squared value is = -0.072227
# Nilotinib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.64588e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (326, 18988)
# 326 train samples
# 81 test samples
# StartTime : 2020-09-18 09:56:09.025059
# EndTime : 2020-09-18 09:56:09.069939
# Nilotinib’s final rmse value is = 0.959997
# Nilotinib R-squared value is = 0.136542
# 17-AAG_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.73951e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:09.402053
# EndTime : 2020-09-18 09:56:09.452914
# 17-AAG’s final rmse value is = 1.102708
# 17-AAG R-squared value is = 0.064111
# PHA-665752_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.37772e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:09.778045
# EndTime : 2020-09-18 09:56:09.830904
# PHA-665752’s final rmse value is = 0.405754
# PHA-665752 R-squared value is = -7.278265
# Lapatinib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.28297e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:10.164014
# EndTime : 2020-09-18 09:56:10.231832
# Lapatinib’s final rmse value is = 0.597002
# Lapatinib R-squared value is = -0.289075
# Nutlin-3_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.01419e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:10.569928
# EndTime : 2020-09-18 09:56:10.627775
# Nutlin-3’s final rmse value is = 0.307955
# Nutlin-3 R-squared value is = -11.937700
# AZD0530_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.93981e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:10.969860
# EndTime : 2020-09-18 09:56:11.024711
# AZD0530’s final rmse value is = 0.920197
# AZD0530 R-squared value is = 0.094342
# PF2341066_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.38849e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:11.415665
# EndTime : 2020-09-18 09:56:11.474509
# PF2341066’s final rmse value is = 0.809811
# PF2341066 R-squared value is = 0.045099
# L-685458_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.91025e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (383, 18988)
# 383 train samples
# 95 test samples
# StartTime : 2020-09-18 09:56:11.797645
# EndTime : 2020-09-18 09:56:11.850504
# L-685458’s final rmse value is = 0.654326
# L-685458 R-squared value is = 0.068466
# ZD-6474_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.434e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-18 09:56:12.157683
# EndTime : 2020-09-18 09:56:12.224503
# ZD-6474’s final rmse value is = 0.719175
# ZD-6474 R-squared value is = -0.222231
# Panobinostat_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.69517e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (390, 18988)
# 390 train samples
# 97 test samples
# StartTime : 2020-09-18 09:56:12.597507
# EndTime : 2020-09-18 09:56:12.665324
# Panobinostat’s final rmse value is = 0.709154
# Panobinostat R-squared value is = 0.417530
# Sorafenib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.29242e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:13.021373
# EndTime : 2020-09-18 09:56:13.082209
# Sorafenib’s final rmse value is = 0.731231
# Sorafenib R-squared value is = -0.580171
# Irinotecan_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.72296e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (245, 18988)
# 245 train samples
# 61 test samples
# StartTime : 2020-09-18 09:56:13.326556
# EndTime : 2020-09-18 09:56:13.363458
# Irinotecan’s final rmse value is = 1.061932
# Irinotecan R-squared value is = 0.353881
# Topotecan_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.55456e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:13.722497
# EndTime : 2020-09-18 09:56:13.777350
# Topotecan’s final rmse value is = 1.224018
# Topotecan R-squared value is = 0.320433
# LBW242_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.58694e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:14.117442
# EndTime : 2020-09-18 09:56:14.170301
# LBW242’s final rmse value is = 0.671893
# LBW242 R-squared value is = -3.303919
# PD-0325901_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.2984e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:14.500417
# EndTime : 2020-09-18 09:56:14.566242
# PD-0325901’s final rmse value is = 1.955651
# PD-0325901 R-squared value is = 0.243934
# PD-0332991_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.36614e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (337, 18988)
# 337 train samples
# 84 test samples
# StartTime : 2020-09-18 09:56:14.859457
# EndTime : 2020-09-18 09:56:14.907329
# PD-0332991’s final rmse value is = 0.657558
# PD-0332991 R-squared value is = -0.034676
# Paclitaxel_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.07021e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:15.223483
# EndTime : 2020-09-18 09:56:15.283324
# Paclitaxel’s final rmse value is = 2.106172
# Paclitaxel R-squared value is = -0.017058
# PLX4720_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.88283e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-18 09:56:15.613442
# EndTime : 2020-09-18 09:56:15.670289
# PLX4720’s final rmse value is = 0.683761
# PLX4720 R-squared value is = 0.416622
# RAF265_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.22928e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (358, 18988)
# 358 train samples
# 89 test samples
# StartTime : 2020-09-18 09:56:16.002402
# EndTime : 2020-09-18 09:56:16.068226
# RAF265’s final rmse value is = 1.114408
# RAF265 R-squared value is = 0.034445
# TAE684_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.72836e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:16.420283
# EndTime : 2020-09-18 09:56:16.477132
# TAE684’s final rmse value is = 1.219769
# TAE684 R-squared value is = 0.112900
# TKI258_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.13156e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:16.811237
# EndTime : 2020-09-18 09:56:16.871078
# TKI258’s final rmse value is = 0.680209
# TKI258 R-squared value is = 0.046557
# Erlotinib_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=3.37187e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:17.238097
# EndTime : 2020-09-18 09:56:17.315893
# Erlotinib’s final rmse value is = 0.730554
# Erlotinib R-squared value is = 0.041663
# AZD6244_//n
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.01738e-09): result may not be accurate.
#   overwrite_a=False)
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:17.678917
# EndTime : 2020-09-18 09:56:17.763691
# AZD6244’s final rmse value is = 1.183464
# AZD6244 R-squared value is = 0.151880
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=4.10766e-09): result may not be accurate.
#   overwrite_a=False)

# %%
num
# Out:
# 25

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE    R2value
# 0         AEW541  0.814540  -0.072227
# 1      Nilotinib  0.959997   0.136542
# 2         17-AAG  1.102708   0.064111
# 3     PHA-665752  0.405754  -7.278265
# 4      Lapatinib  0.597002  -0.289075
# 5       Nutlin-3  0.307955 -11.937700
# 6        AZD0530  0.920197   0.094342
# 7      PF2341066  0.809811   0.045099
# 8       L-685458  0.654326   0.068466
# 9        ZD-6474  0.719175  -0.222231
# 10  Panobinostat  0.709154   0.417530
# 11     Sorafenib  0.731231  -0.580171
# 12    Irinotecan  1.061932   0.353881
# 13     Topotecan  1.224018   0.320433
# 14        LBW242  0.671893  -3.303919
# 15    PD-0325901  1.955651   0.243934
# 16    PD-0332991  0.657558  -0.034676
# 17    Paclitaxel  2.106172  -0.017058
# 18       PLX4720  0.683761   0.416622
# 19        RAF265  1.114408   0.034445
# 20        TAE684  1.219769   0.112900
# 21        TKI258  0.680209   0.046557
# 22     Erlotinib  0.730554   0.041663
# 23       AZD6244  1.183464   0.151880

# %%
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach" 
result.to_csv(workdir +'//200915_scenario5_Ridge_24drugs_metrics.csv', index=False)
