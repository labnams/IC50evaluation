# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
import matplotlib
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score

# input file path
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario5_individual_model_approach"

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(workdir + "//200914_EC11K_%s.npz" % dname)
    ss0 = np.load(workdir + '//200914_EC11K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]

    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)

    lasso_regressor = Lasso(alpha=0.001)
    lasso_regressor.fit(train_X,train_y)

    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)
    
    predicted_classes = lasso_regressor.predict(test_X)
    predicted_value = predicted_classes

    
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Table//Lasso"
    c.to_csv(workdir + '//200915_scenario5_Lasso_%s_pred_and_val_result.csv' % dname, index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario5_individual_model_approach"
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Figure"    

plt.savefig(workdir +'//200915_scenario5_Lasso_plot.png', dpi=400)
# Out:
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:55:54.257576
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4741508960723877, tolerance: 0.02711053378880024
#   positive)
# EndTime : 2020-09-18 09:55:57.107926
# AEW541’s final rmse value is = 0.925429
# AEW541 R-squared value is = -0.384037
# Nilotinib_//n
# train_X shape: (326, 18988)
# 326 train samples
# 81 test samples
# StartTime : 2020-09-18 09:55:57.381195
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6076542139053345, tolerance: 0.030471911653876305
#   positive)
# EndTime : 2020-09-18 09:55:59.712960
# Nilotinib’s final rmse value is = 1.057351
# Nilotinib R-squared value is = -0.047464
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:00.028117
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.8456857204437256, tolerance: 0.09724763035774231
#   positive)
# EndTime : 2020-09-18 09:56:02.610212
# 17-AAG’s final rmse value is = 1.344921
# 17-AAG R-squared value is = -0.392184
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:02.929372
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1921105980873108, tolerance: 0.011618178337812424
#   positive)
# EndTime : 2020-09-18 09:56:06.321289
# PHA-665752’s final rmse value is = 0.534906
# PHA-665752 R-squared value is = -13.386912
# Lapatinib_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:06.650411
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4499291777610779, tolerance: 0.0274934284389019
#   positive)
# EndTime : 2020-09-18 09:56:09.582568
# Lapatinib’s final rmse value is = 0.841361
# Lapatinib R-squared value is = -1.560301
# Nutlin-3_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:09.927645
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2432575821876526, tolerance: 0.007710447534918785
#   positive)
# EndTime : 2020-09-18 09:56:13.438257
# Nutlin-3’s final rmse value is = 0.340374
# Nutlin-3 R-squared value is = -14.805036
# AZD0530_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:13.782338
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6528247594833374, tolerance: 0.02354738675057888
#   positive)
# EndTime : 2020-09-18 09:56:16.850136
# AZD0530’s final rmse value is = 0.990075
# AZD0530 R-squared value is = -0.048427
# PF2341066_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:17.221142
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.586195945739746, tolerance: 0.023991459980607033
#   positive)
# EndTime : 2020-09-18 09:56:20.252037
# PF2341066’s final rmse value is = 0.918604
# PF2341066 R-squared value is = -0.228705
# L-685458_//n
# train_X shape: (383, 18988)
# 383 train samples
# 95 test samples
# StartTime : 2020-09-18 09:56:20.558219
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0860881805419922, tolerance: 0.01593216322362423
#   positive)
# EndTime : 2020-09-18 09:56:23.444500
# L-685458’s final rmse value is = 0.732391
# L-685458 R-squared value is = -0.167068
# ZD-6474_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-18 09:56:23.754670
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.99310302734375, tolerance: 0.02571379393339157
#   positive)
# EndTime : 2020-09-18 09:56:26.498334
# ZD-6474’s final rmse value is = 0.827128
# ZD-6474 R-squared value is = -0.616700
# Panobinostat_//n
# train_X shape: (390, 18988)
# 390 train samples
# 97 test samples
# StartTime : 2020-09-18 09:56:26.814489
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8886421322822571, tolerance: 0.02849719114601612
#   positive)
# EndTime : 2020-09-18 09:56:29.700781
# Panobinostat’s final rmse value is = 0.829921
# Panobinostat R-squared value is = 0.202252
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:30.035875
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4416672885417938, tolerance: 0.018064314499497414
#   positive)
# EndTime : 2020-09-18 09:56:32.748620
# Sorafenib’s final rmse value is = 0.855303
# Sorafenib R-squared value is = -1.161895
# Irinotecan_//n
# train_X shape: (245, 18988)
# 245 train samples
# 61 test samples
# StartTime : 2020-09-18 09:56:32.981996
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5178806781768799, tolerance: 0.04202764108777046
#   positive)
# EndTime : 2020-09-18 09:56:34.953723
# Irinotecan’s final rmse value is = 1.201473
# Irinotecan R-squared value is = 0.172922
# Topotecan_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:35.250929
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.600017070770264, tolerance: 0.0999259352684021
#   positive)
# EndTime : 2020-09-18 09:56:37.916801
# Topotecan’s final rmse value is = 1.440102
# Topotecan R-squared value is = 0.059317
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:38.209020
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.013859748840332, tolerance: 0.03493840992450714
#   positive)
# EndTime : 2020-09-18 09:56:40.752218
# LBW242’s final rmse value is = 0.936369
# LBW242 R-squared value is = -7.359071
# PD-0325901_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:41.068375
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.967233657836914, tolerance: 0.1887928694486618
#   positive)
# EndTime : 2020-09-18 09:56:43.751198
# PD-0325901’s final rmse value is = 2.112699
# PD-0325901 R-squared value is = 0.117627
# PD-0332991_//n
# train_X shape: (337, 18988)
# 337 train samples
# 84 test samples
# StartTime : 2020-09-18 09:56:44.009508
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.38755083084106445, tolerance: 0.011182527057826519
#   positive)
# EndTime : 2020-09-18 09:56:46.401112
# PD-0332991’s final rmse value is = 0.731738
# PD-0332991 R-squared value is = -0.281291
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-18 09:56:46.705300
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.3100032806396484, tolerance: 0.16578121483325958
#   positive)
# EndTime : 2020-09-18 09:56:49.257473
# Paclitaxel’s final rmse value is = 2.320838
# Paclitaxel R-squared value is = -0.234945
# PLX4720_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-18 09:56:49.587592
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3609304428100586, tolerance: 0.011019531637430191
#   positive)
# EndTime : 2020-09-18 09:56:52.214566
# PLX4720’s final rmse value is = 0.748312
# PLX4720 R-squared value is = 0.301274
# RAF265_//n
# train_X shape: (358, 18988)
# 358 train samples
# 89 test samples
# StartTime : 2020-09-18 09:56:52.502797
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5529468059539795, tolerance: 0.04983460158109665
#   positive)
# EndTime : 2020-09-18 09:56:55.112816
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-98ebb6aa22d1> in <module>()
#      53     c.columns=["Predicted","Test"]
#      54     workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Table//Lasso"
# ---> 55     c.to_csv(workdir + '//200915_scenario5_Lasso_%s_pred_and_val_result.csv', index=False)
#      56
#      57     # RMSE
#
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# C:\Users\ylab\AppData\Local\conda\conda\envs\ronny\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     397         if encoding:
#     398             # Encoding
# --> 399             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     400         elif is_text:
#     401             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Table//Lasso//200915_scenario5_Lasso_%s_pred_and_val_result.csv'

# %%
num

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']

# %%
result

# %%
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach" 
result.to_csv(workdir +'//200915_scenario5_Lasso_24drugs_metrics.csv', index=False)
