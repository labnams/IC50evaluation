# %%
import os
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
from datetime import datetime
import xgboost as xgb
import matplotlib
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score


# input file path
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario5_individual_model_approach"

# %%
drug_list = ["AEW541","Nilotinib","17-AAG","PHA-665752","Lapatinib","Nutlin-3"
            ,"AZD0530","PF2341066","L-685458","ZD-6474","Panobinostat","Sorafenib"
            ,"Irinotecan","Topotecan","LBW242","PD-0325901","PD-0332991","Paclitaxel"
            ,"PLX4720","RAF265","TAE684","TKI258","Erlotinib","AZD6244"]

# %%
rmselist = []
r2list = []

# drug_list = ["Topotecan"]
fig = plt.figure(figsize=(15,20),dpi=400)
fig.subplots_adjust(hspace=0.5, wspace=0.5)
num = 1
for dname in drug_list:
    
    print('%s_//n' % dname)
    # read input file and index file for training and test set
    dataset = np.load(workdir + "//200914_EC11K_%s.npz" % dname)
    ss0 = np.load(workdir + '//200914_EC11K_%s_0_8_2.npz' % dname)

    # input and index file assign
    x = dataset['x']
    y = dataset['y']
    # y_linear = dataset['y_lnIC50']
    ss0_train = ss0['train']
    ss0_test = ss0['test']
    
    # training and test dataset assign
    train_X, train_y = x[ss0_train], y[ss0_train]
    test_X, test_y = x[ss0_test], y[ss0_test]

    # data typing and the number of dataset
    train_X = train_X.astype('float32')
    test_X = test_X.astype('float32')
    # train_X /= 255
    # test_X /= 255
    print('train_X shape:', train_X.shape)
    print(train_X.shape[0], 'train samples')
    print(test_X.shape[0], 'test samples')
    
    # model fitting
    StartTime8 = datetime.now()
    print("StartTime :", StartTime8)
    model = xgb.XGBRegressor()
    model.fit(train_X,train_y)
    EndTime8 = datetime.now()
    print("EndTime :", EndTime8)


    predicted_classes = model.predict(test_X)
    predicted_value = predicted_classes
        
    
    # saving predicted ln(IC50)s and ln(IC50)s in the test set
    a = pd.DataFrame(predicted_value)
    b = pd.DataFrame(test_y)
    c = pd.concat([a,b], axis=1)
    c.columns=["Predicted","Test"]
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Table//XGB"
    c.to_csv(workdir + '//200915_scenario5_XGB_%s_pred_and_val_result.csv', index=False)

    # RMSE
    rse = ((b[0]-a[0])**2).sum()
    mse = rse / len(b)
    rmse = np.sqrt(mse)
    print("%s’s final rmse value is = %f" % (dname,rmse))
    
    # R-squared value
    r2_value = r2_score(b,a)
    print("%s R-squared value is = %f" % (dname,r2_value))
    rmselist.append(rmse)
    r2list.append(r2_value)
          
    plt.subplot(6,4,num)
    plt.scatter(test_y,predicted_value,c='orange')
    plt.title(dname,fontdict ={'fontsize' : 20},fontname="Arial",y = 1.02)
    plt.tick_params(labelsize=15)
    
    num += 1
#     plt.scatter(test_y,predicted_value,c='red')
#     plt.xlabel('test_IC50_value')
#     plt.ylabel('predicted_IC50_value')
#     plt.savefig(workdir + '//%s_test_scatterplot.png' % dname)
    
    workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Dataset//Scenario5_individual_model_approach"
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach//Figure"    

plt.savefig(workdir +'//200915_scenario5_XGB_plot.png', dpi=400)
# Out:
# AEW541_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 16:47:19.301213
# [16:47:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:47:56.810043
# AEW541’s final rmse value is = 0.748134
# AEW541 R-squared value is = 0.095475
# Nilotinib_//n
# train_X shape: (326, 18988)
# 326 train samples
# 81 test samples
# StartTime : 2020-09-16 16:47:57.064166
# [16:47:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:48:26.088802
# Nilotinib’s final rmse value is = 1.086551
# Nilotinib R-squared value is = -0.106118
# 17-AAG_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 16:48:26.379026
# [16:48:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:49:02.039553
# 17-AAG’s final rmse value is = 1.081337
# 17-AAG R-squared value is = 0.100036
# PHA-665752_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 16:49:02.343766
# [16:49:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:49:35.509995
# PHA-665752’s final rmse value is = 0.281316
# PHA-665752 R-squared value is = -2.979270
# Lapatinib_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 16:49:35.808199
# [16:49:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:50:10.420386
# Lapatinib’s final rmse value is = 0.598046
# Lapatinib R-squared value is = -0.293585
# Nutlin-3_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 16:50:10.723938
# [16:50:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:50:44.389434
# Nutlin-3’s final rmse value is = 0.722482
# Nutlin-3 R-squared value is = -70.209260
# AZD0530_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 16:50:44.671651
# [16:50:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:51:20.056322
# AZD0530’s final rmse value is = 0.945481
# AZD0530 R-squared value is = 0.043889
# PF2341066_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 16:51:20.350505
# [16:51:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:51:56.458258
# PF2341066’s final rmse value is = 0.783995
# PF2341066 R-squared value is = 0.105012
# L-685458_//n
# train_X shape: (383, 18988)
# 383 train samples
# 95 test samples
# StartTime : 2020-09-16 16:51:56.753441
# [16:51:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:52:37.254822
# L-685458’s final rmse value is = 0.659312
# L-685458 R-squared value is = 0.054217
# ZD-6474_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-16 16:52:37.587952
# [16:52:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:53:21.784155
# ZD-6474’s final rmse value is = 0.700615
# ZD-6474 R-squared value is = -0.159959
# Panobinostat_//n
# train_X shape: (390, 18988)
# 390 train samples
# 97 test samples
# StartTime : 2020-09-16 16:53:22.102277
# [16:53:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:54:02.336917
# Panobinostat’s final rmse value is = 0.710832
# Panobinostat R-squared value is = 0.414771
# Sorafenib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 16:54:02.654983
# [16:54:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:54:45.967257
# Sorafenib’s final rmse value is = 0.581474
# Sorafenib R-squared value is = 0.000796
# Irinotecan_//n
# train_X shape: (245, 18988)
# 245 train samples
# 61 test samples
# StartTime : 2020-09-16 16:54:46.200635
# [16:54:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:55:16.097422
# Irinotecan’s final rmse value is = 1.109511
# Irinotecan R-squared value is = 0.294686
# Topotecan_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 16:55:16.407101
# [16:55:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:55:59.371789
# Topotecan’s final rmse value is = 1.137705
# Topotecan R-squared value is = 0.412895
# LBW242_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 16:55:59.702888
# [16:55:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:56:42.131066
# LBW242’s final rmse value is = 0.560511
# LBW242 R-squared value is = -1.995242
# PD-0325901_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 16:56:42.493607
# [16:56:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:57:27.960038
# PD-0325901’s final rmse value is = 1.829619
# PD-0325901 R-squared value is = 0.338244
# PD-0332991_//n
# train_X shape: (337, 18988)
# 337 train samples
# 84 test samples
# StartTime : 2020-09-16 16:57:28.288503
# [16:57:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:58:05.834485
# PD-0332991’s final rmse value is = 0.646305
# PD-0332991 R-squared value is = 0.000433
# Paclitaxel_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 16:58:06.154631
# [16:58:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:58:49.133063
# Paclitaxel’s final rmse value is = 2.057275
# Paclitaxel R-squared value is = 0.029618
# PLX4720_//n
# train_X shape: (387, 18988)
# 387 train samples
# 96 test samples
# StartTime : 2020-09-16 16:58:49.473619
# [16:58:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 16:59:30.283400
# PLX4720’s final rmse value is = 0.836270
# PLX4720 R-squared value is = 0.127360
# RAF265_//n
# train_X shape: (358, 18988)
# 358 train samples
# 89 test samples
# StartTime : 2020-09-16 16:59:30.610524
# [16:59:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 17:00:12.447488
# RAF265’s final rmse value is = 1.086872
# RAF265 R-squared value is = 0.081571
# TAE684_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 17:00:12.843197
# [17:00:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 17:00:58.746670
# TAE684’s final rmse value is = 1.246573
# TAE684 R-squared value is = 0.073485
# TKI258_//n
# train_X shape: (393, 18988)
# 393 train samples
# 98 test samples
# StartTime : 2020-09-16 17:00:59.070772
# [17:00:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 17:01:42.496579
# TKI258’s final rmse value is = 0.635679
# TKI258 R-squared value is = 0.167304
# Erlotinib_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 17:01:42.830709
# [17:01:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 17:02:21.712750
# Erlotinib’s final rmse value is = 0.792897
# Erlotinib R-squared value is = -0.128880
# AZD6244_//n
# train_X shape: (392, 18988)
# 392 train samples
# 98 test samples
# StartTime : 2020-09-16 17:02:22.020898
# [17:02:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# EndTime : 2020-09-16 17:03:00.642692
# AZD6244’s final rmse value is = 1.242245
# AZD6244 R-squared value is = 0.065537

# %%
num
# Out:
# 25

# %%
print("This is lasso regression with expression dataset for each drugs")
a = pd.DataFrame(drug_list)
b = pd.DataFrame(rmselist)
c =pd.DataFrame(r2list)
result = pd.concat([a,b,c],axis=1)
result.columns = ['Drug','RMSE','R2value']
# Out:
# This is lasso regression with expression dataset for each drugs

# %%
result
# Out:
#             Drug      RMSE    R2value
# 0         AEW541  0.748134   0.095475
# 1      Nilotinib  1.086551  -0.106118
# 2         17-AAG  1.081337   0.100036
# 3     PHA-665752  0.281316  -2.979270
# 4      Lapatinib  0.598046  -0.293585
# 5       Nutlin-3  0.722482 -70.209260
# 6        AZD0530  0.945481   0.043889
# 7      PF2341066  0.783995   0.105012
# 8       L-685458  0.659312   0.054217
# 9        ZD-6474  0.700615  -0.159959
# 10  Panobinostat  0.710832   0.414771
# 11     Sorafenib  0.581474   0.000796
# 12    Irinotecan  1.109511   0.294686
# 13     Topotecan  1.137705   0.412895
# 14        LBW242  0.560511  -1.995242
# 15    PD-0325901  1.829619   0.338244
# 16    PD-0332991  0.646305   0.000433
# 17    Paclitaxel  2.057275   0.029618
# 18       PLX4720  0.836270   0.127360
# 19        RAF265  1.086872   0.081571
# 20        TAE684  1.246573   0.073485
# 21        TKI258  0.635679   0.167304
# 22     Erlotinib  0.792897  -0.128880
# 23       AZD6244  1.242245   0.065537

# %%
workdir = "D://DrugResponsivenessGuideline_log//Github//200914_reupload//Result//Scenario5_individual_approach" 
result.to_csv(workdir +'//200915_scenario5_XGB_24drugs_metrics.csv', index=False)
