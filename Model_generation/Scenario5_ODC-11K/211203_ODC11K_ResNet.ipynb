# %%
import os
import sys
import pandas as pd
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
import random
import matplotlib
from matplotlib import pyplot as plt
import statistics
from pandas import DataFrame
from datetime import datetime
import keras
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Reshape, Flatten, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D, GlobalAveragePooling1D
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import Adam, RMSprop
#from keras import backend as K
import keras.backend.tensorflow_backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from keras.backend.tensorflow_backend import set_session
from os.path import basename
#import seaborn as sns
from keras.models import load_model
from keras.utils.vis_utils import plot_model
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from scipy.stats import pearsonr

# from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
#from tensorflow.keras.optimizers import Adam




config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
# Out:
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())


# 출처: https://3months.tistory.com/206 [Deep Play]
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10376882174987124916
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 8267812044
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12249724627250052437
# physical_device_desc: "device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# ]

# %%
workdir = "D://EODC-11K//ODC-11K"

# %%
# < Important note > [ Please download input data from https://mega.nz/#F!CeYGDKyS!uqkmWJ4E2XSGJp_C2VO2gg]
# IC50evaluation//Dataset//Scenario5_EODC-9K

dataset = np.load(workdir + "//ODC11K_dataset.npz") # input file
ss0 = np.load(workdir + '//ODC11K_dataset_r0.npz') # split for training and test

# %%
x = dataset['x']
y = dataset['y']
# y_linear = dataset['y_lnIC50']
ss0_train = ss0['train']
ss0_test = ss0['test']

# %%
training_image_array, training_label_array = x[ss0_train], y[ss0_train]
test_image_array, test_label_array = x[ss0_test], y[ss0_test]

# # In[9]:
# ori = training_image_array
# bat = np.zeros((ori.shape[0],178))
# cat = np.hstack([ori,bat])
# training_image_array = cat

# # In[8]:
# training_image_array.shape

# # In[10]:
# ori2 = test_image_array
# bat2 = np.zeros((ori2.shape[0],178))
# cat2 = np.hstack([ori2,bat2])
# test_image_array = cat2

# %%
# In[15]:
ab =[]
for i in range(100,300):
    ab.append(len(training_image_array) % i)
    
print(min(ab), ab.index(min(ab)))
# Out:
# 1 9

# %%
x.shape
# Out:
# (11385, 19331)

# %%
training_image_array.shape
# Out:
# (10247, 19331)

# %%
# In[21]:

num_classes = 1
learning_rate = 0.0002
training_epochs = 150
batch_size = 100
# img_rows, img_cols = 154, 154

# %%
train_X, train_y, test_X, test_y = training_image_array, training_label_array, test_image_array, test_label_array

# if K.image_data_format() == 'channels_first':
#     train_X = train_X.reshape(train_X.shape[0], 1, img_rows, img_cols)
#     test_X = test_X.reshape(x_test.shape[0], 1, img_rows, img_cols)
#     input_shape = (1, img_rows, img_cols)
# else:
#     train_X = train_X.reshape(train_X.shape[0], img_rows, img_cols, 1)
#     test_X = test_X.reshape(test_X.shape[0], img_rows, img_cols, 1)
#     input_shape = (img_rows, img_cols, 1)

# %%
train_X = train_X.reshape(train_X.shape[0], train_X.shape[1],1)
test_X = test_X.reshape(test_X.shape[0], test_X.shape[1],1)
#input_shape = (img_rows, img_cols, 1)

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (10247, 19331, 1) (10247,) (1138, 19331, 1) (1138,)

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
# train_X /= 255
# test_X /= 255
print('train_X shape:', train_X.shape)
print(train_X.shape[0], 'train samples')
print(test_X.shape[0], 'test samples')
# Out:
# train_X shape: (10247, 19331, 1)
# 10247 train samples
# 1138 test samples

# %%
training_image_array.shape
# Out:
# (10247, 19331)

# %%
# In[10]:
with K.tf.device('/GPU:0'):
    inputs = Input(shape=(train_X.shape[1],1),name='inputs')

    x = Conv1D(16, kernel_size=3, strides=2, padding="same")(inputs)
    x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
#     y = x
    x = Activation('tanh')(x)

    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)

    
    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)
    
    
    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    
    x = Conv1D(16, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)
    
    x = Conv1D(32, kernel_size=3, strides=2, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
#     x = BatchNormalization()(x)
        
    x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)
    
        
    x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)

    x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(32, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)

    x = Conv1D(64, kernel_size=3, strides=2, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
#     x = BatchNormalization()(x)
        
    x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)
    
        
    x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)

    x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    y = x
    x = Activation('relu')(x)

    x = Conv1D(64, kernel_size=3, strides=1, padding="same")(x)
#     x = MaxPooling1D(pool_size=5)(x)
    x = BatchNormalization()(x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)

#     x = AveragePooling1D(pool_size=8)(x)
    x = Flatten()(x)
    x = Dense(units=2048, name='dense1'  ) (x)
    x = BatchNormalization()(x)
    x = Dropout(0.1, name='dropout1') (x)
    x = Activation('relu')(x)

#    x = Reshape((300,1))(x)

#    x = Conv1D(30, kernel_size=150, strides=1, activation = 'relu')(x)
#    x = MaxPooling1D(pool_size=2)(x)
#    x = BatchNormalization()(x)

    x = Dense(units=1024, name='dense5'  ) (x)
    x = BatchNormalization()(x)
    y = x
    x = Dropout(0.1, name='dropout5') (x)
    x = Activation('relu')(x)

    x = Dense(units=512, name='dense6'  ) (x)
    x = BatchNormalization()(x)
    x = Dropout(0.1, name='dropout6') (x)
    x = Activation('relu')(x)

    x = Dense(units=1024, name='dense7'  ) (x)
    x = BatchNormalization()(x)
    x = Dropout(0.1, name='dropout7') (x)
    x = keras.layers.add([x,y])
    x = Activation('relu')(x)
    
    x = Dense(units=512, name='dense8'  ) (x)
    x = BatchNormalization()(x)
    x = Dropout(0.1, name='dropout8') (x)
    x = Activation('relu')(x)
    
    x = Dense(units=256, name='dense9'  ) (x)
    x = BatchNormalization()(x)
    x = Dropout(0.1, name='dropout9') (x)
    x = Activation('relu')(x)

    x = Dense(units=128, name='dense10'  ) (x)
    x = BatchNormalization()(x)
    y = x
    x = Dropout(0.1, name='dropout10') (x)
    x = Activation('relu')(x)


    predictions = Dense(1, activation='linear', name='predictions', kernel_initializer='he_normal')(x)
#     predictions = Dense(1, activation='linear', name='predictions')(x)

    

    model = Model(inputs=inputs, outputs=predictions, name='Test_v2_DNN20190327')
    model.compile(loss=keras.losses.mean_squared_error,
                  optimizer=keras.optimizers.Adam(learning_rate),
                  metrics=['mse','mae'])


    model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "Test_v2_DNN20190327"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             (None, 19331, 1)     0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 9666, 16)     64          inputs[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 1933, 16)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1933, 16)     64          max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1933, 16)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 1933, 16)     784         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 1933, 16)     64          conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1933, 16)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1933, 16)     784         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 1933, 16)     64          conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1933, 16)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 1933, 16)     784         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 1933, 16)     64          conv1d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1933, 16)     0           batch_normalization_4[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1933, 16)     0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 1933, 16)     784         activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 1933, 16)     64          conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1933, 16)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 1933, 16)     784         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 1933, 16)     64          conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1933, 16)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 1933, 16)     784         activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 1933, 16)     64          conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1933, 16)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 1933, 16)     784         activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 1933, 16)     64          conv1d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1933, 16)     0           batch_normalization_8[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1933, 16)     0           add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 967, 32)      1568        activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 967, 32)      128         conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 967, 32)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 967, 32)      3104        activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 967, 32)      3104        conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 967, 32)      128         conv1d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 967, 32)      0           batch_normalization_10[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 967, 32)      0           add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 967, 32)      3104        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 967, 32)      128         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 967, 32)      0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 967, 32)      3104        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 967, 32)      128         conv1d_13[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 967, 32)      0           batch_normalization_12[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 967, 32)      0           add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 967, 32)      3104        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 967, 32)      128         conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 967, 32)      0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 967, 32)      3104        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 967, 32)      128         conv1d_15[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 967, 32)      0           batch_normalization_14[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 967, 32)      0           add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 484, 64)      6208        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 484, 64)      256         conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 484, 64)      0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 484, 64)      12352       activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 484, 64)      12352       conv1d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 484, 64)      256         conv1d_18[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 484, 64)      0           batch_normalization_16[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 484, 64)      0           add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 484, 64)      12352       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 484, 64)      256         conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 484, 64)      0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 484, 64)      12352       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 484, 64)      256         conv1d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 484, 64)      0           batch_normalization_18[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 484, 64)      0           add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 484, 64)      12352       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 484, 64)      256         conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 484, 64)      0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 484, 64)      12352       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 484, 64)      256         conv1d_22[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 484, 64)      0           batch_normalization_20[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 484, 64)      0           add_8[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 30976)        0           activation_20[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 2048)         63440896    flatten_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 2048)         8192        dense1[0][0]
# __________________________________________________________________________________________________
# dropout1 (Dropout)              (None, 2048)         0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2048)         0           dropout1[0][0]
# __________________________________________________________________________________________________
# dense5 (Dense)                  (None, 1024)         2098176     activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 1024)         4096        dense5[0][0]
# __________________________________________________________________________________________________
# dropout5 (Dropout)              (None, 1024)         0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1024)         0           dropout5[0][0]
# __________________________________________________________________________________________________
# dense6 (Dense)                  (None, 512)          524800      activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 512)          2048        dense6[0][0]
# __________________________________________________________________________________________________
# dropout6 (Dropout)              (None, 512)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 512)          0           dropout6[0][0]
# __________________________________________________________________________________________________
# dense7 (Dense)                  (None, 1024)         525312      activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 1024)         4096        dense7[0][0]
# __________________________________________________________________________________________________
# dropout7 (Dropout)              (None, 1024)         0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 1024)         0           dropout7[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 1024)         0           add_9[0][0]
# __________________________________________________________________________________________________
# dense8 (Dense)                  (None, 512)          524800      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 512)          2048        dense8[0][0]
# __________________________________________________________________________________________________
# dropout8 (Dropout)              (None, 512)          0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 512)          0           dropout8[0][0]
# __________________________________________________________________________________________________
# dense9 (Dense)                  (None, 256)          131328      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256)          1024        dense9[0][0]
# __________________________________________________________________________________________________
# dropout9 (Dropout)              (None, 256)          0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 256)          0           dropout9[0][0]
# __________________________________________________________________________________________________
# dense10 (Dense)                 (None, 128)          32896       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128)          512         dense10[0][0]
# __________________________________________________________________________________________________
# dropout10 (Dropout)             (None, 128)          0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 128)          0           dropout10[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1)            129         activation_27[0][0]
# ==================================================================================================
# Total params: 67,409,233
# Trainable params: 67,396,817
# Non-trainable params: 12,416
# __________________________________________________________________________________________________

# %%
StartTime8 = datetime.now()
print("StartTime :", StartTime8)
with K.tf.device('/GPU:0'):
    model_train = model.fit(train_X, training_label_array, batch_size=batch_size,epochs=training_epochs,verbose=1,
                        validation_data=(test_X, test_label_array))

EndTime8 = datetime.now()
print("EndTime :", EndTime8)
# Out:
# StartTime : 2021-12-04 21:14:56.369259
# WARNING:tensorflow:From C:\Users\BGM18\.conda\envs\ronny_keras\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 10247 samples, validate on 1138 samples
# Epoch 1/150
# 10247/10247 [==============================] - 16s 2ms/step - loss: 1.9715 - mse: 1.9715 - mae: 1.0360 - val_loss: 3.6161 - val_mse: 3.6161 - val_mae: 1.59450  - ETA: 6s - l
# Epoch 2/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 1.3049 - mse: 1.3049 - mae: 0.7797 - val_loss: 3.7506 - val_mse: 3.7506 - val_mae: 1.60839 - mse: 1.2559 - mae:  - ETA: 4s - loss: 1.2527 - mse: 1.2527 - m - ETA: 3s
# Epoch 3/150
# 10247/10247 [==============================] - 10s 946us/step - loss: 1.0271 - mse: 1.0271 - mae: 0.6915 - val_loss: 3.6624 - val_mse: 3.6624 - val_mae: 1.2268136 - mse: 1.0136 - mae: 0.6 - ETA: 1s - loss: 1.0228 - mse: 1.0228 -  - ETA: 0s - loss: 1.0282 - mse: 1.0282 - mae: 0.6
# Epoch 4/150
# 10247/10247 [==============================] - 10s 946us/step - loss: 0.7951 - mse: 0.7951 - mae: 0.6126 - val_loss: 2.8093 - val_mse: 2.8093 - val_mae: 0.9858- mae - ETA: 0s - loss: 0.7922 - mse: 0.7922 - mae:
# Epoch 5/150
# 10247/10247 [==============================] - 10s 948us/step - loss: 0.7037 - mse: 0.7037 - mae: 0.5747 - val_loss: 1.3368 - val_mse: 1.3368 - val_mae: 0.6737 - ETA: 4s - loss: 0.6970 - mse: 0.6970 -  - ETA: 3s - loss: 0.6950 - mse: 0 - ETA: 1s - loss: 0.7097 - mse: 0.70
# Epoch 6/150
# 10247/10247 [==============================] - 10s 947us/step - loss: 0.5920 - mse: 0.5920 - mae: 0.5323 - val_loss: 0.9980 - val_mse: 0.9980 - val_mae: 0.5920oss: 0.650 - ETA: 5s - loss: 0.5891 - mse: 0.5 - ETA: 4s - loss: 0.5830 - mse: 0.5 - ETA: 2s - loss: 0.5803 - mse: 0.5803 - ETA: 1s - loss: 0.5793 - mse: 0.5793 - mae: - ETA: 0s - loss: 0.5898 - mse: 0.5898 - mae
# Epoch 7/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.5698 - mse: 0.5698 - mae: 0.5274 - val_loss: 0.9493 - val_mse: 0.9493 - val_mae: 0.59432 - mse: - ETA: 5s - loss: 0.5608 - mse: 0.5608  - ETA: 4s - l - ETA: 0s - loss: 0.5610 - mse: 0.5610 - mae: 0.5 - ETA: 0s - loss: 0.5627 - mse: 0.5627 - mae: 0.
# Epoch 8/150
# 10247/10247 [==============================] - 10s 945us/step - loss: 0.5026 - mse: 0.5026 - mae: 0.4992 - val_loss: 1.0667 - val_mse: 1.0667 - val_mae: 0.5929mse: 0.4969 - mae: 0.4
# Epoch 9/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.4636 - mse: 0.4636 - mae: 0.4756 - val_loss: 0.9513 - val_mse: 0.9513 - val_mae: 0.562039 - mse: 0.4639 - mae: 0 - ETA: 5s  - ETA: 1s - loss: 0.4562 - mse: 0.4562 - mae: 0.4 - ETA: 1s - loss: 0.4553 - mse: 0.4553 - mae: 0.470 - ETA: 1s - loss: 0.4579 - mse: 0.4579 - mae: 0.471 - ETA: 1s - loss: 0.4573 - mse: 0.4573 - mae:  - ETA: 0s - loss: 0.4578 - mse: 0.4578 - ma
# Epoch 10/150
# 10247/10247 [==============================] - 10s 960us/step - loss: 0.4230 - mse: 0.4230 - mae: 0.4591 - val_loss: 0.9431 - val_mse: 0.9431 - val_mae: 0.5535
# Epoch 11/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.3589 - mse: 0.3589 - mae: 0.4279 - val_loss: 0.9598 - val_mse: 0.9598 - val_mae: 0.5789- ETA: 2s - loss: 0.3536 - mse: 0.3536 - mae: 0.425 - ETA: 2s - loss: 0.3520 -  - ETA: 0s - loss: 0.3609 - mse: 0.3609 - mae:
# Epoch 12/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.3499 - mse: 0.3499 - mae: 0.4190 - val_loss: 0.9318 - val_mse: 0.9318 - val_mae: 0.5413 - mse: 0.3467 - mae:
# Epoch 13/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.3302 - mse: 0.3302 - mae: 0.4060 - val_loss: 0.9359 - val_mse: 0.9359 - val_mae: 0.5452 - mse: 0.3236 -  - ETA: 5s - loss: 0.3298 - mse: 0. - ETA: 3s - loss: 0.3289 - mse: 0.3289 - mae: 0. - ETA: 3s - loss: 0.3216 - mse: 0.3216 - m - ETA: 2s - loss: 0.3238 - mse: 0.3238 - mae - ETA: 1s - loss: 0.3294 - mse: 0.32 - ETA: 0s - loss: 0.3305 - mse: 0.3305 - mae: 0.406
# Epoch 14/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.3146 - mse: 0.3146 - mae: 0.4011 - val_loss: 0.8891 - val_mse: 0.8891 - val_mae: 0.5210998 - mse: 0. - ETA: 6s - loss: 0.2818 - mse: 0.2818  - ETA: 5s - loss: 0.2843 - mse: 0.2843 - - ETA: 4s - loss: 0.2971 - mse: 0.2971 - ETA: 2s - loss: 0.3027 - mse: 0.3027 - mae: 0.39 - ETA: 2s - loss: 0.3050 - mse: 0.3050  - ETA: 1s - loss: 0.3135 - mse: 0.3135  - ETA: 0s - loss: 0.3136 - mse: 0.3136 - mae: 0.40
# Epoch 15/150
# 10247/10247 [==============================] - 10s 949us/step - loss: 0.3055 - mse: 0.3055 - mae: 0.3951 - val_loss: 1.0139 - val_mse: 1.0139 - val_mae: 0.5642e: 0.2810 - mae: 0 - ETA: 5s - loss: 0 - ETA: 2s - loss: 0.3033 - mse: 0.3033 - - ETA: 1s - loss: 0.3025 - mse: 0.3025 - m - ETA: 0s - loss: 0.3023 - mse: 0.3023 - mae: 0.3
# Epoch 16/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.2702 - mse: 0.2702 - mae: 0.3738 - val_loss: 0.9721 - val_mse: 0.9721 - val_mae: 0.5557
# Epoch 17/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.2576 - mse: 0.2576 - mae: 0.3624 - val_loss: 0.9673 - val_mse: 0.9673 - val_mae: 0.5417 3s - loss: 0.2588 - mse: 0.2588 - ma - ETA: 2s - loss: 0.
# Epoch 18/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.2480 - mse: 0.2480 - mae: 0.3576 - val_loss: 0.8943 - val_mse: 0.8943 - val_mae: 0.5244 mse: 0. - ETA: 4s - loss: 0.2453 - ETA: 2s - loss: 0.2481 -
# Epoch 19/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.2527 - mse: 0.2527 - mae: 0.3552 - val_loss: 0.9702 - val_mse: 0.9702 - val_mae: 0.537302 - mse: 0.2402 -  - ETA: 3s - loss: 0.2600 - mse: 0.2600 - mae: 0.3 - ETA: 3s - loss: 0.25 - ETA: 0s - loss: 0.2528 - mse: 0.2528 - mae: 0.
# Epoch 20/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.2177 - mse: 0.2177 - mae: 0.3340 - val_loss: 0.9230 - val_mse: 0.9230 - val_mae: 0.5193s: 0.2060 - mse:  - ETA: 4s - loss: 0.2156 - mse: 0.2156 - mae: 0. - ETA: 3s - loss: 0.2149 - mse: 0.2149 - ETA: 2s - loss: 0.2148 - mse:  - ETA: 0s - loss: 0.2199 - mse: 0.2199 - mae:
# Epoch 21/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.2341 - mse: 0.2341 - mae: 0.3482 - val_loss: 0.9049 - val_mse: 0.9049 - val_mae: 0.5139575 - ms - ETA: 5s - loss: 0.2461 - mse: 0.2461 - mae: 0.3 - ETA: 5s - loss: 0.2437 - mse: 0.2437 - ma - ETA: 4s - loss: 0.2452 - mse: 0.2452 - mae: 0. - ETA: 4s - ETA: 0s - loss: 0.2337 - mse: 0.2337 - mae: 0.3
# Epoch 22/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.2261 - mse: 0.2261 - mae: 0.3390 - val_loss: 0.9238 - val_mse: 0.9238 - val_mae: 0.531503 - mse: 0.2303 - mae - ETA: 1s - loss: 0.2280 - mse: 0
# Epoch 23/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.2153 - mse: 0.2153 - mae: 0.3330 - val_loss: 0.9313 - val_mse: 0.9313 - val_mae: 0.5147s: 0.2204 - mse: 0.22 - ETA: 1s - loss: 0.2201 - mse: 0.2201  - ETA: 0s - loss: 0.2164 - mse: 0.2164 - mae: 0
# Epoch 24/150
# 10247/10247 [==============================] - 10s 964us/step - loss: 0.2042 - mse: 0.2042 - mae: 0.3278 - val_loss: 0.9024 - val_mse: 0.9024 - val_mae: 0.5211 loss: 0.2016 -
# Epoch 25/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.1902 - mse: 0.1902 - mae: 0.3140 - val_loss: 0.9396 - val_mse: 0.9396 - val_mae: 0.5282
# Epoch 26/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.1801 - mse: 0.1801 - mae: 0.3050 - val_loss: 0.8906 - val_mse: 0.8906 - val_mae: 0.5204 0.1848 - mse: 0.1848 - mae - ETA: 7s - loss: 0.1756 - mse: 0.1756 - mae: 0.298 - ETA: 7s - loss: 0.1749 - mse: 0.1749 - mae: - ETA: 6s - loss: 0.1723 - mse: 0.1723 - ma - ETA:  - ETA: 1s - loss: 0.1750 - mse: 0
# Epoch 27/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.2096 - mse: 0.2096 - mae: 0.3241 - val_loss: 0.8802 - val_mse: 0.8802 - val_mae: 0.5128loss: 0.1795 - mse: 0.1795 - mae: 0. - - ETA: 2s - loss: 0.2019 - mse:  - ETA: 0s - loss: 0.2060 - mse: 0.2060 - mae:
# Epoch 28/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.2139 - mse: 0.2139 - mae: 0.3214 - val_loss: 0.8877 - val_mse: 0.8877 - val_mae: 0.5030loss: 0.2039 - mse: 0. - ETA: 5s - loss: 0.2247 - mse: 0.2247 - mae: - ETA: 5s - loss: 0.2248 - mse: 0.2248 -  - ETA: 4s - loss: 0.2265  - ETA: 1s - loss: 0.2194 - mse: 0.2194 - mae: 0 - ETA: 1s - loss: 0.2190 - mse: 0.2190 - mae: 0. - ETA: 0s - loss: 0.2169 - mse: 0.2169 - mae
# Epoch 29/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.1863 - mse: 0.1863 - mae: 0.3054 - val_loss: 0.8916 - val_mse: 0.8916 - val_mae: 0.4971.1934 - mse: 0.1934 - mae: 0 - ETA: 2s - loss: 0.1928 - mse: 0.1928 - mae: 0 - ETA: 1s - loss: 0.1903 - mse: 0.1903 - mae - ETA: 1s - loss: 0.1895 - mse: 0.1895
# Epoch 30/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.1871 - mse: 0.1871 - mae: 0.3100 - val_loss: 0.9352 - val_mse: 0.9352 - val_mae: 0.5318 loss: 0.1802 - mse: 0.1802 - mae: 0.3 - ETA: 4s - loss: 0.1787 - mse: 0.1787 - ma - ETA: 3s - loss: 0.1803 - mse: 0.1803 - mae: 0.3 - ETA: 3s - loss: 0.1804 - mse: 0.1804 - mae - ETA: 2s - loss: 0.1791 - mse: 0.1791 - ma - ETA: 1s - loss: 0.1856 - mse: 0.1856 - m - ETA: 0s - loss: 0.1871 - mse: 0.1871 - mae:
# Epoch 31/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.1846 - mse: 0.1846 - mae: 0.3080 - val_loss: 1.0568 - val_mse: 1.0568 - val_mae: 0.5374oss: 0.1960 - mse:  - ETA: 5s - loss: - ETA: 2s - loss: 0.1863  - ETA: 0s - loss: 0.1831 - mse: 0.1831 - mae: 0.306
# Epoch 32/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.1721 - mse: 0.1721 - mae: 0.2942 - val_loss: 0.9264 - val_mse: 0.9264 - val_mae: 0.51287 - mse: 0 - ETA: 0s - loss: 0.1726 - mse: 0.1726 - mae: 0 - ETA: 0s - loss: 0.1729 - mse: 0.1729 - mae: 0.
# Epoch 33/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.1640 - mse: 0.1640 - mae: 0.2875 - val_loss: 0.9524 - val_mse: 0.9524 - val_mae: 0.5145 0.1587 - mae: 0.283 - ETA: 4s - loss: 0.1613 - mse:  - ETA: 2s - loss: 0.1606 - mse: 0.1606 - mae: 0 - ETA: 2s - loss: 0.1614 -
# Epoch 34/150
# 10247/10247 [==============================] - 10s 949us/step - loss: 0.1825 - mse: 0.1825 - mae: 0.3055 - val_loss: 0.8636 - val_mse: 0.8636 - val_mae: 0.5010 loss: 0.1824 - mse: 0. - ETA: 5s - loss: 0.1910 - mse: 0.19 - ETA:
# Epoch 35/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.1751 - mse: 0.1751 - mae: 0.3003 - val_loss: 0.9310 - val_mse: 0.9310 - val_mae: 0.5164mse: 0.1888 - - ETA: 3s - loss: 0.1891 - mse: 0.1891 - - ETA: 2s - loss: 0.1816 - m
# Epoch 36/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.1788 - mse: 0.1788 - mae: 0.2920 - val_loss: 0.8499 - val_mse: 0.8499 - val_mae: 0.48971805 - ma - ETA: 2s - loss: 0.1794 - mse: 0.1794 - mae:  - ETA: 1s - loss: 0.1790 - mse: 0.1790 - mae: - ETA: 0s - loss: 0.1771 - mse: 0.1771 -
# Epoch 37/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.1604 - mse: 0.1604 - mae: 0.2779 - val_loss: 0.9254 - val_mse: 0.9254 - val_mae: 0.4985: 0.1605
# Epoch 38/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.1485 - mse: 0.1485 - mae: 0.2744 - val_loss: 0.9448 - val_mse: 0.9448 - val_mae: 0.50780.1500 - mse: 0.15
# Epoch 39/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.1419 - mse: 0.1419 - mae: 0.2679 - val_loss: 0.9587 - val_mse: 0.9587 - val_mae: 0.5065
# Epoch 40/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.1429 - mse: 0.1429 - mae: 0.2692 - val_loss: 0.9073 - val_mse: 0.9073 - val_mae: 0.4969- mse
# Epoch 41/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.1332 - mse: 0.1332 - mae: 0.2609 - val_loss: 0.9421 - val_mse: 0.9421 - val_mae: 0.5007: 2s - loss: 0.1371 - mse: 0.1371  - ETA: 1s - loss: 0.1348 - mse: 0.1348  - ETA: 0s - loss: 0.1344 - mse: 0.1344 - mae: 0.
# Epoch 42/150
# 10247/10247 [==============================] - 10s 964us/step - loss: 0.1296 - mse: 0.1296 - mae: 0.2582 - val_loss: 0.9203 - val_mse: 0.9203 - val_mae: 0.50201314 - mse
# Epoch 43/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.1223 - mse: 0.1223 - mae: 0.2527 - val_loss: 0.8790 - val_mse: 0.8790 - val_mae: 0.4963
# Epoch 44/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.1321 - mse: 0.1321 - mae: 0.2593 - val_loss: 0.9161 - val_mse: 0.9161 - val_mae: 0.4994- mae: 0.25
# Epoch 45/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.1298 - mse: 0.1298 - mae: 0.2577 - val_loss: 0.9264 - val_mse: 0.9264 - val_mae: 0.4959se: 0 - ETA: 2s - loss: 0.1314 - mse: 0.1314 - m - ETA: 1s - loss: 0.1328 - mse: 0.1328 - mae: 0.26 - ETA: 1s - loss: 0.1324 - mse: 0.1324 - ma - ETA: 0s - loss: 0.1309 - mse: 0.1309 - mae:
# Epoch 46/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.2005 - mse: 0.2005 - mae: 0.2853 - val_loss: 0.9832 - val_mse: 0.9832 - val_mae: 0.5293: 0.1785 - ETA: 0s - loss: 0.2024 - mse: 0.2024 - mae: 0.
# Epoch 47/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.2928 - mse: 0.2928 - mae: 0.3382 - val_loss: 1.0890 - val_mse: 1.0890 - val_mae: 0.5708- loss: 0.2583 - mse:  - ETA: 6s - loss: 0.2639 - mse:  - ETA: 4s - loss: 0.2657 - mse: 0.26 - ETA: 2s - loss: 0.
# Epoch 48/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.3736 - mse: 0.3736 - mae: 0.3837 - val_loss: 1.0553 - val_mse: 1.0553 - val_mae: 0.5767oss: 0.2889 - mse: 0.2889 - mae - ETA: 7s - loss: 0.3208 - mse: 0.3208 - mae: 0.364 - ETA: 7s - loss: 0.3145  - ETA: 0s - loss: 0.3761 - mse: 0.3761 - mae:
# Epoch 49/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.3163 - mse: 0.3163 - mae: 0.3586 - val_loss: 1.0592 - val_mse: 1.0592 - val_mae: 0.5770se: 0.3786 - mae: 0.3 - ETA: 6s - loss: 0.3765 - mse: 0.3765 - ETA: 0s - loss: 0.3145 - mse: 0.3145 - mae: 0.3
# Epoch 50/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.2863 - mse: 0.2863 - mae: 0.3390 - val_loss: 0.9411 - val_mse: 0.9411 - val_mae: 0.5386oss: 0.3019 - mse: 0.3019 - mae: - ETA: 6s - loss: 0.2844 - mse: 0
# Epoch 51/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.2075 - mse: 0.2075 - mae: 0.3069 - val_loss: 1.0559 - val_mse: 1.0559 - val_mae: 0.5409
# Epoch 52/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.1593 - mse: 0.1593 - mae: 0.2718 - val_loss: 0.9371 - val_mse: 0.9371 - val_mae: 0.5016 0.1707 - mse: 0.1 - ETA: 0s - loss: 0.1613 - mse: 0.1613 -
# Epoch 53/150
# 10247/10247 [==============================] - 10s 957us/step - loss: 0.1483 - mse: 0.1483 - mae: 0.2610 - val_loss: 0.8701 - val_mse: 0.8701 - val_mae: 0.489551 - ETA: 0s - loss: 0.1476 - mse: 0.1476 - mae: 0.
# Epoch 54/150
# 10247/10247 [==============================] - 10s 960us/step - loss: 0.1228 - mse: 0.1228 - mae: 0.2473 - val_loss: 0.9067 - val_mse: 0.9067 - val_mae: 0.4821
# Epoch 55/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.1055 - mse: 0.1055 - mae: 0.2351 - val_loss: 0.8608 - val_mse: 0.8608 - val_mae: 0.4866- ETA: 5s - loss: 0.1076 - mse - ETA: 3s - loss: 0
# Epoch 56/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.1025 - mse: 0.1025 - mae: 0.2303 - val_loss: 0.8674 - val_mse: 0.8674 - val_mae: 0.4802: 2s - loss: 0.1019 - ms - ETA: 0s - loss: 0.1029 - mse: 0.1029 - mae: 0
# Epoch 57/150
# 10247/10247 [==============================] - 10s 964us/step - loss: 0.0987 - mse: 0.0987 - mae: 0.2253 - val_loss: 0.8586 - val_mse: 0.8586 - val_mae: 0.4689- loss: 0.1 - ETA: 2s - loss: 0.0998 - mse: 0.0998 - m - ETA: 1s - loss: 0.0981 - mse: 0.0981 - mae - ETA: 0s - loss: 0.0979 - mse: 0.0979 - mae: 0.2 - ETA: 0s - loss: 0.0984 - mse: 0.0984 - mae: 0
# Epoch 58/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.0971 - mse: 0.0971 - mae: 0.2233 - val_loss: 0.8492 - val_mse: 0.8492 - val_mae: 0.4709 0.0949 - m - ETA: 5s - loss: 0.0934 - mse: 0.0934  - ETA: 4s - loss: 0.1019 - mse: 0.1019 - mae: 0.22 - ETA: 3s - lo - ETA: 0s - loss: 0.0972 - mse: 0.0972 - mae: 0.2
# Epoch 59/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0905 - mse: 0.0905 - mae: 0.2161 - val_loss: 0.8776 - val_mse: 0.8776 - val_mae: 0.4705loss: 0.0936 - mse: 0.0936 - mae: 0.218 - ETA: 5s - loss: 0.0931 - mse:  - ETA: 3s - loss: 0.0927 - mse:  - ETA: 1s - loss: 0.0912 - mse: 0.0912 - mae: 0.216 - ETA: 1s - loss: 0.0914 - mse: 0.0914
# Epoch 60/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.0977 - mse: 0.0977 - mae: 0.2242 - val_loss: 0.9001 - val_mse: 0.9001 - val_mae: 0.4747- loss: 0.1159 - mse: 0.1159 - m - ETA: 8s - loss: 0.0969 - mse: 0.0969 - mae: 0.225 - ETA: 7s - loss: 0.0977 - mse: 0.0977 - mae: 0 - ETA: 7s - loss: 0.0938 - mse: 0.0938 - mae: 0. - ETA: 7s - loss: 0.0988 - - ETA: 4s - ETA: 0s - loss: 0.0983 - mse: 0.0983 - mae: 0.224 - ETA: 0s - loss: 0.0980 - mse: 0.0980 - mae
# Epoch 61/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0948 - mse: 0.0948 - mae: 0.2209 - val_loss: 0.8751 - val_mse: 0.8751 - val_mae: 0.4804loss: 0.0852 -  - ETA: 4s - loss: 0.0899 - mse: 0.0899 - m - ETA: 3s - loss: 0.0935 - mse: 0.0935 - mae: 0 - ETA: 3s - loss: 0.0926 - mse: - ETA: 1s - loss: 0.0956 - mse: 0.0956 - mae: 0.2 - ETA: 1s - loss: 0.0950 - mse: 0.0950 -
# Epoch 62/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.0903 - mse: 0.0903 - mae: 0.2193 - val_loss: 0.9113 - val_mse: 0.9113 - val_mae: 0.47430.0902 - mae: 0.21
# Epoch 63/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0963 - mse: 0.0963 - mae: 0.2178 - val_loss: 0.8703 - val_mse: 0.8703 - val_mae: 0.48540.0923 - m - ETA: 5s - loss: 0.1022 - mse: - ETA: 3s - loss: 0.1005 - mse: - ETA: 1s - loss: 0.0976 - mse: 0.0976 - mae: 0.220 - ETA: 1s - loss: 0.0983 - mse: 0.0983  - ETA: 0s - loss: 0.0954 - mse: 0.0954 - mae: 0. - ETA: 0s - loss: 0.0959 - mse: 0.0959 - mae: 0.21
# Epoch 64/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.0965 - mse: 0.0965 - mae: 0.2207 - val_loss: 0.8739 - val_mse: 0.8739 - val_mae: 0.47700971 - mse: 0.0971 - mae: 0.22 - ETA: 0s - loss: 0.0969 - mse: 0.0969 - mae: 0.220 - ETA: 0s - loss: 0.0965 - mse: 0.0965 - mae: 0.220 - ETA: 0s - loss: 0.0962 - mse: 0.0962 - mae
# Epoch 65/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.0850 - mse: 0.0850 - mae: 0.2120 - val_loss: 0.8703 - val_mse: 0.8703 - val_mae: 0.4740A: 1s - loss: 0.0841 - mse: 0.0841 - mae: 0.2 - ETA: 1s - loss: 0.0846 - mse: 0.0846 - - ETA: 0s - loss: 0.0850 - mse: 0.0850 - mae:
# Epoch 66/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.0843 - mse: 0.0843 - mae: 0.2090 - val_loss: 0.8693 - val_mse: 0.8693 - val_mae: 0.4811se: 0.0 - ETA: 4s - loss: 0.0750 - mse: 0.0750 - mae: 0.20 - ETA: 3s - loss: 0.0759 - mse: 0. - ETA: 2s - loss: 0.0804 - mse: 0 - ETA: 0s - loss: 0.0825 - mse: 0.0825 - mae:
# Epoch 67/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.0873 - mse: 0.0873 - mae: 0.2119 - val_loss: 0.8727 - val_mse: 0.8727 - val_mae: 0.47128
# Epoch 68/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0829 - mse: 0.0829 - mae: 0.2079 - val_loss: 0.8668 - val_mse: 0.8668 - val_mae: 0.4719 loss: 0.0803 - mse: 0.0803 - mae: 0.2 - ETA: 7s - loss: 0.0783 - mse: 0.0783 - mae: - ETA: 7s - loss: 0.0766 - mse: 0.0766 -  - ETA: 6s - loss: 0.0796 - mse: 0.0796 -  - ETA: 0s - loss: 0.0818 - mse: 0.0818 - mae: 0.20
# Epoch 69/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.0874 - mse: 0.0874 - mae: 0.2130 - val_loss: 0.8745 - val_mse: 0.8745 - val_mae: 0.47740.0886 - mse: 0. - ETA: 1s - loss: 0.0877 - mse:
# Epoch 70/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.0803 - mse: 0.0803 - mae: 0.2049 - val_loss: 0.8850 - val_mse: 0.8850 - val_mae: 0.4758
# Epoch 71/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0800 - mse: 0.0800 - mae: 0.2033 - val_loss: 0.8562 - val_mse: 0.8562 - val_mae: 0.4728 ETA: 4s - loss: 0.0809 - mse: 0.0809 - mae:  - ETA: 3s - loss: 0.0801 - mse: 0.0801 - mae: - ETA: 2s - loss: 0.0789 - mse: 0 - ETA: 1s - loss: 0.0793 - mse: 0.0793
# Epoch 72/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0809 - mse: 0.0809 - mae: 0.2009 - val_loss: 0.9032 - val_mse: 0.9032 - val_mae: 0.4771s: 0.0823 - mse: 0.08 - ETA: 6s - loss: 0.0780 - mse: 0.078 - ETA: 5s - loss: 0.0768 - mse: 0.0768 - mae: 0.19 - ETA: 4s  - ETA: 1s - loss: 0.0804 - mse: 0.0804 -
# Epoch 73/150
# 10247/10247 [==============================] - 10s 960us/step - loss: 0.0884 - mse: 0.0884 - mae: 0.2071 - val_loss: 0.8621 - val_mse: 0.8621 - val_mae: 0.47494 - mse: 0.1064 -  - ETA: 6s - loss: 0.1012 - mse: 0.1012 - m - ETA: 5s - loss: 0.0950 - mse: 0.0950 - mae: 0. - ETA: 4s - loss: 0.0937 - mse: 0.0937 - mae: 0 - ETA: 4s - loss: 0.0912 - - ETA: 2s - loss: 0.0884 - mse: 0.0884 - mae: - ETA: 1s - loss: 0.0881 - mse: 0.0881  - ETA: 0s - loss: 0.0874 - mse: 0.0874 - mae: 0.2
# Epoch 74/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0958 - mse: 0.0958 - mae: 0.2135 - val_loss: 0.8499 - val_mse: 0.8499 - val_mae: 0.47480.0942 - mse: 0.0942 - mae: 0. - ETA: 5s - loss: 0.0937 - ms - ETA: 3s - loss: 0.0962 - mse: 0.0962 - - ETA: 1s - loss: 0.0942 - mse
# Epoch 75/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.1273 - mse: 0.1273 - mae: 0.2315 - val_loss: 1.0688 - val_mse: 1.0688 - val_mae: 0.5284s: 0.1236 - mse: 0.1236 - mae:
# Epoch 76/150
# 10247/10247 [==============================] - 10s 960us/step - loss: 0.2489 - mse: 0.2489 - mae: 0.2878 - val_loss: 1.2816 - val_mse: 1.2816 - val_mae: 0.6794- loss: 0.1810 - mse: 0.1810  - ETA: 6s - loss: 0.1809 - mse: 0.1809 - mae - ETA: 5s - loss: 0.1824 - mse:  - ETA: 3s - loss: 0.2149 - mse: 0.2149 - mae: 0. - ETA: 3s - loss: 0.2147 - mse: 0.2147 - mae: 0.27 - ETA: 2s - loss: 0.2168 - mse:  - ETA: 1s - loss: 0.2277 - mse: 0.2277 -
# Epoch 77/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.3147 - mse: 0.3147 - mae: 0.3298 - val_loss: 1.2102 - val_mse: 1.2102 - val_mae: 0.565844 - mse: 0.3044 - mae: 0.  - ETA: 2s - loss: 0.3070 - mse: 0.3070 - mae: 0. - ETA: 2s - loss: 0.3091 - mse: 0.3091 - - ETA: 1s - loss: 0.3046 - mse: 0.3046
# Epoch 78/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.2226 - mse: 0.2226 - mae: 0.2889 - val_loss: 0.9740 - val_mse: 0.9740 - val_mae: 0.5348.2200 -  - ETA: 0s - loss: 0.2157 - mse: 0.2157 - ma - ETA: 0s - loss: 0.2224 - mse: 0.2224 - mae: 0.288
# Epoch 79/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.1827 - mse: 0.1827 - mae: 0.2794 - val_loss: 0.8805 - val_mse: 0.8805 - val_mae: 0.5065- mse: 0.187
# Epoch 80/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.1429 - mse: 0.1429 - mae: 0.2461 - val_loss: 0.9059 - val_mse: 0.9059 - val_mae: 0.4858s: 0.1483 - mse: 0.1483 - mae: 0. - ETA: 7s - loss: 0.1421 - mse: 0.1421 - ma - ETA: 6s - loss: 0.1499 - ms - ETA: 4s - loss: 0.1452 - mse: 0.1452 -  - ETA: 3s - loss: 0.1466 - mse: 0.1466 - ETA: 1s - loss: 0.1460 - mse:  - ETA: 0s - loss: 0.1424 - mse: 0.1424 - mae: 0.246
# Epoch 81/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.0967 - mse: 0.0967 - mae: 0.2150 - val_loss: 0.9085 - val_mse: 0.9085 - val_mae: 0.4893
# Epoch 82/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.1034 - mse: 0.1034 - mae: 0.2128 - val_loss: 0.9221 - val_mse: 0.9221 - val_mae: 0.4773TA: 3s - loss:  - ETA: 0s - loss: 0.1033 - mse: 0.1033 - mae: 0.2
# Epoch 83/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.0866 - mse: 0.0866 - mae: 0.2079 - val_loss: 0.8767 - val_mse: 0.8767 - val_mae: 0.4738s: 0.0869 - mse: 0.0869 - mae: 0.
# Epoch 84/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.0928 - mse: 0.0928 - mae: 0.2069 - val_loss: 0.8857 - val_mse: 0.8857 - val_mae: 0.4704- mse: 0.0857 -  - ETA: 3s - loss: 0.0911 - mse: 0 - ETA: 1s - loss: 0.0931 - mse: 0
# Epoch 85/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.0871 - mse: 0.0871 - mae: 0.2006 - val_loss: 0.9688 - val_mse: 0.9688 - val_mae: 0.4879loss: 0.0657 - mse: 0.0657 -  - ETA: 8s - loss: 0.0679 - mse: 0.0679 -  - ETA: 7s - loss: 0.0730 - - ETA - ETA: 0s - loss: 0.0874 - mse: 0.0874 - mae: 0.2
# Epoch 86/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.0798 - mse: 0.0798 - mae: 0.1923 - val_loss: 0.9628 - val_mse: 0.9628 - val_mae: 0.4952
# Epoch 87/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0719 - mse: 0.0719 - mae: 0.1888 - val_loss: 0.9361 - val_mse: 0.9361 - val_mae: 0.4791
# Epoch 88/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.0761 - mse: 0.0761 - mae: 0.1951 - val_loss: 0.8931 - val_mse: 0.8931 - val_mae: 0.4711 - mae:  - ETA: 1s - loss: 0.0774 - mse: 0.0
# Epoch 89/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.0730 - mse: 0.0730 - mae: 0.1890 - val_loss: 0.8835 - val_mse: 0.8835 - val_mae: 0.4809se: 0.0645 - mae: 0.17 - ETA: 5s - loss: 0.0646 - mse: 0.0646 - ETA: 4s - loss: 0.0656 - mse: 0.0656 - mae - ETA: 3s - loss: 0.0696 - mse: 0.0696 - mae:  - ETA: 3s - loss: 0.0711 -  - ETA: 0s - loss: 0.0713 - mse: 0.0713 -
# Epoch 90/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.0642 - mse: 0.0642 - mae: 0.1785 - val_loss: 0.8830 - val_mse: 0.8830 - val_mae: 0.4729 0.0689 - m - ETA: 1s - loss: 0.0665 - mse: 0.0 - ETA: 0s - loss: 0.0641 - mse: 0.0641 - mae: 0.178
# Epoch 91/150
# 10247/10247 [==============================] - 10s 963us/step - loss: 0.0647 - mse: 0.0647 - mae: 0.1835 - val_loss: 0.9184 - val_mse: 0.9184 - val_mae: 0.4796oss: 0. - ETA: 5s - loss: 0.0628 - mse: 0.0628 - mae: 0. - ETA: 5s - loss: 0.0632  - ETA: 2s - loss: 0.0
# Epoch 92/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.0632 - mse: 0.0632 - mae: 0.1803 - val_loss: 0.9057 - val_mse: 0.9057 - val_mae: 0.4843 loss: 0.0680 - mse: 0.068 - ETA: 7s - loss: 0.0636  - ETA: 4s - loss: 0.0644 - mse: 0.0644 - mae:  - ETA: 4s - loss: 0.0632 - mse: 0.0632 - - ETA: 3s - loss: 0.0609 - mse: 0.0609 - mae: - ETA: 2s - loss: 0.0617 - mse: 0.0617  - ETA: 1s - loss: 0.0609 - mse: 0.0609  - ETA: 0s - loss: 0.0627 - mse: 0.0627 - mae: 0.1
# Epoch 93/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0572 - mse: 0.0572 - mae: 0.1731 - val_loss: 0.9083 - val_mse: 0.9083 - val_mae: 0.4688
# Epoch 94/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.0601 - mse: 0.0601 - mae: 0.1758 - val_loss: 0.8586 - val_mse: 0.8586 - val_mae: 0.47514s - loss: 0.0602 - mse: 0.0602 - mae: 0.177 - ETA: 4s - loss: 0.0602 - mse: 0. - ETA: 2s - loss: 0.0604 - mse: 0.0604 - ma - ETA: 2s - loss: 0.0594 - mse: 0.0594 - mae: 0.175 - ETA: 1s - loss: 0.0594 - mse:
# Epoch 95/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.0708 - mse: 0.0708 - mae: 0.1824 - val_loss: 0.8324 - val_mse: 0.8324 - val_mae: 0.4600: 0.0722 -  - ETA: 4s - loss: 0.0710 - mse: 0.0710 - ETA: 2s - loss: 0.
# Epoch 96/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0626 - mse: 0.0626 - mae: 0.1774 - val_loss: 0.8768 - val_mse: 0.8768 - val_mae: 0.4614e: 0 - ETA: 4s - loss: 0.0613 - mse: 0.0613 - mae: 0.176 - ETA:  - ETA: 0s - loss: 0.0621 - mse: 0.0621 - mae: 0.1
# Epoch 97/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.0575 - mse: 0.0575 - mae: 0.1739 - val_loss: 0.8834 - val_mse: 0.8834 - val_mae: 0.4686loss: 0.0537 - mse: 0.0537 - mae:  - ETA: 6s - loss: 0.0564 - mse: 0.0564 - mae: 0.170 - ETA: 6s - loss: 0.0563 - mse: 0.0563 - mae:  - ETA: 5s - loss: 0.0568 - mse: 0.0568 - - ETA: 4s - - ETA: 0s - loss: 0.0577 - mse: 0.0577 - mae: 0 - ETA: 0s - loss: 0.0572 - mse: 0.0572 - mae: 0.17
# Epoch 98/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0588 - mse: 0.0588 - mae: 0.1736 - val_loss: 0.8624 - val_mse: 0.8624 - val_mae: 0.4605 mae: 0. - ETA: 5s - loss: 0.0599 - mse: 0 - ETA: 4s - loss: 0.0584 - mse: 0. - ETA: 2s - loss: 0.0585 -  - ETA: 0s - loss: 0.0588 - mse: 0.0588 - mae: 0.173
# Epoch 99/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.0566 - mse: 0.0566 - mae: 0.1696 - val_loss: 0.9097 - val_mse: 0.9097 - val_mae: 0.4665oss: 0.0566 - mse:  - ETA: 1s - loss: 0.0560 - mse: 0.0
# Epoch 100/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.0559 - mse: 0.0559 - mae: 0.1687 - val_loss: 0.8609 - val_mse: 0.8609 - val_mae: 0.4649
# Epoch 101/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0570 - mse: 0.0570 - mae: 0.1699 - val_loss: 0.8889 - val_mse: 0.8889 - val_mae: 0.4681 0.0566  - ETA: 3s - loss: 0.0562 - mse: 0.05 - ETA: 2s - loss: 0.0559 -
# Epoch 102/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.0667 - mse: 0.0667 - mae: 0.1812 - val_loss: 0.8843 - val_mse: 0.8843 - val_mae: 0.486077 - ETA: 3s - loss: 0.0663 - mse: 0 - ETA: 1s - loss: 0.0662 - mse
# Epoch 103/150
# 10247/10247 [==============================] - 10s 957us/step - loss: 0.0623 - mse: 0.0623 - mae: 0.1753 - val_loss: 0.8360 - val_mse: 0.8360 - val_mae: 0.4557ae: 0.1 - ETA: 3s - loss: 0.0602 - mse: 0.0602 - m - ETA: 3s - loss: 0.0604 - mse: 0.0604 - mae: 0. - ETA: 2s - loss: 0.0605 - mse: 0.0605 - mae:  - ETA: 2s - loss: 0.0605 - mse: 0.0605 - mae: 0.1 - ETA: 1s - loss: 0.0607 - mse: 0.0607 - ETA: 0s - loss: 0.0618 - mse: 0.0618 - mae:
# Epoch 104/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.0621 - mse: 0.0621 - mae: 0.1776 - val_loss: 0.8660 - val_mse: 0.8660 - val_mae: 0.4669loss: 0.0680 - mse: 0.0680 - mae: 0 - ETA: 5s - loss: 0.0660 - mse:  - ETA: 3s - los - ETA: 0s - loss: 0.0633 - mse: 0.0633 - mae: 0.179 - ETA: 0s - loss: 0.0631 - mse: 0.0631 - mae: 0.178 - ETA: 0s - loss: 0.0628 - mse: 0.0628 - mae: 0
# Epoch 105/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.0590 - mse: 0.0590 - mae: 0.1708 - val_loss: 0.8653 - val_mse: 0.8653 - val_mae: 0.4672 loss: 0.0549 - mse: 0.0549 - - ETA: 6s - loss: 0.0546  - ETA: 3s - loss: 0.0543 - mse:  - ETA: 1s - loss: 0.0580 - mse: 0.0580 - mae: 0 - ETA: 1s - loss: 0.0575 - mse: 0.0575 - mae: 0.16 - ETA: 1s - loss: 0.0572 - mse: 0.057
# Epoch 106/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0617 - mse: 0.0617 - mae: 0.1740 - val_loss: 0.8336 - val_mse: 0.8336 - val_mae: 0.4584628 - mse: 0.0628 - mae: - ETA: 2s - loss: 0.0621 - ms
# Epoch 107/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0580 - mse: 0.0580 - mae: 0.1700 - val_loss: 0.9047 - val_mse: 0.9047 - val_mae: 0.4723 0.0571 - mse: 0.0571 - mae: 0.16 - ETA: 6s - loss: 0.0578 - mse: 0.0578 - mae: 0.166 - ETA: 6s - loss: 0.0576 - mse: 0.0576 -  - ETA: 5s - loss: 0 - ETA: 2s - loss: 0.0577 - mse: 0.0577 - mae - ETA: 1s - loss: 0.0574 - mse: 0.0574 - mae: 0.16 - ETA: 1s - loss: 0.0573 - mse: 0.0
# Epoch 108/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.0571 - mse: 0.0571 - mae: 0.1691 - val_loss: 0.8675 - val_mse: 0.8675 - val_mae: 0.4617A: 3s - loss: 0.0571 - mse: 0.0571 - ETA: 2s - loss: 0.0569 - mse: 0.056 - ETA: 1s - loss: 0.0571 - mse: 0.057
# Epoch 109/150
# 10247/10247 [==============================] - 10s 964us/step - loss: 0.0508 - mse: 0.0508 - mae: 0.1614 - val_loss: 0.8739 - val_mse: 0.8739 - val_mae: 0.46450.0508 - mae - ETA: 0s - loss: 0.0506 - mse: 0.0506 - mae: 0.16
# Epoch 110/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.0531 - mse: 0.0531 - mae: 0.1664 - val_loss: 0.8711 - val_mse: 0.8711 - val_mae: 0.45660.0558 - mse: 0.0558 - mae:  - ETA: 7s - loss: 0.0552 - ms - ETA: 5s - loss: 0.0514 - mse: 0.0514 - m - ETA: 4s - loss: 0.0513 - mse: 0.0513 - m - ETA: 3s - loss: 0.0506 - mse: 0.0506 - ma - ETA: 2s - loss: 0.0512
# Epoch 111/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0523 - mse: 0.0523 - mae: 0.1632 - val_loss: 0.9102 - val_mse: 0.9102 - val_mae: 0.46857 - mse: 0.0497 - mae: 0. - ETA: 7s - loss: 0.0493 - mse: 0.0493  - ETA: 6s - loss: 0.0507 - mse: 0.0507 - - ETA: 5s - loss: 0.050 - ETA: 2s - loss: 0.0521 -
# Epoch 112/150
# 10247/10247 [==============================] - 10s 957us/step - loss: 0.0582 - mse: 0.0582 - mae: 0.1693 - val_loss: 0.8498 - val_mse: 0.8498 - val_mae: 0.4621
# Epoch 113/150
# 10247/10247 [==============================] - 10s 967us/step - loss: 0.0634 - mse: 0.0634 - mae: 0.1686 - val_loss: 0.9016 - val_mse: 0.9016 - val_mae: 0.46734 - mse: 0.0584 - ETA: 3s - loss: 0.0597 - mse: 0.059 - ETA: 1s - loss: 0.0604 - mse:
# Epoch 114/150
# 10247/10247 [==============================] - 10s 950us/step - loss: 0.0797 - mse: 0.0797 - mae: 0.1826 - val_loss: 0.9322 - val_mse: 0.9322 - val_mae: 0.4863
# Epoch 115/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.1102 - mse: 0.1102 - mae: 0.1994 - val_loss: 1.0246 - val_mse: 1.0246 - val_mae: 0.5287 loss:
# Epoch 116/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.1977 - mse: 0.1977 - mae: 0.2488 - val_loss: 1.1417 - val_mse: 1.1417 - val_mae: 0.5601 loss: 0.1605 - mse: 0.1605 - mae: 0 - ETA: 5s - loss: 0.1579 - m - ETA: 3s - loss: 0.1587 - mse: 0.1587 - mae - ETA: 3s - loss: 0.1648 - ETA: 0s - loss: 0.1934 - mse: 0.1934 - mae: 0
# Epoch 117/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.3448 - mse: 0.3448 - mae: 0.3188 - val_loss: 1.1141 - val_mse: 1.1141 - val_mae: 0.5643
# Epoch 118/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.2394 - mse: 0.2394 - mae: 0.2784 - val_loss: 0.9860 - val_mse: 0.9860 - val_mae: 0.5082e: 0.2700 - mae: 0 - ETA: 5s - loss: 0. - ETA: 2s - loss: 0.2449 - mse: 0.2449 - - ETA: 0s - loss: 0.2445 - mse: 0.2445 - mae: 0 - ETA: 0s - loss: 0.2411 - mse: 0.2411 - mae:
# Epoch 119/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.1471 - mse: 0.1471 - mae: 0.2344 - val_loss: 0.9670 - val_mse: 0.9670 - val_mae: 0.5198
# Epoch 120/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.1147 - mse: 0.1147 - mae: 0.2066 - val_loss: 0.9210 - val_mse: 0.9210 - val_mae: 0.48141187 - mse: 0.1187 - mae: 0.2 - ETA: 1s - loss: 0.1195 - mse: 0.1195 - mae: - ETA: 0s - loss: 0.1180 - mse: 0.1180 - mae:  - ETA: 0s - loss: 0.1162 - mse: 0.1162 - mae: 0
# Epoch 121/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0858 - mse: 0.0858 - mae: 0.1845 - val_loss: 0.8969 - val_mse: 0.8969 - val_mae: 0.4760794 - mse: 0.0794 - mae:  - ETA: 7s - loss - ETA: 3s - loss: 0.0735 - mse: 0.0735 - mae - ETA: 3s - loss: 0.085 - ETA: 0s - loss: 0.0866 - mse: 0.0866 - mae: 0
# Epoch 122/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0700 - mse: 0.0700 - mae: 0.1786 - val_loss: 0.8641 - val_mse: 0.8641 - val_mae: 0.4801- ETA: 5s - loss: 0.0684 - mse: 0.0684  - ETA: 3s
# Epoch 123/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.0611 - mse: 0.0611 - mae: 0.1695 - val_loss: 0.9040 - val_mse: 0.9040 - val_mae: 0.4773A: 4s - loss: 0.0658 - mse: 0.065 - ETA: 2s - loss: 0.0637 - mse: 0. - ETA: 0s - loss: 0.0626 - mse: 0.0626 - mae: - ETA: 0s - loss: 0.0613 - mse: 0.0613 - mae: 0.
# Epoch 124/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0494 - mse: 0.0494 - mae: 0.1589 - val_loss: 0.8516 - val_mse: 0.8516 - val_mae: 0.4619oss: 0.0496 - mse: 0.0496 - mae: 0. - ETA: 4s - loss: 0.0489 - mse: 0 - ETA: 3s - loss: 0.0479 - mse - ETA: 1s - loss: 0.0484 - mse: 0.0484 - - ETA: 0s - loss: 0.0493 - mse: 0.0493 - mae: 0.158
# Epoch 125/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0515 - mse: 0.0515 - mae: 0.1606 - val_loss: 0.8595 - val_mse: 0.8595 - val_mae: 0.4650oss: 0.0534 - mse: 0.0534 - m - ETA: 1s - loss: 0.0524 - mse: 0.0524 - mae: 0.16 - ETA: 1s - loss: 0.0523 - mse: 0
# Epoch 126/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0466 - mse: 0.0466 - mae: 0.1533 - val_loss: 0.8758 - val_mse: 0.8758 - val_mae: 0.4626oss: 0.0519 - mse: 0.0519 - mae: 0.16 - ETA: 8s - loss: 0.0503 - ETA: 6s - loss: 0.0470 - mse: 0.0470 -
# Epoch 127/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0478 - mse: 0.0478 - mae: 0.1545 - val_loss: 0.8615 - val_mse: 0.8615 - val_mae: 0.4575- ETA: 3s - loss: 0.0473 - mse: 0.0473 - - ETA: 1s - loss: 0.0476 - mse: 0.0476 - - ETA: 0s - loss: 0.0483 - mse: 0.0483 - m
# Epoch 128/150
# 10247/10247 [==============================] - 10s 961us/step - loss: 0.0455 - mse: 0.0455 - mae: 0.1525 - val_loss: 0.8793 - val_mse: 0.8793 - val_mae: 0.4643
# Epoch 129/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0431 - mse: 0.0431 - mae: 0.1473 - val_loss: 0.8724 - val_mse: 0.8724 - val_mae: 0.4600.0430 - mae: 0.146 - ETA: 2s - loss: 0.0429 - m
# Epoch 130/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.0422 - mse: 0.0422 - mae: 0.1475 - val_loss: 0.8608 - val_mse: 0.8608 - val_mae: 0.4660
# Epoch 131/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1422 - val_loss: 0.8346 - val_mse: 0.8346 - val_mae: 0.4548390 - mse: 0.03 - ETA: 4s - loss: 0.0386 - mse: 0.0386 - mae: - ETA: 4s - loss: 0.0396 - mse: 0.0396 - mae: - ETA: 3s - loss: 0.0 - ETA: 0s - loss: 0.0393 - mse: 0.0393 - ma
# Epoch 132/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0425 - mse: 0.0425 - mae: 0.1462 - val_loss: 0.8500 - val_mse: 0.8500 - val_mae: 0.4581loss: 0.0423 - mse: 0.0423 - mae: 0.1
# Epoch 133/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1429 - val_loss: 0.8563 - val_mse: 0.8563 - val_mae: 0.4554.0384 - mse: 0.0384 - mae: 0.1 - ETA: 6s - loss: 0.0380 - mse: 0.0380 - mae: 0. - ETA: 5s - ETA: 1s - loss: 0.0398 - mse
# Epoch 134/150
# 10247/10247 [==============================] - 10s 957us/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1432 - val_loss: 0.8753 - val_mse: 0.8753 - val_mae: 0.4689ae: 0. - ETA: 0s - loss: 0.0392 - mse: 0.0392 - mae: 0.1
# Epoch 135/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.1360 - mse: 0.1360 - mae: 0.2138 - val_loss: 1.0339 - val_mse: 1.0339 - val_mae: 0.5379se: 0.0485 - mae: 0.155 - ETA: 6s - loss: 0.0490 - mse: 0.0490 - mae: 0. - ETA: 6s - loss: 0.0510 - mse: 0.0510 - mae: 0.15 - ETA: 6s - loss: 0.0513 - mse: 0.0513 - mae: 0. - ETA: 6s - loss: 0.0528 - m - ETA: 3s - loss: 0.0865 - mse: 0.0865 -  - ETA: 2s - loss: 0.0
# Epoch 136/150
# 10247/10247 [==============================] - 10s 962us/step - loss: 0.2792 - mse: 0.2792 - mae: 0.2901 - val_loss: 1.0839 - val_mse: 1.0839 - val_mae: 0.5494s - loss: 0.2654 - mse: 0.2654 - mae: 0.28 - ETA: 3s - loss: 0.2644 - mse: - ETA: 1s - loss: 0.2741 - mse:
# Epoch 137/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.2129 - mse: 0.2129 - mae: 0.2631 - val_loss: 1.0256 - val_mse: 1.0256 - val_mae: 0.5079mse: 0.2243 - m - ETA: 5s - loss: 0.2328 - - ETA: 3s - loss: 0.2324 - mse: 0.2324 - mae:  - ETA: 2s - loss: 0.22
# Epoch 138/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.1230 - mse: 0.1230 - mae: 0.2141 - val_loss: 0.9959 - val_mse: 0.9959 - val_mae: 0.5028 - m
# Epoch 139/150
# 10247/10247 [==============================] - 10s 955us/step - loss: 0.1164 - mse: 0.1164 - mae: 0.1939 - val_loss: 0.9748 - val_mse: 0.9748 - val_mae: 0.4889: 0s - loss: 0.1186 - mse: 0.1186 - mae:
# Epoch 140/150
# 10247/10247 [==============================] - 10s 960us/step - loss: 0.0942 - mse: 0.0942 - mae: 0.1822 - val_loss: 0.9423 - val_mse: 0.9423 - val_mae: 0.4786 mse: 0.0694 - - ETA: 5s - loss: 0.0763 - mse: 0.0763 - mae - ETA: 4s - loss: 0.0735 - mse: 0.0735 - mae:  - ETA: 4s - loss: 0.0976 - mse: 0 - ETA: 2s - loss: 0.0988 - mse: 0 - ETA: 0s - loss: 0.0940 - mse: 0.0940 - ma
# Epoch 141/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.1084 - mse: 0.1084 - mae: 0.1906 - val_loss: 0.9142 - val_mse: 0.9142 - val_mae: 0.4680
# Epoch 142/150
# 10247/10247 [==============================] - 10s 951us/step - loss: 0.0758 - mse: 0.0758 - mae: 0.1735 - val_loss: 0.9570 - val_mse: 0.9570 - val_mae: 0.4738 0.0808 - mse: 0.0808 - mae: 0.17 - ETA: 3s - loss: 0.0796 - ETA: 0s - loss: 0.0776 - mse: 0.0776 - ma
# Epoch 143/150
# 10247/10247 [==============================] - 10s 956us/step - loss: 0.0575 - mse: 0.0575 - mae: 0.1607 - val_loss: 0.9048 - val_mse: 0.9048 - val_mae: 0.4666mse: 0.0555 -  - ETA: 6s - loss: 0.0585 - mse: - ETA:
# Epoch 144/150
# 10247/10247 [==============================] - 10s 953us/step - loss: 0.0565 - mse: 0.0565 - mae: 0.1630 - val_loss: 0.9177 - val_mse: 0.9177 - val_mae: 0.466679 - mse: 0.05 - ETA: 5s - loss: 0.0572 - ETA: 2s - loss: 0.0565 - mse: 0. - ETA: 1s - loss: 0.0561 - mse: 0.0561 -
# Epoch 145/150
# 10247/10247 [==============================] - 10s 965us/step - loss: 0.0528 - mse: 0.0528 - mae: 0.1591 - val_loss: 0.9500 - val_mse: 0.9500 - val_mae: 0.4747- loss: 0.0440 - mse: 0.0440 - mae: 0 - ETA: 7s - loss: 0.0429 - mse: 0.0429 - mae: 0.14 - ETA: 7s - loss: 0.0433 - mse: 0.0 - ETA: 5s - loss: 0 - ETA: 2s - loss: 0.0496 - mse: 0.0496 - mae: 0. - ETA: 2s - loss: 0.0502 -
# Epoch 146/150
# 10247/10247 [==============================] - 10s 959us/step - loss: 0.0676 - mse: 0.0676 - mae: 0.1621 - val_loss: 0.9050 - val_mse: 0.9050 - val_mae: 0.4657 - ETA: 4s - loss: 0.0746 - mse: 0.0746 - mae: 0.1 - ETA: 4s - loss: 0.0729 - mse: 0 - ETA: 2s - loss: 0.0678 - mse: 0.0678 - - ETA: 1s - loss: 0.0710 - mse: 0.07 - ETA: 0s - loss: 0.0679 - mse: 0.0679 - mae: 0.162 - ETA: 0s - loss: 0.0676 - mse: 0.0676 - mae: 0.16
# Epoch 147/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0511 - mse: 0.0511 - mae: 0.1562 - val_loss: 0.9556 - val_mse: 0.9556 - val_mae: 0.4776 0. - ETA: 5s - loss: 0.0471 - mse: 0. - ETA: 3s - los - ETA: 0s - loss: 0.0509 - mse: 0.0509 - mae: 0.156
# Epoch 148/150
# 10247/10247 [==============================] - 10s 958us/step - loss: 0.0456 - mse: 0.0456 - mae: 0.1492 - val_loss: 0.8962 - val_mse: 0.8962 - val_mae: 0.4632 mse: 0.0459 - mae: - ETA: 2s - loss: 0.0458 - mse: 0.0458 - mae: 0. - ETA: 2s - loss: 0.0468 - mse:  - ETA: 0s - loss: 0.0457 - mse: 0.0457 - mae:
# Epoch 149/150
# 10247/10247 [==============================] - 10s 954us/step - loss: 0.0449 - mse: 0.0449 - mae: 0.1483 - val_loss: 0.9051 - val_mse: 0.9051 - val_mae: 0.4596s: 0.0460 - mse: 0.0460 - ma - ETA: 1s - loss: 0.0450 - mse:
# Epoch 150/150
# 10247/10247 [==============================] - 10s 952us/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1439 - val_loss: 0.8730 - val_mse: 0.8730 - val_mae: 0.4544ss: 0.0413 - mse: 0.0413 - mae: - ETA: 0s - loss: 0.0414 - mse: 0.0414 - mae:  - ETA: 0s - loss: 0.0410 - mse: 0.0410 - mae: 0
# EndTime : 2021-12-04 21:39:41.882502

# %%
import json
from keras.models import model_from_json, load_model
workdir = "D://EODC-11K//Result//ODC-11K//ResNet"
# Option 1: Save Weights + Architecture
model.save_weights(workdir+ '//ODC11K_ResNet_model_fix_v3.h5')
with open(workdir + '//ODC11K_ResNet_model_architecture_fix_v3.json', 'w') as f:
    f.write(model.to_json())
# Option 1: Load Weights + Architecture
# with open('model_architecture.json', 'r') as f:
#     new_model_1 = model_from_json(f.read())
# new_model_1.load_weights('model_weights.h5')

# %%
# Option 2: Save/Load the Entire Model
from keras.models import load_model

# Creates a HDF5 file 'my_model.h5'
model.save(workdir + '//ODC11K_ResNet_model_fix_2080ti_v3.h5')

# Deletes the existing model
# del model  

# Returns a compiled model identical to the previous one
# model = load_model('my_model.h5')

# %%
test_eval = model.evaluate(test_X, test_label_array, verbose=1)
# Out:
# 1138/1138 [==============================] - 0s 353us/step

# %%
test_eval
# Out:
# [0.8729746944560737, 0.8729747533798218, 0.45437192916870117]

# %%
accuracy = model_train.history['mse']
val_accuracy = model_train.history['val_mse']
loss = model_train.history['loss']
val_loss = model_train.history['val_loss']

np_acc = np.array(accuracy)
np_val_acc = np.array(val_accuracy)
np_loss = np.array(loss)
np_val_loss = np.array(val_loss)

# %%
import matplotlib
from matplotlib import pyplot as plt

# %%
# accuracy = model_train.history['acc']
# val_accuracy = model_train.history['val_acc']
# loss = model_train.history['loss']
# val_loss = model_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training mse')
plt.plot(epochs, val_accuracy, 'b', label='Validation mse')
plt.title('Training and validation mse')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes = model.predict(test_X)

# %%
predicted_value = predicted_classes

# %%
a = pd.DataFrame(predicted_value)
b = pd.DataFrame(test_label_array)
c = pd.concat([a,b], axis=1)
c.columns=["Predicted","Test"]

# %%
c.to_csv(workdir + '//ODC11K_ResNet_pred_obs_table.csv')

# %%
c
# Out:
#       Predicted      Test
# 0      1.942539  2.079442
# 1      2.087068  2.079442
# 2     -3.469869 -3.747924
# 3      2.084376  2.079442
# 4      1.191160 -0.114399
# ...         ...       ...
# 1133   2.068761  2.079442
# 1134   1.997796  2.079442
# 1135  -1.810248 -2.327235
# 1136   1.874744  2.079442
# 1137   2.019900  2.079442
#
# [1138 rows x 2 columns]

# %%
predicted_value.shape
# Out:
# (1138, 1)

# %%
from scipy.stats import linregress
linregress(b[0], a[0])
# Out:
# LinregressResult(slope=0.8404087513239602, intercept=0.23585718429219993, rvalue=0.8715440324000334, pvalue=0.0, stderr=0.014027789297278458)

# %%
from sklearn.metrics import r2_score
r2_value = r2_score(b,a)
print(r2_value)
# Out:
# 0.7490960043418814

# %%
rse = ((b[0]-a[0])**2).sum()
mse = rse / len(b)
print("Final rmse value is =",np.sqrt(mse))
# Out:
# Final rmse value is = 0.9343311426004793

# %%
workdir = "D://EODC-11K//Result//Fig_ODC-11K"
import seaborn as sns

g = sns.jointplot(x="Test", y="Predicted", data=c, kind='reg', color='#7C7C7C',
                  joint_kws={'line_kws':{'color':'black'}})
g.savefig(workdir+ '//ODC11K_ResNet.png', dpi=300)
